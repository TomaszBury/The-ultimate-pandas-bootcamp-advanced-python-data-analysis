# %%
import pandas as pd
import numpy as np

# %%
################################# DATA ##################################
# 5+ years of stock prices: Apple, Facekook, Microsoft, Google adn Amazon
tech_url = 'https://andybek.com/pandas-tech'
# ...OR
# attached to the lecture

# %%
tech = pd.read_csv(tech_url)

# %%
tech.head()
# Out:
#          date  month  year  day   name    open   close    high     low  \
# 0  2014-01-02      1  2014    2     FB   54.86   54.71   55.22   54.19
# 1  2014-01-02      1  2014    2   AAPL   79.38   79.02   79.58   78.86
# 2  2014-01-02      1  2014    2  GOOGL  557.73  556.56  558.88  554.13
# 3  2014-01-02      1  2014    2   MSFT   37.35   37.16   37.40   37.10
# 4  2014-01-02      1  2014    2   AMZN  398.80  397.97  399.36  394.02
#
#      volume volume_type
# 0  43257622      medium
# 1   8398851         low
# 2   1822719      medium
# 3  30643745      medium
# 4   2140246      medium

# %%
tech.sort_values(by='volume', ascending=False).head(n=9)
# Out:
#             date  month  year  day  name    open   close    high     low  \
# 901   2014-09-19      9  2014   19  MSFT   46.82   47.52   47.57   46.60
# 863   2014-09-09      9  2014    9  AAPL   99.11   97.99  103.08   96.14
# 5745  2018-07-26      7  2018   26    FB  174.89  176.26  180.13  173.75
# 1343  2015-01-27      1  2015   27  MSFT   42.95   42.66   43.20   42.11
# 2066  2015-08-24      8  2015   24  AAPL   94.87  103.12  108.80   92.00
# 95    2014-01-30      1  2014   30    FB   62.10   61.08   62.50   60.46
# 1347  2015-01-28      1  2015   28  AAPL  117.63  115.31  118.12  115.31
# 385   2014-04-24      4  2014   24    FB   63.59   60.87   63.65   59.77
# 2281  2015-10-23     10  2015   23  MSFT   52.30   52.87   54.07   52.25
#
#          volume volume_type
# 901   202526536        high
# 863   189846255        high
# 5745  169803668        high
# 1343  169163953        high
# 2066  162206292        high
# 95    150438699        high
# 1347  146477063        high
# ...

# %%
tech.shape
# Out:
# (7105, 11)

# %%
tech.shape[0] / 250 / 5
# Out:
# 5.684

# %%
tech.year.value_counts() / 5
# Out:
# 2014    252.0
# 2015    252.0
# 2016    252.0
# 2017    251.0
# 2018    251.0
# 2019    163.0
# Name: year, dtype: float64

# %%
tech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7105 entries, 0 to 7104
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7105 non-null   object
#  1   month        7105 non-null   int64
#  2   year         7105 non-null   int64
#  3   day          7105 non-null   int64
#  4   name         7105 non-null   object
#  5   open         7105 non-null   float64
#  6   close        7105 non-null   float64
#  7   high         7105 non-null   float64
#  8   low          7105 non-null   float64
#  9   volume       7105 non-null   int64
#  10  volume_type  7105 non-null   object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 610.7+ KB

# %% [markdown]
# # 171. Index and Rangeindex

# %%
tech.volume.head(n=10)
# Out:
# 0    43257622
# 1     8398851
# 2     1822719
# 3    30643745
# 4     2140246
# 5    38287706
# 6     1669229
# 7    31134795
# 8    14043410
# 9     2213512
# Name: volume, dtype: int64

# %%
tech.head(n=10)
# Out:
#          date  month  year  day   name    open   close    high     low  \
# 0  2014-01-02      1  2014    2     FB   54.86   54.71   55.22   54.19
# 1  2014-01-02      1  2014    2   AAPL   79.38   79.02   79.58   78.86
# 2  2014-01-02      1  2014    2  GOOGL  557.73  556.56  558.88  554.13
# 3  2014-01-02      1  2014    2   MSFT   37.35   37.16   37.40   37.10
# 4  2014-01-02      1  2014    2   AMZN  398.80  397.97  399.36  394.02
# 5  2014-01-03      1  2014    3     FB   55.00   54.56   55.65   54.53
# 6  2014-01-03      1  2014    3  GOOGL  557.50  552.50  558.47  552.47
# 7  2014-01-03      1  2014    3   MSFT   37.20   36.91   37.22   36.60
# 8  2014-01-03      1  2014    3   AAPL   79.00   77.28   79.10   77.20
# 9  2014-01-03      1  2014    3   AMZN  398.29  396.44  402.71  396.22
#
#      volume volume_type
# 0  43257622      medium
# 1   8398851         low
# 2   1822719      medium
# 3  30643745      medium
# 4   2140246      medium
# 5  38287706      medium
# ...

# %%
type(tech.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
tech.columns
# Out:
# Index(['date', 'month', 'year', 'day', 'name', 'open', 'close', 'high', 'low',
#        'volume', 'volume_type'],
#       dtype='object')

# %%
type(tech.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
tech.set_index('date')
# Out:
#             month  year  day   name     open    close     high      low  \
# date
# 2014-01-02      1  2014    2     FB    54.86    54.71    55.22    54.19
# 2014-01-02      1  2014    2   AAPL    79.38    79.02    79.58    78.86
# 2014-01-02      1  2014    2  GOOGL   557.73   556.56   558.88   554.13
# 2014-01-02      1  2014    2   MSFT    37.35    37.16    37.40    37.10
# 2014-01-02      1  2014    2   AMZN   398.80   397.97   399.36   394.02
# ...           ...   ...  ...    ...      ...      ...      ...      ...
# 2019-08-23      8  2019   23   MSFT   137.19   133.39   138.35   132.80
# 2019-08-23      8  2019   23   AAPL   209.43   202.64   212.05   201.00
# 2019-08-23      8  2019   23  GOOGL  1185.17  1153.58  1195.67  1150.00
# 2019-08-23      8  2019   23   AMZN  1793.03  1749.62  1804.90  1745.23
# 2019-08-23      8  2019   23     FB   180.84   177.75   183.13   176.66
#
#               volume volume_type
# date
# 2014-01-02  43257622      medium
# ...

# %%
type(tech.set_index('date').index)
# Out:
# pandas.core.indexes.base.Index

# %%
tech.set_index('date').loc['2019-08-01']
# Out:
#             month  year  day   name     open    close     high      low  \
# date
# 2019-08-01      8  2019    1  GOOGL  1217.63  1211.78  1236.30  1207.00
# 2019-08-01      8  2019    1     FB   194.17   192.73   198.47   190.88
# 2019-08-01      8  2019    1   MSFT   137.00   138.06   140.94   136.93
# 2019-08-01      8  2019    1   AMZN  1871.72  1855.32  1897.92  1844.01
# 2019-08-01      8  2019    1   AAPL   213.90   208.43   218.03   206.74
#
#               volume volume_type
# date
# 2019-08-01   1771271      medium
# 2019-08-01  17777013      medium
# 2019-08-01  40557502      medium
# 2019-08-01   4713311      medium
# 2019-08-01  54017922      medium

# %% [markdown]
# # 172. Dreating a Mulitindex

# %%
tech.set_index('date')
# Out:
#             month  year  day   name     open    close     high      low  \
# date
# 2014-01-02      1  2014    2     FB    54.86    54.71    55.22    54.19
# 2014-01-02      1  2014    2   AAPL    79.38    79.02    79.58    78.86
# 2014-01-02      1  2014    2  GOOGL   557.73   556.56   558.88   554.13
# 2014-01-02      1  2014    2   MSFT    37.35    37.16    37.40    37.10
# 2014-01-02      1  2014    2   AMZN   398.80   397.97   399.36   394.02
# ...           ...   ...  ...    ...      ...      ...      ...      ...
# 2019-08-23      8  2019   23   MSFT   137.19   133.39   138.35   132.80
# 2019-08-23      8  2019   23   AAPL   209.43   202.64   212.05   201.00
# 2019-08-23      8  2019   23  GOOGL  1185.17  1153.58  1195.67  1150.00
# 2019-08-23      8  2019   23   AMZN  1793.03  1749.62  1804.90  1745.23
# 2019-08-23      8  2019   23     FB   180.84   177.75   183.13   176.66
#
#               volume volume_type
# date
# 2014-01-02  43257622      medium
# ...

# %%
tech.set_index(['date','name'], inplace=True)

# %%
tech.head(n=10)
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
# 2014-01-03 FB         1  2014    3   55.00   54.56   55.65   54.53  38287706
#            GOOGL      1  2014    3  557.50  552.50  558.47  552.47   1669229
#            MSFT       1  2014    3   37.20   36.91   37.22   36.60  31134795
#            AAPL       1  2014    3   79.00   77.28   79.10   77.20  14043410
#            AMZN       1  2014    3  398.29  396.44  402.71  396.22   2213512
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
# ...

# %%
tech.loc['2014-01-02']
# Out:
#        month  year  day    open   close    high     low    volume volume_type
# name
# FB         1  2014    2   54.86   54.71   55.22   54.19  43257622      medium
# AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851         low
# GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719      medium
# MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745      medium
# AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246      medium

# %%
type(tech.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# # 173. Multiindex from read_csv()

# %%
############# Previously #################
# tech = pd.read_csv(tech_url)
# tech.set_index(['date', 'name'])

# %%
tech = pd.read_csv(tech_url, index_col=['date', 'name'])

# %%
tech.head(n=10)
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
# 2014-01-03 FB         1  2014    3   55.00   54.56   55.65   54.53  38287706
#            GOOGL      1  2014    3  557.50  552.50  558.47  552.47   1669229
#            MSFT       1  2014    3   37.20   36.91   37.22   36.60  31134795
#            AAPL       1  2014    3   79.00   77.28   79.10   77.20  14043410
#            AMZN       1  2014    3  398.29  396.44  402.71  396.22   2213512
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
# ...

# %%
# another approach

# %%
# pd.DataFrame(data, index=MultiIndexObject)

# %% [markdown]
# # 174. Indexing hierarchical DataFrames

# %%
tech.head(n=10)
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
# 2014-01-03 FB         1  2014    3   55.00   54.56   55.65   54.53  38287706
#            GOOGL      1  2014    3  557.50  552.50  558.47  552.47   1669229
#            MSFT       1  2014    3   37.20   36.91   37.22   36.60  31134795
#            AAPL       1  2014    3   79.00   77.28   79.10   77.20  14043410
#            AMZN       1  2014    3  398.29  396.44  402.71  396.22   2213512
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
# ...

# %%
tech.loc['2014-01-02']
# Out:
#        month  year  day    open   close    high     low    volume volume_type
# name
# FB         1  2014    2   54.86   54.71   55.22   54.19  43257622      medium
# AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851         low
# GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719      medium
# MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745      medium
# AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246      medium

# %%
tech.loc['2014-01-02'].loc['GOOGL','close']
# Out:
# 556.56

# %%
tech.loc['2014-01-02','GOOGL'].close
# Out:
# 556.56

# %%
tech.loc[('2014-01-02','GOOGL'),'close']
# Out:
# 556.56

# %%
tech.head()
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
#            AAPL          low
#            GOOGL      medium
#            MSFT       medium
#            AMZN       medium

# %%
tech.iloc[2,4]
# Out:
# 556.56

# %%
tech.loc[('2014-01-03', 'AAPL'), 'open':'close']
# Out:
# open     79.00
# close    77.28
# Name: (2014-01-03, AAPL), dtype: float64

# %%
tech.iloc[8,3:5]
# Out:
# open     79.00
# close    77.28
# Name: (2014-01-03, AAPL), dtype: float64

# %% [markdown]
# 175. Indexing Ranges and Slices

# %%
# selsect multiple days

# %%
tech.loc[['2015-01-06','2015-01-07']]
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2015-01-06 AAPL       1  2015    6  106.54  106.26  107.43  104.63  65797116
#            FB         1  2015    6   77.23   76.15   77.59   75.36  27399288
#            AMZN       1  2015    6  302.20  295.29  303.00  292.38   3519034
#            MSFT       1  2015    6   46.38   45.65   46.75   45.54  36447854
#            GOOGL      1  2015    6  520.49  506.64  521.21  505.55   2731813
# 2015-01-07 FB         1  2015    7   76.76   76.15   77.36   75.82  22045333
#            MSFT       1  2015    7   45.98   46.23   46.46   45.49  29114061
#            GOOGL      1  2015    7  510.99  505.15  511.49  503.65   2345875
#            AMZN       1  2015    7  297.54  298.42  301.28  295.33   2640349
#            AAPL       1  2015    7  107.20  107.75  108.20  106.70  40105934
#
#                  volume_type
# date       name
# 2015-01-06 AAPL       medium
# ...

# %%
tech.index
# Out:
# MultiIndex([('2014-01-02',    'FB'),
#             ('2014-01-02',  'AAPL'),
#             ('2014-01-02', 'GOOGL'),
#             ('2014-01-02',  'MSFT'),
#             ('2014-01-02',  'AMZN'),
#             ('2014-01-03',    'FB'),
#             ('2014-01-03', 'GOOGL'),
#             ('2014-01-03',  'MSFT'),
#             ('2014-01-03',  'AAPL'),
#             ('2014-01-03',  'AMZN'),
#             ...
#             ('2019-08-22',  'MSFT'),
#             ('2019-08-22',    'FB'),
#             ('2019-08-22',  'AMZN'),
#             ('2019-08-22',  'AAPL'),
#             ('2019-08-22', 'GOOGL'),
#             ('2019-08-23',  'MSFT'),
#             ('2019-08-23',  'AAPL'),
#             ('2019-08-23', 'GOOGL'),
#             ('2019-08-23',  'AMZN'),
#             ('2019-08-23',    'FB')],
#            names=['date', 'name'], length=7105)

# %%
dates = pd.DataFrame(columns=['date', 'name'])

# %%
dates
# Out:
# Empty DataFrame
# Columns: [date, name]
# Index: []

# %%
dates_data = tech.index.to_flat_index().tolist()

# %%
dates_data
# Out:
# [('2014-01-02', 'FB'),
#  ('2014-01-02', 'AAPL'),
#  ('2014-01-02', 'GOOGL'),
#  ('2014-01-02', 'MSFT'),
#  ('2014-01-02', 'AMZN'),
#  ('2014-01-03', 'FB'),
#  ('2014-01-03', 'GOOGL'),
#  ('2014-01-03', 'MSFT'),
#  ('2014-01-03', 'AAPL'),
#  ('2014-01-03', 'AMZN'),
#  ('2014-01-06', 'MSFT'),
#  ('2014-01-06', 'AMZN'),
#  ('2014-01-06', 'AAPL'),
#  ('2014-01-06', 'GOOGL'),
#  ('2014-01-06', 'FB'),
#  ('2014-01-07', 'FB'),
#  ('2014-01-07', 'AAPL'),
#  ('2014-01-07', 'MSFT'),
#  ('2014-01-07', 'AMZN'),
#  ('2014-01-07', 'GOOGL'),
#  ('2014-01-08', 'AAPL'),
#  ('2014-01-08', 'AMZN'),
#  ('2014-01-08', 'MSFT'),
#  ('2014-01-08', 'GOOGL'),
#  ('2014-01-08', 'FB'),
#  ('2014-01-09', 'AAPL'),
#  ('2014-01-09', 'AMZN'),
#  ('2014-01-09', 'GOOGL'),
#  ('2014-01-09', 'FB'),
#  ('2014-01-09', 'MSFT'),
#  ('2014-01-10', 'AAPL'),
#  ('2014-01-10', 'GOOGL'),
#  ('2014-01-10', 'MSFT'),
#  ('2014-01-10', 'FB'),
#  ('2014-01-10', 'AMZN'),
#  ('2014-01-13', 'AAPL'),
#  ('2014-01-13', 'MSFT'),
# ...

# %%
type(dates_data)
# Out:
# list

# %%
dates = pd.DataFrame(columns=['date', 'name'], data=dates_data)

# %%
dates
# Out:
#             date   name
# 0     2014-01-02     FB
# 1     2014-01-02   AAPL
# 2     2014-01-02  GOOGL
# 3     2014-01-02   MSFT
# 4     2014-01-02   AMZN
# ...          ...    ...
# 7100  2019-08-23   MSFT
# 7101  2019-08-23   AAPL
# 7102  2019-08-23  GOOGL
# 7103  2019-08-23   AMZN
# 7104  2019-08-23     FB
#
# [7105 rows x 2 columns]

# %%
dates.shape
# Out:
# (7105, 2)

# %%
dates.shape[0]
# Out:
# 7105

# %%
type(dates.shape[0])
# Out:
# int

# %%
import random
dates.iloc[random.randint(0,dates.shape[0]),0]
# Out:
# '2015-09-24'

# %%
def list_of_random_dates(n):
    random_dates = []
    for i in range(n):
        random_dates.append(dates.iloc[random.randint(0,dates.shape[0]-1),0])
    return random_dates

# %%
list_dates = list_of_random_dates(5)
list_dates
# Out:
# ['2016-04-18', '2014-07-21', '2015-04-17', '2018-11-08', '2018-01-08']

# %%
tech.loc[list_dates]
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2016-04-18 FB         4  2016   18   109.74   110.45   110.81   109.20
#            AMZN       4  2016   18   625.35   635.35   637.64   624.96
#            GOOGL      4  2016   18   780.19   787.68   788.55   777.61
#            MSFT       4  2016   18    55.49    56.46    56.59    55.21
#            AAPL       4  2016   18   108.89   107.48   108.95   106.94
# 2014-07-21 FB         7  2014   21    68.84    69.40    69.96    68.50
#            AMZN       7  2014   21   358.30   359.76   361.71   356.72
#            AAPL       7  2014   21    95.00    93.94    95.00    93.72
#            GOOGL      7  2014   21   601.35   598.44   604.16   594.45
#            MSFT       7  2014   21    44.55    44.84    45.16    44.22
# 2015-04-17 MSFT       4  2015   17    41.67    41.62    41.74    41.16
#            AAPL       4  2015   17   125.55   124.75   126.14   124.46
# ...

# %%
tech.loc[(['2015-01-06','2015-01-07'],['FB','AMZN']),:]
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2015-01-06 FB        1  2015    6   77.23   76.15   77.59   75.36  27399288
#            AMZN      1  2015    6  302.20  295.29  303.00  292.38   3519034
# 2015-01-07 FB        1  2015    7   76.76   76.15   77.36   75.82  22045333
#            AMZN      1  2015    7  297.54  298.42  301.28  295.33   2640349
#
#                 volume_type
# date       name
# 2015-01-06 FB        medium
#            AMZN      medium
# 2015-01-07 FB        medium
#            AMZN      medium

# %%
tech.loc[(list_of_random_dates(3), ['FB','AMZN']),:]
# Out:
#                  month  year  day     open    close     high      low  \
# date       name
# 2014-10-29 FB       10  2014   29    75.45    75.86    76.88    74.78
#            AMZN     10  2014   29   299.11   294.12   299.61   293.07
# 2018-05-03 FB        5  2018    3   175.13   174.02   176.12   172.12
#            AMZN      5  2018    3  1560.01  1572.08  1574.80  1546.02
# 2015-07-06 FB        7  2015    6    86.49    87.55    88.18    86.39
#            AMZN      7  2015    6   435.23   436.04   439.73   433.52
#
#                     volume volume_type
# date       name
# 2014-10-29 FB    106119520        high
#            AMZN    4883259      medium
# 2018-05-03 FB     24026071      medium
#            AMZN    4251917      medium
# 2015-07-06 FB     24635915      medium
#            AMZN    1903161         low

# %%
# What acout slices?

# %%
tech.loc['2017-01-03':'2017-01-31','open':'low']
# Out:
#                     open   close    high     low
# date       name
# 2017-01-03 AMZN   757.92  753.67  758.76  747.70
#            FB     116.03  116.86  117.84  115.51
#            MSFT    62.79   62.58   62.84   62.13
#            AAPL   115.80  116.15  116.33  114.76
#            GOOGL  800.62  808.01  811.44  796.89
# ...                  ...     ...     ...     ...
# 2017-01-31 MSFT    64.86   64.65   65.15   64.26
#            AAPL   121.15  121.35  121.39  120.62
#            FB     130.17  130.32  130.66  129.52
#            GOOGL  819.50  820.19  823.07  813.40
#            AMZN   823.75  823.48  826.99  819.56
#
# [100 rows x 4 columns]

# %%
# How to isolate google from the above?
# tech.loc[('2017-01-03':'2017-01-31','GOOGL'),'opne':'low']

# SyntaxError: invalid syntax

# %%
# the slice() object
tech.loc[(slice('2017-01-03','2017-01-31'),'GOOGL'),'open':'low']
# Out:
#                     open   close    high     low
# date       name
# 2017-01-03 GOOGL  800.62  808.01  811.44  796.89
# 2017-01-04 GOOGL  809.89  807.77  813.43  804.11
# 2017-01-05 GOOGL  807.50  813.02  813.74  805.92
# 2017-01-06 GOOGL  814.99  825.21  828.96  811.50
# 2017-01-09 GOOGL  826.37  827.18  830.43  821.62
# 2017-01-10 GOOGL  827.07  826.01  829.41  823.14
# 2017-01-11 GOOGL  826.62  829.86  829.90  821.47
# 2017-01-12 GOOGL  828.38  829.53  830.38  821.01
# 2017-01-13 GOOGL  831.00  830.94  834.65  829.52
# 2017-01-17 GOOGL  830.00  827.46  830.18  823.20
# 2017-01-18 GOOGL  829.80  829.02  829.81  824.08
# 2017-01-19 GOOGL  829.00  824.37  833.00  823.96
# 2017-01-20 GOOGL  829.09  828.17  829.24  824.60
# 2017-01-23 GOOGL  831.61  844.43  845.54  828.70
# 2017-01-24 GOOGL  846.98  849.53  851.52  842.28
# 2017-01-25 GOOGL  853.55  858.45  858.79  849.74
# 2017-01-26 GOOGL  859.05  856.98  861.00  850.52
# 2017-01-27 GOOGL  859.00  845.03  867.00  841.90
# ...

# %%
# open price for FB and AMZN for all the dates in our df

# %%
tech.head()
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
#            AAPL          low
#            GOOGL      medium
#            MSFT       medium
#            AMZN       medium

# %%
tech.loc[(slice(None),['FB','AMZN']),'open']
# Out:
# date        name
# 2014-01-02  FB        54.86
# 2014-01-03  FB        55.00
# 2014-01-06  FB        54.39
# 2014-01-07  FB        57.67
# 2014-01-08  FB        57.59
#                      ...
# 2019-08-19  AMZN    1818.08
# 2019-08-20  AMZN    1814.50
# 2019-08-21  AMZN    1819.39
# 2019-08-22  AMZN    1828.00
# 2019-08-23  AMZN    1793.03
# Name: open, Length: 2842, dtype: float64

# %% [markdown]
# # 176. BONUS - Use: with pd.indexSlice

# %%
tech.loc[pd.IndexSlice[:,['FB','AMZN']],'high':'low']
# Out:
#                     high      low
# date       name
# 2014-01-02 FB      55.22    54.19
# 2014-01-03 FB      55.65    54.53
# 2014-01-06 FB      57.26    54.05
# 2014-01-07 FB      58.55    57.22
# 2014-01-08 FB      58.41    57.23
# ...                  ...      ...
# 2019-08-19 AMZN  1826.00  1812.61
# 2019-08-20 AMZN  1816.82  1799.88
# 2019-08-21 AMZN  1829.58  1815.00
# 2019-08-22 AMZN  1829.41  1800.10
# 2019-08-23 AMZN  1804.90  1745.23
#
# [2842 rows x 2 columns]

# %%
i = pd.IndexSlice[:,['FB','AMZN']]
tech.loc[i,'high':'low']
# Out:
#                     high      low
# date       name
# 2014-01-02 FB      55.22    54.19
# 2014-01-03 FB      55.65    54.53
# 2014-01-06 FB      57.26    54.05
# 2014-01-07 FB      58.55    57.22
# 2014-01-08 FB      58.41    57.23
# ...                  ...      ...
# 2019-08-19 AMZN  1826.00  1812.61
# 2019-08-20 AMZN  1816.82  1799.88
# 2019-08-21 AMZN  1829.58  1815.00
# 2019-08-22 AMZN  1829.41  1800.10
# 2019-08-23 AMZN  1804.90  1745.23
#
# [2842 rows x 2 columns]

# %%
# jan 6 to jan 10
i = pd.IndexSlice
tech.loc[i['2014-01-06':'2014-01-10',['FB','AMZN']],'high':'low']
# Out:
#                    high     low
# date       name
# 2014-01-06 AMZN  397.00  388.42
#            FB     57.26   54.05
# 2014-01-07 FB     58.55   57.22
#            AMZN  398.47  394.29
# 2014-01-08 AMZN  403.00  396.04
#            FB     58.41   57.23
# 2014-01-09 AMZN  406.89  398.44
#            FB     58.96   56.65
# 2014-01-10 FB     58.30   57.06
#            AMZN  403.76  393.80

# %% [markdown]
# # 177. Cross section with xs()

# %%
# xs() is a type of label=based indexing

# %%
tech.xs('2019-01-02')
# Out:
#        month  year  day     open    close     high      low    volume  \
# name
# MSFT       1  2019    2    99.55   101.12   101.75    98.94  35329345
# FB         1  2019    2   128.99   135.68   137.51   128.56  28146193
# GOOGL      1  2019    2  1027.20  1054.68  1060.79  1025.28   1593395
# AMZN       1  2019    2  1465.20  1539.13  1553.36  1460.93   7983103
# AAPL       1  2019    2   154.89   157.92   158.85   154.23  37039737
#
#       volume_type
# name
# MSFT       medium
# FB         medium
# GOOGL      medium
# AMZN       medium
# AAPL       medium

# %%
tech.loc['2019-01-02']
# Out:
#        month  year  day     open    close     high      low    volume  \
# name
# MSFT       1  2019    2    99.55   101.12   101.75    98.94  35329345
# FB         1  2019    2   128.99   135.68   137.51   128.56  28146193
# GOOGL      1  2019    2  1027.20  1054.68  1060.79  1025.28   1593395
# AMZN       1  2019    2  1465.20  1539.13  1553.36  1460.93   7983103
# AAPL       1  2019    2   154.89   157.92   158.85   154.23  37039737
#
#       volume_type
# name
# MSFT       medium
# FB         medium
# GOOGL      medium
# AMZN       medium
# AAPL       medium

# %%
tech.loc[(slice(None),'FB'),:]
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB        1  2014    2   54.86   54.71   55.22   54.19  43257622
# 2014-01-03 FB        1  2014    3   55.00   54.56   55.65   54.53  38287706
# 2014-01-06 FB        1  2014    6   54.39   57.20   57.26   54.05  68974359
# 2014-01-07 FB        1  2014    7   57.67   57.92   58.55   57.22  77329009
# 2014-01-08 FB        1  2014    8   57.59   58.23   58.41   57.23  56800776
# ...                ...   ...  ...     ...     ...     ...     ...       ...
# 2019-08-19 FB        8  2019   19  186.01  186.17  187.50  184.85   9699661
# 2019-08-20 FB        8  2019   20  185.45  183.81  186.00  182.39  10087592
# 2019-08-21 FB        8  2019   21  185.00  183.55  185.90  183.14   8409548
# 2019-08-22 FB        8  2019   22  183.43  182.04  184.11  179.91  10829509
# 2019-08-23 FB        8  2019   23  180.84  177.75  183.13  176.66  17331221
#
#                 volume_type
# ...

# %%
tech.xs(key='FB' , level=1 , )
# Out:
#             month  year  day    open   close    high     low    volume  \
# date
# 2014-01-02      1  2014    2   54.86   54.71   55.22   54.19  43257622
# 2014-01-03      1  2014    3   55.00   54.56   55.65   54.53  38287706
# 2014-01-06      1  2014    6   54.39   57.20   57.26   54.05  68974359
# 2014-01-07      1  2014    7   57.67   57.92   58.55   57.22  77329009
# 2014-01-08      1  2014    8   57.59   58.23   58.41   57.23  56800776
# ...           ...   ...  ...     ...     ...     ...     ...       ...
# 2019-08-19      8  2019   19  186.01  186.17  187.50  184.85   9699661
# 2019-08-20      8  2019   20  185.45  183.81  186.00  182.39  10087592
# 2019-08-21      8  2019   21  185.00  183.55  185.90  183.14   8409548
# 2019-08-22      8  2019   22  183.43  182.04  184.11  179.91  10829509
# 2019-08-23      8  2019   23  180.84  177.75  183.13  176.66  17331221
#
#            volume_type
# date
# 2014-01-02      medium
# 2014-01-03      medium
# 2014-01-06        high
# ...

# %%
tech.xs(key='GOOGL', level=1 , drop_level=False)
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 GOOGL      1  2014    2   557.73   556.56   558.88   554.13
# 2014-01-03 GOOGL      1  2014    3   557.50   552.50   558.47   552.47
# 2014-01-06 GOOGL      1  2014    6   556.51   558.66   559.43   553.22
# 2014-01-07 GOOGL      1  2014    7   562.49   569.43   569.85   560.58
# 2014-01-08 GOOGL      1  2014    8   573.66   570.62   573.66   566.65
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-19 GOOGL      8  2019   19  1191.83  1200.44  1209.39  1190.40
# 2019-08-20 GOOGL      8  2019   20  1195.35  1183.53  1198.00  1183.05
# 2019-08-21 GOOGL      8  2019   21  1195.82  1191.58  1200.56  1187.92
# 2019-08-22 GOOGL      8  2019   22  1193.80  1191.52  1198.78  1178.91
# 2019-08-23 GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#
#                    volume volume_type
# date       name
# 2014-01-02 GOOGL  1822719      medium
# ...

# %%
tech.xs(key=('2019-01-02','FB'),level=(0,1))
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2019-01-02 FB        1  2019    2  128.99  135.68  137.51  128.56  28146193
#
#                 volume_type
# date       name
# 2019-01-02 FB        medium

# %% [markdown]
# # 178. Skill Challenge

# %%
# 1. From the tech datafram. selecet all the stock prices between july 13, 2015 and august 17, 2016. Assign the resulting dataframe slice tot the variable tech_df2

# %%
start = '2015-07-13'
end = '2016-08-17'
tech_df2 = tech.loc[pd.IndexSlice[start:end,:],:]

# %%
tech_df2.head(n=1)
# Out:
#                  month  year  day   open  close   high    low    volume  \
# date       name
# 2015-07-13 MSFT      7  2015   13  44.98  45.54  45.62  44.95  28178329
#
#                 volume_type
# date       name
# 2015-07-13 MSFT      medium

# %%
# 2. Select 10 days at randome from tech_df2, containing only AAPL price data.

# %%
import random
from datetime import datetime, timedelta

min_year=2014
max_year=2019

start = datetime(min_year, 1, 1)
years = max_year - min_year+1
end = start + timedelta(days=365 * years)
list_days = []

for i in range(10):
    random_date = start + (end - start) * random.random()
    # print(f'{type(random_date.strftime("%Y-%m-%d"))} - {random_date.strftime("%Y-%m-%d")}')
    list_days.append(random_date.strftime("%Y-%m-%d"))

# %%
list_days
# Out:
# ['2018-12-15',
#  '2015-05-28',
#  '2019-03-19',
#  '2019-04-04',
#  '2015-03-31',
#  '2017-05-03',
#  '2014-04-08',
#  '2019-03-02',
#  '2017-01-18',
#  '2016-03-03']

# %%
tech.loc[(list_days,'AAPL'),:]
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_1032\3298826863.py:1: FutureWarning: The behavior of indexing on a MultiIndex with a nested sequence of labels is deprecated and will change in a future version. `series.loc[label, sequence]` will raise if any members of 'sequence' or not present in the index's second level. To retain the old behavior, use `series.index.isin(sequence, level=1)`
#   tech.loc[(list_days,'AAPL'),:]
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2015-05-28 AAPL      5  2015   28  131.86  131.78  131.95  131.10  30733309
# 2019-03-19 AAPL      3  2019   19  188.35  186.53  188.99  185.92  31646369
# 2019-04-04 AAPL      4  2019    4  194.79  195.69  196.37  193.14  19114275
# 2015-03-31 AAPL      3  2015   31  126.09  124.43  126.49  124.36  42090553
# 2017-05-03 AAPL      5  2017    3  145.59  147.06  147.49  144.27  45697034
# 2014-04-08 AAPL      4  2014    8   75.01   74.78   75.16   74.10   8710269
# ...

# %%
tech.loc[pd.IndexSlice[list_days,'AAPL'],:]
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_1032\3406895546.py:1: FutureWarning: The behavior of indexing on a MultiIndex with a nested sequence of labels is deprecated and will change in a future version. `series.loc[label, sequence]` will raise if any members of 'sequence' or not present in the index's second level. To retain the old behavior, use `series.index.isin(sequence, level=1)`
#   tech.loc[pd.IndexSlice[list_days,'AAPL'],:]
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2015-05-28 AAPL      5  2015   28  131.86  131.78  131.95  131.10  30733309
# 2019-03-19 AAPL      3  2019   19  188.35  186.53  188.99  185.92  31646369
# 2019-04-04 AAPL      4  2019    4  194.79  195.69  196.37  193.14  19114275
# 2015-03-31 AAPL      3  2015   31  126.09  124.43  126.49  124.36  42090553
# 2017-05-03 AAPL      5  2017    3  145.59  147.06  147.49  144.27  45697034
# ...

# %%
# tech.xs(list_days,level=0)

# KeyError: 'Key length (10) exceeds index depth (2)'

# %%
# tech.loc[list_days]

# KeyError: "['2017-11-04' '2019-02-09' '2014-05-25'] not in index"

# %%
# 3 Select all the intraday high and low prices for AAPL and GOOGL for all the dates in tech_df2

# %%
tech_df2.loc[(slice(None),['AAPL',"GOOGL"]),'high':'low']
# Out:
#                     high     low
# date       name
# 2015-07-13 AAPL   125.76  124.32
# 2015-07-14 AAPL   126.37  125.04
# 2015-07-15 AAPL   127.15  125.58
# 2015-07-16 AAPL   128.57  127.35
# 2015-07-17 AAPL   129.62  128.31
# ...                  ...     ...
# 2016-08-11 GOOGL  813.88  806.00
# 2016-08-12 GOOGL  807.19  803.64
# 2016-08-15 GOOGL  811.36  804.03
# 2016-08-16 GOOGL  804.26  797.00
# 2016-08-17 GOOGL  805.63  796.30
#
# [558 rows x 2 columns]

# %% [markdown]
# # 179. Solution

# %%
# 1.
tech_df2 = tech.loc['2015-07-13':'2016-08-17']

# %%
tech_df2.head(n=2)
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2015-07-13 MSFT      7  2015   13   44.98   45.54   45.62   44.95  28178329
#            AMZN      7  2015   13  448.29  455.57  457.87  447.54   3956802
#
#                 volume_type
# date       name
# 2015-07-13 MSFT      medium
#            AMZN      medium

# %%
tech.xs(level=0, key=slice('2015-07-13','2016-08-17'))
# Out:
#        month  year  day    open   close    high     low    volume volume_type
# name
# MSFT       7  2015   13   44.98   45.54   45.62   44.95  28178329      medium
# AMZN       7  2015   13  448.29  455.57  457.87  447.54   3956802      medium
# FB         7  2015   13   88.66   90.10   90.22   88.42  29976670      medium
# GOOGL      7  2015   13  559.51  571.73  572.85  558.70   2089641      medium
# AAPL       7  2015   13  125.03  125.66  125.76  124.32  41440538      medium
# ...      ...   ...  ...     ...     ...     ...     ...       ...         ...
# GOOGL      8  2016   17  800.00  805.42  805.63  796.30   1066070      medium
# AMZN       8  2016   17  764.41  764.63  765.22  759.20   1891116         low
# MSFT       8  2016   17   57.54   57.56   57.68   57.23  18856423      medium
# FB         8  2016   17  123.66  124.37  124.38  122.85  13794179         low
# AAPL       8  2016   17  109.10  109.22  109.37  108.34  25355976      medium
#
# [1395 rows x 9 columns]

# %%
# 2
to_unpack = tech_df2.index.to_flat_index().tolist()
to_unpack
# Out:
# [('2015-07-13', 'MSFT'),
#  ('2015-07-13', 'AMZN'),
#  ('2015-07-13', 'FB'),
#  ('2015-07-13', 'GOOGL'),
#  ('2015-07-13', 'AAPL'),
#  ('2015-07-14', 'AMZN'),
#  ('2015-07-14', 'GOOGL'),
#  ('2015-07-14', 'MSFT'),
#  ('2015-07-14', 'FB'),
#  ('2015-07-14', 'AAPL'),
#  ('2015-07-15', 'AMZN'),
#  ('2015-07-15', 'GOOGL'),
#  ('2015-07-15', 'FB'),
#  ('2015-07-15', 'AAPL'),
#  ('2015-07-15', 'MSFT'),
#  ('2015-07-16', 'AAPL'),
#  ('2015-07-16', 'FB'),
#  ('2015-07-16', 'AMZN'),
#  ('2015-07-16', 'GOOGL'),
#  ('2015-07-16', 'MSFT'),
#  ('2015-07-17', 'GOOGL'),
#  ('2015-07-17', 'AMZN'),
#  ('2015-07-17', 'AAPL'),
#  ('2015-07-17', 'FB'),
#  ('2015-07-17', 'MSFT'),
#  ('2015-07-20', 'FB'),
#  ('2015-07-20', 'AAPL'),
#  ('2015-07-20', 'AMZN'),
#  ('2015-07-20', 'GOOGL'),
#  ('2015-07-20', 'MSFT'),
#  ('2015-07-21', 'MSFT'),
#  ('2015-07-21', 'AMZN'),
#  ('2015-07-21', 'GOOGL'),
#  ('2015-07-21', 'FB'),
#  ('2015-07-21', 'AAPL'),
#  ('2015-07-22', 'MSFT'),
#  ('2015-07-22', 'AAPL'),
# ...

# %%
b = list(map(lambda to: to[0],to_unpack))
b
# Out:
# ['2015-07-13',
#  '2015-07-13',
#  '2015-07-13',
#  '2015-07-13',
#  '2015-07-13',
#  '2015-07-14',
#  '2015-07-14',
#  '2015-07-14',
#  '2015-07-14',
#  '2015-07-14',
#  '2015-07-15',
#  '2015-07-15',
#  '2015-07-15',
#  '2015-07-15',
#  '2015-07-15',
#  '2015-07-16',
#  '2015-07-16',
#  '2015-07-16',
#  '2015-07-16',
#  '2015-07-16',
#  '2015-07-17',
#  '2015-07-17',
#  '2015-07-17',
#  '2015-07-17',
#  '2015-07-17',
#  '2015-07-20',
#  '2015-07-20',
#  '2015-07-20',
#  '2015-07-20',
#  '2015-07-20',
#  '2015-07-21',
#  '2015-07-21',
#  '2015-07-21',
#  '2015-07-21',
#  '2015-07-21',
#  '2015-07-22',
#  '2015-07-22',
#  '2015-07-22',
#  '2015-07-22',
#  '2015-07-22',
#  '2015-07-23',
#  '2015-07-23',
#  '2015-07-23',
#  '2015-07-23',
#  '2015-07-23',
#  '2015-07-24',
#  '2015-07-24',
#  '2015-07-24',
#  '2015-07-24',
#  '2015-07-24',
#  '2015-07-27',
#  '2015-07-27',
#  '2015-07-27',
#  '2015-07-27',
#  '2015-07-27',
#  '2015-07-28',
#  '2015-07-28',
#  '2015-07-28',
# ...

# %%
random_list_dates = random.choices(b, k=10)
random_list_dates
# Out:
# ['2016-04-05',
#  '2015-08-11',
#  '2016-08-11',
#  '2016-01-22',
#  '2016-01-29',
#  '2016-01-14',
#  '2016-02-09',
#  '2015-12-08',
#  '2015-12-14',
#  '2015-11-18']

# %%
tech_df2.xs(key='AAPL',level=1).sample(10)
# Out:
#             month  year  day    open   close    high     low    volume  \
# date
# 2015-12-02     12  2015    2  117.05  116.28  118.11  116.08  33386563
# 2015-11-06     11  2015    6  121.11  121.06  121.81  120.62  33042283
# 2015-09-28      9  2015   28  113.85  112.44  114.57  112.44  52109011
# 2015-07-23      7  2015   23  126.20  125.16  127.09  125.06  50999452
# 2016-06-16      6  2016   16   96.45   97.55   97.75   96.07  31326815
# 2016-06-03      6  2016    3   97.79   97.92   98.27   97.45  28504888
# 2015-12-21     12  2015   21  107.28  107.33  107.37  105.57  47590610
# 2016-03-10      3  2016   10  101.41  101.17  102.24  100.15  33513577
# 2015-07-14      7  2015   14  126.04  125.61  126.37  125.04  31768139
# 2016-04-19      4  2016   19  107.88  106.91  108.00  106.23  32384879
#
#            volume_type
# date
# 2015-12-02      medium
# 2015-11-06      medium
# 2015-09-28      medium
# 2015-07-23      medium
# 2016-06-16      medium
# 2016-06-03      medium
# ...

# %%
c = list(tech_df2.xs(key='AAPL',level=1).index)
random.choices(c, k=10)
# Out:
# ['2015-10-09',
#  '2016-04-05',
#  '2016-08-08',
#  '2015-07-23',
#  '2016-02-03',
#  '2015-09-16',
#  '2015-08-10',
#  '2015-07-21',
#  '2015-10-30',
#  '2016-01-29']

# %%
# another way:
tech_df2.loc[(slice(None),'AAPL'),:].sample(10)
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2016-07-25 AAPL      7  2016   25   98.25   97.34   98.84   96.92  40382921
# 2016-02-25 AAPL      2  2016   25   96.05   96.76   96.76   95.25  27582659
# 2016-05-10 AAPL      5  2016   10   93.33   93.42   93.57   92.11  33686836
# 2016-08-01 AAPL      8  2016    1  104.41  106.05  106.15  104.41  38167871
# 2015-09-04 AAPL      9  2015    4  108.97  109.27  110.45  108.51  49996311
# 2015-11-19 AAPL     11  2015   19  117.64  118.78  119.75  116.76  43295820
# 2016-08-17 AAPL      8  2016   17  109.10  109.22  109.37  108.34  25355976
# 2015-09-22 AAPL      9  2015   22  113.38  113.40  114.18  112.52  50346159
# 2015-10-09 AAPL     10  2015    9  110.00  112.12  112.28  109.49  52766140
# 2016-02-10 AAPL      2  2016   10   95.92   94.27   96.35   94.10  42343601
#
#                 volume_type
# date       name
# 2016-07-25 AAPL      medium
# 2016-02-25 AAPL      medium
# ...

# %%
# 3
tech_df2.loc[(slice(None),['AAPL','GOOGL']),'high':'low']
# Out:
#                     high     low
# date       name
# 2015-07-13 AAPL   125.76  124.32
# 2015-07-14 AAPL   126.37  125.04
# 2015-07-15 AAPL   127.15  125.58
# 2015-07-16 AAPL   128.57  127.35
# 2015-07-17 AAPL   129.62  128.31
# ...                  ...     ...
# 2016-08-11 GOOGL  813.88  806.00
# 2016-08-12 GOOGL  807.19  803.64
# 2016-08-15 GOOGL  811.36  804.03
# 2016-08-16 GOOGL  804.26  797.00
# 2016-08-17 GOOGL  805.63  796.30
#
# [558 rows x 2 columns]

# %% [markdown]
# # 180. - The anatomy of a multiindex object

# %%
tech.head(n=4)
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
#            AAPL          low
#            GOOGL      medium
#            MSFT       medium

# %%
type(tech)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tech.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
tech.index
# Out:
# MultiIndex([('2014-01-02',    'FB'),
#             ('2014-01-02',  'AAPL'),
#             ('2014-01-02', 'GOOGL'),
#             ('2014-01-02',  'MSFT'),
#             ('2014-01-02',  'AMZN'),
#             ('2014-01-03',    'FB'),
#             ('2014-01-03', 'GOOGL'),
#             ('2014-01-03',  'MSFT'),
#             ('2014-01-03',  'AAPL'),
#             ('2014-01-03',  'AMZN'),
#             ...
#             ('2019-08-22',  'MSFT'),
#             ('2019-08-22',    'FB'),
#             ('2019-08-22',  'AMZN'),
#             ('2019-08-22',  'AAPL'),
#             ('2019-08-22', 'GOOGL'),
#             ('2019-08-23',  'MSFT'),
#             ('2019-08-23',  'AAPL'),
#             ('2019-08-23', 'GOOGL'),
#             ('2019-08-23',  'AMZN'),
#             ('2019-08-23',    'FB')],
#            names=['date', 'name'], length=7105)

# %%
# names
tech.index.names
# Out:
# FrozenList(['date', 'name'])

# %%
# levels
tech.index.levels
# Out:
# FrozenList([['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07', '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13', '2014-01-14', '2014-01-15', '2014-01-16', '2014-01-17', '2014-01-21', '2014-01-22', '2014-01-23', '2014-01-24', '2014-01-27', '2014-01-28', '2014-01-29', '2014-01-30', '2014-01-31', '2014-02-03', '2014-02-04', '2014-02-05', '2014-02-06', '2014-02-07', '2014-02-10', '2014-02-11', '2014-02-12', '2014-02-13', '2014-02-14', '2014-02-18', '2014-02-19', '2014-02-20', '2014-02-21', '2014-02-24', '2014-02-25', '2014-02-26', '2014-02-27', '2014-02-28', '2014-03-03', '2014-03-04', '2014-03-05', '2014-03-06', '2014-03-07', '2014-03-10', '2014-03-11', '2014-03-12', '2014-03-13', '2014-03-14', '2014-03-17', '2014-03-18', '2014-03-19', '2014-03-20', '2014-03-21', '2014-03-24', '2014-03-25', '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-31', '2014-04-01', '2014-04-02', '2014-04-03', '2014-04-04', '2014-04-07', '2014-04-08', '2014-04-09', '2014-04-10', '2014-04-11', '2014
# ...

# %%
tech.index.nlevels
# Out:
# 2

# %%
tech.index.levels[0]
# Out:
# Index(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07', '2014-01-08',
#        '2014-01-09', '2014-01-10', '2014-01-13', '2014-01-14', '2014-01-15',
#        ...
#        '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15', '2019-08-16',
#        '2019-08-19', '2019-08-20', '2019-08-21', '2019-08-22', '2019-08-23'],
#       dtype='object', name='date', length=1421)

# %%
tech.index.levels[1]
# Out:
# Index(['AAPL', 'AMZN', 'FB', 'GOOGL', 'MSFT'], dtype='object', name='name')

# %%
# levshape
tech.index.levshape
# Out:
# (1421, 5)

# %%
tech.index.values
# Out:
# array([('2014-01-02', 'FB'), ('2014-01-02', 'AAPL'),
#        ('2014-01-02', 'GOOGL'), ..., ('2019-08-23', 'GOOGL'),
#        ('2019-08-23', 'AMZN'), ('2019-08-23', 'FB')], dtype=object)

# %%
tech.head()
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
#            AAPL          low
#            GOOGL      medium
#            MSFT       medium
#            AMZN       medium

# %% [markdown]
# # 181. Adding another level

# %%
tech.head()
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
#            AAPL          low
#            GOOGL      medium
#            MSFT       medium
#            AMZN       medium

# %%
tech.set_index('volume_type', append=True, inplace=True)

# %%
tech.index.nlevels
# Out:
# 3

# %%
tech.index.levels[2]
# Out:
# Index(['high', 'low', 'medium'], dtype='object', name='volume_type')

# %%
tech.index.levels[1]
# Out:
# Index(['AAPL', 'AMZN', 'FB', 'GOOGL', 'MSFT'], dtype='object', name='name')

# %%
tech.index.values
# Out:
# array([('2014-01-02', 'FB', 'medium'), ('2014-01-02', 'AAPL', 'low'),
#        ('2014-01-02', 'GOOGL', 'medium'), ...,
#        ('2019-08-23', 'GOOGL', 'medium'),
#        ('2019-08-23', 'AMZN', 'medium'), ('2019-08-23', 'FB', 'medium')],
#       dtype=object)

# %%
type(tech.index.values)
# Out:
# numpy.ndarray

# %%
tech.index
# Out:
# MultiIndex([('2014-01-02',    'FB', 'medium'),
#             ('2014-01-02',  'AAPL',    'low'),
#             ('2014-01-02', 'GOOGL', 'medium'),
#             ('2014-01-02',  'MSFT', 'medium'),
#             ('2014-01-02',  'AMZN', 'medium'),
#             ('2014-01-03',    'FB', 'medium'),
#             ('2014-01-03', 'GOOGL', 'medium'),
#             ('2014-01-03',  'MSFT', 'medium'),
#             ('2014-01-03',  'AAPL',    'low'),
#             ('2014-01-03',  'AMZN', 'medium'),
#             ...
#             ('2019-08-22',  'MSFT', 'medium'),
#             ('2019-08-22',    'FB',    'low'),
#             ('2019-08-22',  'AMZN', 'medium'),
#             ('2019-08-22',  'AAPL', 'medium'),
#             ('2019-08-22', 'GOOGL',    'low'),
#             ('2019-08-23',  'MSFT', 'medium'),
#             ('2019-08-23',  'AAPL', 'medium'),
#             ('2019-08-23', 'GOOGL', 'medium'),
#             ('2019-08-23',  'AMZN', 'medium'),
#             ('2019-08-23',    'FB', 'medium')],
# ...

# %%
type(tech.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
# jan 2019 high-vloume trading days
tech.loc[(slice('2019-01-01','2019-01-31'),slice(None),'high'),:]
# Out:
#                              month  year  day     open    close     high  \
# date       name volume_type
# 2019-01-03 AAPL high             1  2019    3   143.98   142.19   145.72
# 2019-01-04 AMZN high             1  2019    4  1530.00  1575.39  1594.00
# 2019-01-08 AMZN high             1  2019    8  1664.69  1656.58  1676.61
# 2019-01-31 AMZN high             1  2019   31  1692.85  1718.73  1736.41
#            FB   high             1  2019   31   165.60   166.69   171.68
#
#                                  low    volume
# date       name volume_type
# 2019-01-03 AAPL high          142.00  91312195
# 2019-01-04 AMZN high         1518.31   9182575
# 2019-01-08 AMZN high         1616.61   8881428
# 2019-01-31 AMZN high         1679.08  10910338
#            FB   high          165.00  77233602

# %%
# all high volume trading days
tech.loc[(slice(None),slice(None),'high'),:]
# Out:
#                               month  year  day     open    close     high  \
# date       name  volume_type
# 2014-01-06 FB    high             1  2014    6    54.39    57.20    57.26
# 2014-01-07 FB    high             1  2014    7    57.67    57.92    58.55
# 2014-01-08 FB    high             1  2014    8    57.59    58.23    58.41
# 2014-01-09 FB    high             1  2014    9    58.66    57.22    58.96
# 2014-01-13 FB    high             1  2014   13    57.89    55.91    58.25
# ...                             ...   ...  ...      ...      ...      ...
# 2019-04-30 GOOGL high             4  2019   30  1190.63  1198.96  1200.98
# 2019-06-03 FB    high             6  2019    3   175.00   164.15   175.05
#            AMZN  high             6  2019    3  1760.01  1692.69  1766.29
#            GOOGL high             6  2019    3  1066.93  1038.74  1067.00
# 2019-07-26 GOOGL high             7  2019   26  1228.00  1245.22  1268.39
#
#                                   low    volume
# ...

# %%
tech.xs(level=2,key='high')
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-06 FB         1  2014    6    54.39    57.20    57.26    54.05
# 2014-01-07 FB         1  2014    7    57.67    57.92    58.55    57.22
# 2014-01-08 FB         1  2014    8    57.59    58.23    58.41    57.23
# 2014-01-09 FB         1  2014    9    58.66    57.22    58.96    56.65
# 2014-01-13 FB         1  2014   13    57.89    55.91    58.25    55.38
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-04-30 GOOGL      4  2019   30  1190.63  1198.96  1200.98  1183.00
# 2019-06-03 FB         6  2019    3   175.00   164.15   175.05   161.01
#            AMZN       6  2019    3  1760.01  1692.69  1766.29  1672.00
#            GOOGL      6  2019    3  1066.93  1038.74  1067.00  1027.03
# 2019-07-26 GOOGL      7  2019   26  1228.00  1245.22  1268.39  1228.00
#
#                     volume
# date       name
# 2014-01-06 FB     68974359
# ...

# %%
test_slice = slice(None)
tech.loc[(test_slice,test_slice,'low'),:]
# Out:
#                               month  year  day     open    close     high  \
# date       name  volume_type
# 2014-01-02 AAPL  low              1  2014    2    79.38    79.02    79.58
# 2014-01-03 AAPL  low              1  2014    3    79.00    77.28    79.10
# 2014-01-06 AAPL  low              1  2014    6    76.78    77.70    78.11
# 2014-01-07 AAPL  low              1  2014    7    77.76    77.15    77.99
#            AMZN  low              1  2014    7   395.04   398.03   398.47
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-21 GOOGL low              8  2019   21  1195.82  1191.58  1200.56
#            FB    low              8  2019   21   185.00   183.55   185.90
#            AMZN  low              8  2019   21  1819.39  1823.54  1829.58
# 2019-08-22 FB    low              8  2019   22   183.43   182.04   184.11
#            GOOGL low              8  2019   22  1193.80  1191.52  1198.78
#
#                                   low    volume
# ...

# %%
tech.xs(level=(2,1),key=('high','FB'))
# Out:
#             month  year  day    open   close    high     low    volume
# date
# 2014-01-06      1  2014    6   54.39   57.20   57.26   54.05  68974359
# 2014-01-07      1  2014    7   57.67   57.92   58.55   57.22  77329009
# 2014-01-08      1  2014    8   57.59   58.23   58.41   57.23  56800776
# 2014-01-09      1  2014    9   58.66   57.22   58.96   56.65  92349222
# 2014-01-13      1  2014   13   57.89   55.91   58.25   55.38  63106519
# ...           ...   ...  ...     ...     ...     ...     ...       ...
# 2018-10-31     10  2018   31  155.00  151.79  156.40  148.96  60101251
# 2018-12-19     12  2018   19  141.21  133.24  144.91  132.50  57404894
# 2018-12-21     12  2018   21  133.39  124.95  134.90  123.42  56901491
# 2019-01-31      1  2019   31  165.60  166.69  171.68  165.00  77233602
# 2019-06-03      6  2019    3  175.00  164.15  175.05  161.01  56059609
#
# [115 rows x 8 columns]

# %% [markdown]
# # 182. Shuffing levels.

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       name  volume_type
# 2014-01-02 FB    medium           1  2014    2   54.86   54.71   55.22
#            AAPL  low              1  2014    2   79.38   79.02   79.58
#            GOOGL medium           1  2014    2  557.73  556.56  558.88
#            MSFT  medium           1  2014    2   37.35   37.16   37.40
#            AMZN  medium           1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       name  volume_type
# 2014-01-02 FB    medium        54.19  43257622
#            AAPL  low           78.86   8398851
#            GOOGL medium       554.13   1822719
#            MSFT  medium        37.10  30643745
#            AMZN  medium       394.02   2140246

# %%
tech.sort_index()
# Out:
#                               month  year  day     open    close     high  \
# date       name  volume_type
# 2014-01-02 AAPL  low              1  2014    2    79.38    79.02    79.58
#            AMZN  medium           1  2014    2   398.80   397.97   399.36
#            FB    medium           1  2014    2    54.86    54.71    55.22
#            GOOGL medium           1  2014    2   557.73   556.56   558.88
#            MSFT  medium           1  2014    2    37.35    37.16    37.40
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 AAPL  medium           8  2019   23   209.43   202.64   212.05
#            AMZN  medium           8  2019   23  1793.03  1749.62  1804.90
#            FB    medium           8  2019   23   180.84   177.75   183.13
#            GOOGL medium           8  2019   23  1185.17  1153.58  1195.67
#            MSFT  medium           8  2019   23   137.19   133.39   138.35
#
#                                   low    volume
# ...

# %%
tech.swaplevel(2,1)
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2    54.86    54.71    55.22
#            low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#                        AMZN       1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 medium      MSFT       8  2019   23   137.19   133.39   138.35
#                        AAPL       8  2019   23   209.43   202.64   212.05
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech.swaplevel(0,2)
# Out:
#                               month  year  day     open    close     high  \
# volume_type name  date
# medium      FB    2014-01-02      1  2014    2    54.86    54.71    55.22
# low         AAPL  2014-01-02      1  2014    2    79.38    79.02    79.58
# medium      GOOGL 2014-01-02      1  2014    2   557.73   556.56   558.88
#             MSFT  2014-01-02      1  2014    2    37.35    37.16    37.40
#             AMZN  2014-01-02      1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
#             MSFT  2019-08-23      8  2019   23   137.19   133.39   138.35
#             AAPL  2019-08-23      8  2019   23   209.43   202.64   212.05
#             GOOGL 2019-08-23      8  2019   23  1185.17  1153.58  1195.67
#             AMZN  2019-08-23      8  2019   23  1793.03  1749.62  1804.90
#             FB    2019-08-23      8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech.swaplevel(i=2,j=0)
# Out:
#                               month  year  day     open    close     high  \
# volume_type name  date
# medium      FB    2014-01-02      1  2014    2    54.86    54.71    55.22
# low         AAPL  2014-01-02      1  2014    2    79.38    79.02    79.58
# medium      GOOGL 2014-01-02      1  2014    2   557.73   556.56   558.88
#             MSFT  2014-01-02      1  2014    2    37.35    37.16    37.40
#             AMZN  2014-01-02      1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
#             MSFT  2019-08-23      8  2019   23   137.19   133.39   138.35
#             AAPL  2019-08-23      8  2019   23   209.43   202.64   212.05
#             GOOGL 2019-08-23      8  2019   23  1185.17  1153.58  1195.67
#             AMZN  2019-08-23      8  2019   23  1793.03  1749.62  1804.90
#             FB    2019-08-23      8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       name  volume_type
# 2014-01-02 FB    medium           1  2014    2   54.86   54.71   55.22
#            AAPL  low              1  2014    2   79.38   79.02   79.58
#            GOOGL medium           1  2014    2  557.73  556.56  558.88
#            MSFT  medium           1  2014    2   37.35   37.16   37.40
#            AMZN  medium           1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       name  volume_type
# 2014-01-02 FB    medium        54.19  43257622
#            AAPL  low           78.86   8398851
#            GOOGL medium       554.13   1822719
#            MSFT  medium        37.10  30643745
#            AMZN  medium       394.02   2140246

# %%
tech.swaplevel(j='date', i='volume_type')
# Out:
#                               month  year  day     open    close     high  \
# volume_type name  date
# medium      FB    2014-01-02      1  2014    2    54.86    54.71    55.22
# low         AAPL  2014-01-02      1  2014    2    79.38    79.02    79.58
# medium      GOOGL 2014-01-02      1  2014    2   557.73   556.56   558.88
#             MSFT  2014-01-02      1  2014    2    37.35    37.16    37.40
#             AMZN  2014-01-02      1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
#             MSFT  2019-08-23      8  2019   23   137.19   133.39   138.35
#             AAPL  2019-08-23      8  2019   23   209.43   202.64   212.05
#             GOOGL 2019-08-23      8  2019   23  1185.17  1153.58  1195.67
#             AMZN  2019-08-23      8  2019   23  1793.03  1749.62  1804.90
#             FB    2019-08-23      8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       name  volume_type
# 2014-01-02 FB    medium           1  2014    2   54.86   54.71   55.22
#            AAPL  low              1  2014    2   79.38   79.02   79.58
#            GOOGL medium           1  2014    2  557.73  556.56  558.88
#            MSFT  medium           1  2014    2   37.35   37.16   37.40
#            AMZN  medium           1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       name  volume_type
# 2014-01-02 FB    medium        54.19  43257622
#            AAPL  low           78.86   8398851
#            GOOGL medium       554.13   1822719
#            MSFT  medium        37.10  30643745
#            AMZN  medium       394.02   2140246

# %%
tech = tech.swaplevel('volume_type','name')

# %%
tech.head(n=2)
# Out:
#                              month  year  day   open  close   high    low  \
# date       volume_type name
# 2014-01-02 medium      FB        1  2014    2  54.86  54.71  55.22  54.19
#            low         AAPL      1  2014    2  79.38  79.02  79.58  78.86
#
#                                volume
# date       volume_type name
# 2014-01-02 medium      FB    43257622
#            low         AAPL   8398851

# %%
# the aleenative: teh reorder_levels()
tech.reorder_levels([2,0,1])
# Out:
#                               month  year  day     open    close     high  \
# name  date       volume_type
# FB    2014-01-02 medium           1  2014    2    54.86    54.71    55.22
# AAPL  2014-01-02 low              1  2014    2    79.38    79.02    79.58
# GOOGL 2014-01-02 medium           1  2014    2   557.73   556.56   558.88
# MSFT  2014-01-02 medium           1  2014    2    37.35    37.16    37.40
# AMZN  2014-01-02 medium           1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# MSFT  2019-08-23 medium           8  2019   23   137.19   133.39   138.35
# AAPL  2019-08-23 medium           8  2019   23   209.43   202.64   212.05
# GOOGL 2019-08-23 medium           8  2019   23  1185.17  1153.58  1195.67
# AMZN  2019-08-23 medium           8  2019   23  1793.03  1749.62  1804.90
# FB    2019-08-23 medium           8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech.reorder_levels([2,1,0])
# Out:
#                               month  year  day     open    close     high  \
# name  volume_type date
# FB    medium      2014-01-02      1  2014    2    54.86    54.71    55.22
# AAPL  low         2014-01-02      1  2014    2    79.38    79.02    79.58
# GOOGL medium      2014-01-02      1  2014    2   557.73   556.56   558.88
# MSFT  medium      2014-01-02      1  2014    2    37.35    37.16    37.40
# AMZN  medium      2014-01-02      1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# MSFT  medium      2019-08-23      8  2019   23   137.19   133.39   138.35
# AAPL  medium      2019-08-23      8  2019   23   209.43   202.64   212.05
# GOOGL medium      2019-08-23      8  2019   23  1185.17  1153.58  1195.67
# AMZN  medium      2019-08-23      8  2019   23  1793.03  1749.62  1804.90
# FB    medium      2019-08-23      8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech.index.reorder_levels([2,0,1])
# Out:
# MultiIndex([(   'FB', '2014-01-02', 'medium'),
#             ( 'AAPL', '2014-01-02',    'low'),
#             ('GOOGL', '2014-01-02', 'medium'),
#             ( 'MSFT', '2014-01-02', 'medium'),
#             ( 'AMZN', '2014-01-02', 'medium'),
#             (   'FB', '2014-01-03', 'medium'),
#             ('GOOGL', '2014-01-03', 'medium'),
#             ( 'MSFT', '2014-01-03', 'medium'),
#             ( 'AAPL', '2014-01-03',    'low'),
#             ( 'AMZN', '2014-01-03', 'medium'),
#             ...
#             ( 'MSFT', '2019-08-22', 'medium'),
#             (   'FB', '2019-08-22',    'low'),
#             ( 'AMZN', '2019-08-22', 'medium'),
#             ( 'AAPL', '2019-08-22', 'medium'),
#             ('GOOGL', '2019-08-22',    'low'),
#             ( 'MSFT', '2019-08-23', 'medium'),
#             ( 'AAPL', '2019-08-23', 'medium'),
#             ('GOOGL', '2019-08-23', 'medium'),
#             ( 'AMZN', '2019-08-23', 'medium'),
#             (   'FB', '2019-08-23', 'medium')],
# ...

# %% [markdown]
# # 183. Removing Multiindex levels

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2   54.86   54.71   55.22
#            low         AAPL       1  2014    2   79.38   79.02   79.58
#            medium      GOOGL      1  2014    2  557.73  556.56  558.88
#                        MSFT       1  2014    2   37.35   37.16   37.40
#                        AMZN       1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       volume_type name
# 2014-01-02 medium      FB      54.19  43257622
#            low         AAPL    78.86   8398851
#            medium      GOOGL  554.13   1822719
#                        MSFT    37.10  30643745
#                        AMZN   394.02   2140246

# %%
tech.droplevel(1)
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume
# date       name
# 2014-01-02 FB     43257622
# ...

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2   54.86   54.71   55.22
#            low         AAPL       1  2014    2   79.38   79.02   79.58
#            medium      GOOGL      1  2014    2  557.73  556.56  558.88
#                        MSFT       1  2014    2   37.35   37.16   37.40
#                        AMZN       1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       volume_type name
# 2014-01-02 medium      FB      54.19  43257622
#            low         AAPL    78.86   8398851
#            medium      GOOGL  554.13   1822719
#                        MSFT    37.10  30643745
#                        AMZN   394.02   2140246

# %%
tech.reset_index(level=1,drop=False)
# Out:
#                  volume_type  month  year  day     open    close     high  \
# date       name
# 2014-01-02 FB         medium      1  2014    2    54.86    54.71    55.22
#            AAPL          low      1  2014    2    79.38    79.02    79.58
#            GOOGL      medium      1  2014    2   557.73   556.56   558.88
#            MSFT       medium      1  2014    2    37.35    37.16    37.40
#            AMZN       medium      1  2014    2   398.80   397.97   399.36
# ...                      ...    ...   ...  ...      ...      ...      ...
# 2019-08-23 MSFT       medium      8  2019   23   137.19   133.39   138.35
#            AAPL       medium      8  2019   23   209.43   202.64   212.05
#            GOOGL      medium      8  2019   23  1185.17  1153.58  1195.67
#            AMZN       medium      8  2019   23  1793.03  1749.62  1804.90
#            FB         medium      8  2019   23   180.84   177.75   183.13
#
#                       low    volume
# date       name
# ...

# %%
tech.reset_index(level=1, drop=False)
# Out:
#                  volume_type  month  year  day     open    close     high  \
# date       name
# 2014-01-02 FB         medium      1  2014    2    54.86    54.71    55.22
#            AAPL          low      1  2014    2    79.38    79.02    79.58
#            GOOGL      medium      1  2014    2   557.73   556.56   558.88
#            MSFT       medium      1  2014    2    37.35    37.16    37.40
#            AMZN       medium      1  2014    2   398.80   397.97   399.36
# ...                      ...    ...   ...  ...      ...      ...      ...
# 2019-08-23 MSFT       medium      8  2019   23   137.19   133.39   138.35
#            AAPL       medium      8  2019   23   209.43   202.64   212.05
#            GOOGL      medium      8  2019   23  1185.17  1153.58  1195.67
#            AMZN       medium      8  2019   23  1793.03  1749.62  1804.90
#            FB         medium      8  2019   23   180.84   177.75   183.13
#
#                       low    volume
# date       name
# ...

# %%
tech.reset_index(level=1, drop=True)
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume
# date       name
# 2014-01-02 FB     43257622
# ...

# %%
# how about removing several levels at once?
tech.reset_index(level=['date','name'], drop=False)
# Out:
#                    date   name  month  year  day     open    close     high  \
# volume_type
# medium       2014-01-02     FB      1  2014    2    54.86    54.71    55.22
# low          2014-01-02   AAPL      1  2014    2    79.38    79.02    79.58
# medium       2014-01-02  GOOGL      1  2014    2   557.73   556.56   558.88
# medium       2014-01-02   MSFT      1  2014    2    37.35    37.16    37.40
# medium       2014-01-02   AMZN      1  2014    2   398.80   397.97   399.36
# ...                 ...    ...    ...   ...  ...      ...      ...      ...
# medium       2019-08-23   MSFT      8  2019   23   137.19   133.39   138.35
# medium       2019-08-23   AAPL      8  2019   23   209.43   202.64   212.05
# medium       2019-08-23  GOOGL      8  2019   23  1185.17  1153.58  1195.67
# medium       2019-08-23   AMZN      8  2019   23  1793.03  1749.62  1804.90
# medium       2019-08-23     FB      8  2019   23   180.84   177.75   183.13
#
#                  low    volume
# ...

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2   54.86   54.71   55.22
#            low         AAPL       1  2014    2   79.38   79.02   79.58
#            medium      GOOGL      1  2014    2  557.73  556.56  558.88
#                        MSFT       1  2014    2   37.35   37.16   37.40
#                        AMZN       1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       volume_type name
# 2014-01-02 medium      FB      54.19  43257622
#            low         AAPL    78.86   8398851
#            medium      GOOGL  554.13   1822719
#                        MSFT    37.10  30643745
#                        AMZN   394.02   2140246

# %%
tech.droplevel(['name','volume_type'])
# Out:
#             month  year  day     open    close     high      low    volume
# date
# 2014-01-02      1  2014    2    54.86    54.71    55.22    54.19  43257622
# 2014-01-02      1  2014    2    79.38    79.02    79.58    78.86   8398851
# 2014-01-02      1  2014    2   557.73   556.56   558.88   554.13   1822719
# 2014-01-02      1  2014    2    37.35    37.16    37.40    37.10  30643745
# 2014-01-02      1  2014    2   398.80   397.97   399.36   394.02   2140246
# ...           ...   ...  ...      ...      ...      ...      ...       ...
# 2019-08-23      8  2019   23   137.19   133.39   138.35   132.80  38515386
# 2019-08-23      8  2019   23   209.43   202.64   212.05   201.00  46882843
# 2019-08-23      8  2019   23  1185.17  1153.58  1195.67  1150.00   1813141
# 2019-08-23      8  2019   23  1793.03  1749.62  1804.90  1745.23   5277898
# 2019-08-23      8  2019   23   180.84   177.75   183.13   176.66  17331221
#
# [7105 rows x 8 columns]

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2   54.86   54.71   55.22
#            low         AAPL       1  2014    2   79.38   79.02   79.58
#            medium      GOOGL      1  2014    2  557.73  556.56  558.88
#                        MSFT       1  2014    2   37.35   37.16   37.40
#                        AMZN       1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       volume_type name
# 2014-01-02 medium      FB      54.19  43257622
#            low         AAPL    78.86   8398851
#            medium      GOOGL  554.13   1822719
#                        MSFT    37.10  30643745
#                        AMZN   394.02   2140246

# %%
tech.reset_index()
# Out:
#             date volume_type   name  month  year  day     open    close  \
# 0     2014-01-02      medium     FB      1  2014    2    54.86    54.71
# 1     2014-01-02         low   AAPL      1  2014    2    79.38    79.02
# 2     2014-01-02      medium  GOOGL      1  2014    2   557.73   556.56
# 3     2014-01-02      medium   MSFT      1  2014    2    37.35    37.16
# 4     2014-01-02      medium   AMZN      1  2014    2   398.80   397.97
# ...          ...         ...    ...    ...   ...  ...      ...      ...
# 7100  2019-08-23      medium   MSFT      8  2019   23   137.19   133.39
# 7101  2019-08-23      medium   AAPL      8  2019   23   209.43   202.64
# 7102  2019-08-23      medium  GOOGL      8  2019   23  1185.17  1153.58
# 7103  2019-08-23      medium   AMZN      8  2019   23  1793.03  1749.62
# 7104  2019-08-23      medium     FB      8  2019   23   180.84   177.75
#
#          high      low    volume
# 0       55.22    54.19  43257622
# 1       79.58    78.86   8398851
# ...

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2   54.86   54.71   55.22
#            low         AAPL       1  2014    2   79.38   79.02   79.58
#            medium      GOOGL      1  2014    2  557.73  556.56  558.88
#                        MSFT       1  2014    2   37.35   37.16   37.40
#                        AMZN       1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       volume_type name
# 2014-01-02 medium      FB      54.19  43257622
#            low         AAPL    78.86   8398851
#            medium      GOOGL  554.13   1822719
#                        MSFT    37.10  30643745
#                        AMZN   394.02   2140246

# %% [markdown]
# # 184. Multiindex sort_index()

# %%
tech.loc[(slice('2014-01-02','2014-04-02'),slice(None),'AAPL'),'open':'low']
# Out:
#                               open  close   high    low
# date       volume_type name
# 2014-01-02 low         AAPL  79.38  79.02  79.58  78.86
# 2014-01-03 low         AAPL  79.00  77.28  79.10  77.20
# 2014-01-06 low         AAPL  76.78  77.70  78.11  76.23
# 2014-01-07 low         AAPL  77.76  77.15  77.99  76.85
# 2014-01-08 low         AAPL  76.97  77.64  77.94  76.96
# ...                            ...    ...    ...    ...
# 2014-03-27 low         AAPL  77.11  76.78  77.36  76.45
# 2014-03-28 low         AAPL  76.82  76.69  76.99  76.32
# 2014-03-31 low         AAPL  77.03  76.68  77.26  76.56
# 2014-04-01 low         AAPL  76.84  77.38  77.41  76.68
# 2014-04-02 low         AAPL  77.48  77.51  77.64  77.18
#
# [63 rows x 4 columns]

# %%
# tech.loc[(slice('2014-01-02','2014-04-02'),slice(None),slice('AAPL','FB')),'open':'low']

# UnsortedIndexError: 'MultiIndex slicing requires the index to be lexsorted: slicing on levels [0, 2], lexsort depth 1'

# %%
tech.sort_index(inplace=True)

# %%
tech.loc[(slice('2014-01-02','2014-04-02'),slice(None),slice('AAPL','FB')),'open':'low']
# Out:
#                                open   close    high     low
# date       volume_type name
# 2014-01-02 low         AAPL   79.38   79.02   79.58   78.86
#            medium      AMZN  398.80  397.97  399.36  394.02
#                        FB     54.86   54.71   55.22   54.19
# 2014-01-03 low         AAPL   79.00   77.28   79.10   77.20
#            medium      AMZN  398.29  396.44  402.71  396.22
# ...                             ...     ...     ...     ...
# 2014-04-01 low         AAPL   76.84   77.38   77.41   76.68
#            medium      AMZN  338.35  342.99  344.43  338.00
# 2014-04-02 high        FB     63.24   62.72   63.91   62.21
#            low         AAPL   77.48   77.51   77.64   77.18
#            medium      AMZN  345.99  341.96  348.30  340.38
#
# [189 rows x 4 columns]

# %%
# sorting different levels in diffrent orders
tech.sort_index(level=[0,1,2],ascending=[False,False,True])
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2019-08-23 medium      AAPL       8  2019   23   209.43   202.64   212.05
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        MSFT       8  2019   23   137.19   133.39   138.35
# ...                             ...   ...  ...      ...      ...      ...
# 2014-01-02 medium      AMZN       1  2014    2   398.80   397.97   399.36
#                        FB         1  2014    2    54.86    54.71    55.22
#                        GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#            low         AAPL       1  2014    2    79.38    79.02    79.58
#
#                                   low    volume
# ...

# %% [markdown]
# # 185. More Multiindex methods

# %%
#### Coming up:
# - idx.is_lexsorted() --> tidx.is_monotonic_increasing
# - idx.sortlevel()
# - idx.set_names()
# - idx.to_flat_index()

# %%
tidx = tech.index

# %%
type(tidx)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
tidx.is_monotonic_increasing
# Out:
# True

# %%
tidx.sortlevel(0,ascending=False, sort_remaining=True)
# Out:
# (MultiIndex([('2019-08-23', 'medium',  'MSFT'),
#              ('2019-08-23', 'medium', 'GOOGL'),
#              ('2019-08-23', 'medium',    'FB'),
#              ('2019-08-23', 'medium',  'AMZN'),
#              ('2019-08-23', 'medium',  'AAPL'),
#              ('2019-08-22', 'medium',  'MSFT'),
#              ('2019-08-22', 'medium',  'AMZN'),
#              ('2019-08-22', 'medium',  'AAPL'),
#              ('2019-08-22',    'low', 'GOOGL'),
#              ('2019-08-22',    'low',    'FB'),
#              ...
#              ('2014-01-03', 'medium',  'MSFT'),
#              ('2014-01-03', 'medium', 'GOOGL'),
#              ('2014-01-03', 'medium',    'FB'),
#              ('2014-01-03', 'medium',  'AMZN'),
#              ('2014-01-03',    'low',  'AAPL'),
#              ('2014-01-02', 'medium',  'MSFT'),
#              ('2014-01-02', 'medium', 'GOOGL'),
#              ('2014-01-02', 'medium',    'FB'),
#              ('2014-01-02', 'medium',  'AMZN'),
# ...

# %%
tidx.sortlevel((0,1,2), ascending=[False,True,False])
# Out:
# (MultiIndex([('2019-08-23', 'medium',  'MSFT'),
#              ('2019-08-23', 'medium', 'GOOGL'),
#              ('2019-08-23', 'medium',    'FB'),
#              ('2019-08-23', 'medium',  'AMZN'),
#              ('2019-08-23', 'medium',  'AAPL'),
#              ('2019-08-22',    'low', 'GOOGL'),
#              ('2019-08-22',    'low',    'FB'),
#              ('2019-08-22', 'medium',  'MSFT'),
#              ('2019-08-22', 'medium',  'AMZN'),
#              ('2019-08-22', 'medium',  'AAPL'),
#              ...
#              ('2014-01-03',    'low',  'AAPL'),
#              ('2014-01-03', 'medium',  'MSFT'),
#              ('2014-01-03', 'medium', 'GOOGL'),
#              ('2014-01-03', 'medium',    'FB'),
#              ('2014-01-03', 'medium',  'AMZN'),
#              ('2014-01-02',    'low',  'AAPL'),
#              ('2014-01-02', 'medium',  'MSFT'),
#              ('2014-01-02', 'medium', 'GOOGL'),
#              ('2014-01-02', 'medium',    'FB'),
# ...

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       volume_type name
# 2014-01-02 low         AAPL       1  2014    2   79.38   79.02   79.58
#            medium      AMZN       1  2014    2  398.80  397.97  399.36
#                        FB         1  2014    2   54.86   54.71   55.22
#                        GOOGL      1  2014    2  557.73  556.56  558.88
#                        MSFT       1  2014    2   37.35   37.16   37.40
#
#                                  low    volume
# date       volume_type name
# 2014-01-02 low         AAPL    78.86   8398851
#            medium      AMZN   394.02   2140246
#                        FB      54.19  43257622
#                        GOOGL  554.13   1822719
#                        MSFT    37.10  30643745

# %%
tidx.set_names(['Treading Date','Volume Category','Ticker'], inplace=True)

# %%
tech.head()
# Out:
#                                       month  year  day    open   close  \
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL        1  2014    2   79.38   79.02
#               medium          AMZN        1  2014    2  398.80  397.97
#                               FB          1  2014    2   54.86   54.71
#                               GOOGL       1  2014    2  557.73  556.56
#                               MSFT        1  2014    2   37.35   37.16
#
#                                         high     low    volume
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL     79.58   78.86   8398851
#               medium          AMZN    399.36  394.02   2140246
#                               FB       55.22   54.19  43257622
#                               GOOGL   558.88  554.13   1822719
#                               MSFT     37.40   37.10  30643745

# %%
tech.head()
# Out:
#                                       month  year  day    open   close  \
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL        1  2014    2   79.38   79.02
#               medium          AMZN        1  2014    2  398.80  397.97
#                               FB          1  2014    2   54.86   54.71
#                               GOOGL       1  2014    2  557.73  556.56
#                               MSFT        1  2014    2   37.35   37.16
#
#                                         high     low    volume
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL     79.58   78.86   8398851
#               medium          AMZN    399.36  394.02   2140246
#                               FB       55.22   54.19  43257622
#                               GOOGL   558.88  554.13   1822719
#                               MSFT     37.40   37.10  30643745

# %%
tidx.to_flat_index()
# Out:
# Index([    ('2014-01-02', 'low', 'AAPL'),  ('2014-01-02', 'medium', 'AMZN'),
#           ('2014-01-02', 'medium', 'FB'), ('2014-01-02', 'medium', 'GOOGL'),
#         ('2014-01-02', 'medium', 'MSFT'),     ('2014-01-03', 'low', 'AAPL'),
#         ('2014-01-03', 'medium', 'AMZN'),    ('2014-01-03', 'medium', 'FB'),
#        ('2014-01-03', 'medium', 'GOOGL'),  ('2014-01-03', 'medium', 'MSFT'),
#        ...
#              ('2019-08-22', 'low', 'FB'),    ('2019-08-22', 'low', 'GOOGL'),
#         ('2019-08-22', 'medium', 'AAPL'),  ('2019-08-22', 'medium', 'AMZN'),
#         ('2019-08-22', 'medium', 'MSFT'),  ('2019-08-23', 'medium', 'AAPL'),
#         ('2019-08-23', 'medium', 'AMZN'),    ('2019-08-23', 'medium', 'FB'),
#        ('2019-08-23', 'medium', 'GOOGL'),  ('2019-08-23', 'medium', 'MSFT')],
#       dtype='object', length=7105)

# %%
tech.close
# Out:
# Treading Date  Volume Category  Ticker
# 2014-01-02     low              AAPL        79.02
#                medium           AMZN       397.97
#                                 FB          54.71
#                                 GOOGL      556.56
#                                 MSFT        37.16
#                                            ...
# 2019-08-23     medium           AAPL       202.64
#                                 AMZN      1749.62
#                                 FB         177.75
#                                 GOOGL     1153.58
#                                 MSFT       133.39
# Name: close, Length: 7105, dtype: float64

# %% [markdown]
# # 186. Reshaping with stack()

# %%
tech.head(10)
# Out:
#                                       month  year  day    open   close  \
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL        1  2014    2   79.38   79.02
#               medium          AMZN        1  2014    2  398.80  397.97
#                               FB          1  2014    2   54.86   54.71
#                               GOOGL       1  2014    2  557.73  556.56
#                               MSFT        1  2014    2   37.35   37.16
# 2014-01-03    low             AAPL        1  2014    3   79.00   77.28
#               medium          AMZN        1  2014    3  398.29  396.44
#                               FB          1  2014    3   55.00   54.56
#                               GOOGL       1  2014    3  557.50  552.50
#                               MSFT        1  2014    3   37.20   36.91
#
#                                         high     low    volume
# Treading Date Volume Category Ticker
# ...

# %%
tech.stack
# Out:
# <bound method DataFrame.stack of                                       month  year  day     open    close  \
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL        1  2014    2    79.38    79.02
#               medium          AMZN        1  2014    2   398.80   397.97
#                               FB          1  2014    2    54.86    54.71
#                               GOOGL       1  2014    2   557.73   556.56
#                               MSFT        1  2014    2    37.35    37.16
# ...                                     ...   ...  ...      ...      ...
# 2019-08-23    medium          AAPL        8  2019   23   209.43   202.64
#                               AMZN        8  2019   23  1793.03  1749.62
#                               FB          8  2019   23   180.84   177.75
#                               GOOGL       8  2019   23  1185.17  1153.58
#                               MSFT        8  2019   23   137.19   133.39
#
# ...

# %%
stacked = tech.stack()

# %%
stacked.head(10)
# Out:
# Treading Date  Volume Category  Ticker
# 2014-01-02     low              AAPL    month           1.00
#                                         year         2014.00
#                                         day             2.00
#                                         open           79.38
#                                         close          79.02
#                                         high           79.58
#                                         low            78.86
#                                         volume    8398851.00
#                medium           AMZN    month           1.00
#                                         year         2014.00
# dtype: float64

# %%
type(stacked)
# Out:
# pandas.core.series.Series

# %%
stacked.index
# Out:
# MultiIndex([('2014-01-02',    'low',  'AAPL',  'month'),
#             ('2014-01-02',    'low',  'AAPL',   'year'),
#             ('2014-01-02',    'low',  'AAPL',    'day'),
#             ('2014-01-02',    'low',  'AAPL',   'open'),
#             ('2014-01-02',    'low',  'AAPL',  'close'),
#             ('2014-01-02',    'low',  'AAPL',   'high'),
#             ('2014-01-02',    'low',  'AAPL',    'low'),
#             ('2014-01-02',    'low',  'AAPL', 'volume'),
#             ('2014-01-02', 'medium',  'AMZN',  'month'),
#             ('2014-01-02', 'medium',  'AMZN',   'year'),
#             ...
#             ('2019-08-23', 'medium', 'GOOGL',    'low'),
#             ('2019-08-23', 'medium', 'GOOGL', 'volume'),
#             ('2019-08-23', 'medium',  'MSFT',  'month'),
#             ('2019-08-23', 'medium',  'MSFT',   'year'),
#             ('2019-08-23', 'medium',  'MSFT',    'day'),
#             ('2019-08-23', 'medium',  'MSFT',   'open'),
# ...

# %%
type(stacked)
# Out:
# pandas.core.series.Series

# %%
stacked.index.levels
# Out:
# FrozenList([['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07', '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13', '2014-01-14', '2014-01-15', '2014-01-16', '2014-01-17', '2014-01-21', '2014-01-22', '2014-01-23', '2014-01-24', '2014-01-27', '2014-01-28', '2014-01-29', '2014-01-30', '2014-01-31', '2014-02-03', '2014-02-04', '2014-02-05', '2014-02-06', '2014-02-07', '2014-02-10', '2014-02-11', '2014-02-12', '2014-02-13', '2014-02-14', '2014-02-18', '2014-02-19', '2014-02-20', '2014-02-21', '2014-02-24', '2014-02-25', '2014-02-26', '2014-02-27', '2014-02-28', '2014-03-03', '2014-03-04', '2014-03-05', '2014-03-06', '2014-03-07', '2014-03-10', '2014-03-11', '2014-03-12', '2014-03-13', '2014-03-14', '2014-03-17', '2014-03-18', '2014-03-19', '2014-03-20', '2014-03-21', '2014-03-24', '2014-03-25', '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-31', '2014-04-01', '2014-04-02', '2014-04-03', '2014-04-04', '2014-04-07', '2014-04-08', '2014-04-09', '2014-04-10', '2014-04-11', '2014
# ...

# %%
stacked.index.nlevels
# Out:
# 4

# %%
tech.index.nlevels
# Out:
# 3

# %%
stacked.index.names
# Out:
# FrozenList(['Treading Date', 'Volume Category', 'Ticker', None])

# %%
names = stacked.index.names

# %%
stacked.index.set_names([*names[:-1],'Previously a column axis'], inplace=True)

# %%
stacked.index.names
# Out:
# FrozenList(['Treading Date', 'Volume Category', 'Ticker', 'Previously a column axis'])

# %%
stacked.head()
# Out:
# Treading Date  Volume Category  Ticker  Previously a column axis
# 2014-01-02     low              AAPL    month                          1.00
#                                         year                        2014.00
#                                         day                            2.00
#                                         open                          79.38
#                                         close                         79.02
# dtype: float64

# %%
stacked.shape
# Out:
# (56840,)

# %%
tech.head()
# Out:
#                                       month  year  day    open   close  \
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL        1  2014    2   79.38   79.02
#               medium          AMZN        1  2014    2  398.80  397.97
#                               FB          1  2014    2   54.86   54.71
#                               GOOGL       1  2014    2  557.73  556.56
#                               MSFT        1  2014    2   37.35   37.16
#
#                                         high     low    volume
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL     79.58   78.86   8398851
#               medium          AMZN    399.36  394.02   2140246
#                               FB       55.22   54.19  43257622
#                               GOOGL   558.88  554.13   1822719
#                               MSFT     37.40   37.10  30643745

# %% [markdown]
# # 187. The flipside: unstack()

# %%
tech.head()
# Out:
#                                       month  year  day    open   close  \
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL        1  2014    2   79.38   79.02
#               medium          AMZN        1  2014    2  398.80  397.97
#                               FB          1  2014    2   54.86   54.71
#                               GOOGL       1  2014    2  557.73  556.56
#                               MSFT        1  2014    2   37.35   37.16
#
#                                         high     low    volume
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL     79.58   78.86   8398851
#               medium          AMZN    399.36  394.02   2140246
#                               FB       55.22   54.19  43257622
#                               GOOGL   558.88  554.13   1822719
#                               MSFT     37.40   37.10  30643745

# %%
stacked.index.nlevels
# Out:
# 4

# %%
stacked
# Out:
# Treading Date  Volume Category  Ticker  Previously a column axis
# 2014-01-02     low              AAPL    month                              1.00
#                                         year                            2014.00
#                                         day                                2.00
#                                         open                              79.38
#                                         close                             79.02
#                                                                        ...
# 2019-08-23     medium           MSFT    open                             137.19
#                                         close                            133.39
#                                         high                             138.35
#                                         low                              132.80
#                                         volume                      38515386.00
# Length: 56840, dtype: float64

# %%
stacked.unstack()
# Out:
# Previously a column axis              month    year   day     open    close  \
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL      1.0  2014.0   2.0    79.38    79.02
#               medium          AMZN      1.0  2014.0   2.0   398.80   397.97
#                               FB        1.0  2014.0   2.0    54.86    54.71
#                               GOOGL     1.0  2014.0   2.0   557.73   556.56
#                               MSFT      1.0  2014.0   2.0    37.35    37.16
# ...                                     ...     ...   ...      ...      ...
# 2019-08-23    medium          AAPL      8.0  2019.0  23.0   209.43   202.64
#                               AMZN      8.0  2019.0  23.0  1793.03  1749.62
#                               FB        8.0  2019.0  23.0   180.84   177.75
#                               GOOGL     8.0  2019.0  23.0  1185.17  1153.58
#                               MSFT      8.0  2019.0  23.0   137.19   133.39
#
# ...

# %%
unstacked = stacked.unstack()

# %%
unstacked.reorder_levels([1,2,0])
# Out:
# Previously a column axis              month    year   day     open    close  \
# Volume Category Ticker Treading Date
# low             AAPL   2014-01-02       1.0  2014.0   2.0    79.38    79.02
# medium          AMZN   2014-01-02       1.0  2014.0   2.0   398.80   397.97
#                 FB     2014-01-02       1.0  2014.0   2.0    54.86    54.71
#                 GOOGL  2014-01-02       1.0  2014.0   2.0   557.73   556.56
#                 MSFT   2014-01-02       1.0  2014.0   2.0    37.35    37.16
# ...                                     ...     ...   ...      ...      ...
#                 AAPL   2019-08-23       8.0  2019.0  23.0   209.43   202.64
#                 AMZN   2019-08-23       8.0  2019.0  23.0  1793.03  1749.62
#                 FB     2019-08-23       8.0  2019.0  23.0   180.84   177.75
#                 GOOGL  2019-08-23       8.0  2019.0  23.0  1185.17  1153.58
#                 MSFT   2019-08-23       8.0  2019.0  23.0   137.19   133.39
#
# ...

# %%
stacked.unstack().unstack()
# Out:
# Previously a column axis      month                         year          \
# Ticker                         AAPL AMZN   FB GOOGL MSFT    AAPL    AMZN
# Treading Date Volume Category
# 2014-01-02    low               1.0  NaN  NaN   NaN  NaN  2014.0     NaN
#               medium            NaN  1.0  1.0   1.0  1.0     NaN  2014.0
# 2014-01-03    low               1.0  NaN  NaN   NaN  NaN  2014.0     NaN
#               medium            NaN  1.0  1.0   1.0  1.0     NaN  2014.0
# 2014-01-06    high              NaN  NaN  1.0   NaN  NaN     NaN     NaN
# ...                             ...  ...  ...   ...  ...     ...     ...
# 2019-08-21    low               NaN  8.0  8.0   8.0  8.0     NaN  2019.0
#               medium            8.0  NaN  NaN   NaN  NaN  2019.0     NaN
# 2019-08-22    low               NaN  NaN  8.0   8.0  NaN     NaN     NaN
#               medium            8.0  8.0  NaN   NaN  8.0  2019.0  2019.0
# ...

# %%
stacked.unstack().unstack(fill_value='-')
# Out:
# Previously a column axis      month                         year          \
# Ticker                         AAPL AMZN   FB GOOGL MSFT    AAPL    AMZN
# Treading Date Volume Category
# 2014-01-02    low               1.0    -    -     -    -  2014.0       -
#               medium              -  1.0  1.0   1.0  1.0       -  2014.0
# 2014-01-03    low               1.0    -    -     -    -  2014.0       -
#               medium              -  1.0  1.0   1.0  1.0       -  2014.0
# 2014-01-06    high                -    -  1.0     -    -       -       -
# ...                             ...  ...  ...   ...  ...     ...     ...
# 2019-08-21    low                 -  8.0  8.0   8.0  8.0       -  2019.0
#               medium            8.0    -    -     -    -  2019.0       -
# 2019-08-22    low                 -    -  8.0   8.0    -       -       -
#               medium            8.0  8.0    -     -  8.0  2019.0  2019.0
# ...

# %%
stacked.unstack()
# Out:
# Previously a column axis              month    year   day     open    close  \
# Treading Date Volume Category Ticker
# 2014-01-02    low             AAPL      1.0  2014.0   2.0    79.38    79.02
#               medium          AMZN      1.0  2014.0   2.0   398.80   397.97
#                               FB        1.0  2014.0   2.0    54.86    54.71
#                               GOOGL     1.0  2014.0   2.0   557.73   556.56
#                               MSFT      1.0  2014.0   2.0    37.35    37.16
# ...                                     ...     ...   ...      ...      ...
# 2019-08-23    medium          AAPL      8.0  2019.0  23.0   209.43   202.64
#                               AMZN      8.0  2019.0  23.0  1793.03  1749.62
#                               FB        8.0  2019.0  23.0   180.84   177.75
#                               GOOGL     8.0  2019.0  23.0  1185.17  1153.58
#                               MSFT      8.0  2019.0  23.0   137.19   133.39
#
# ...

# %%
stacked
# Out:
# Treading Date  Volume Category  Ticker  Previously a column axis
# 2014-01-02     low              AAPL    month                              1.00
#                                         year                            2014.00
#                                         day                                2.00
#                                         open                              79.38
#                                         close                             79.02
#                                                                        ...
# 2019-08-23     medium           MSFT    open                             137.19
#                                         close                            133.39
#                                         high                             138.35
#                                         low                              132.80
#                                         volume                      38515386.00
# Length: 56840, dtype: float64

# %%
stacked.unstack(level=1, fill_value='-')
# Out:
# Volume Category                               high     low      medium
# Treading Date Ticker Previously a column axis
# 2014-01-02    AAPL   month                       -     1.0           -
#                      year                        -  2014.0           -
#                      day                         -     2.0           -
#                      open                        -   79.38           -
#                      close                       -   79.02           -
# ...                                            ...     ...         ...
# 2019-08-23    MSFT   open                        -       -      137.19
#                      close                       -       -      133.39
#                      high                        -       -      138.35
#                      low                         -       -       132.8
#                      volume                      -       -  38515386.0
#
# [56840 rows x 3 columns]

# %%
stacked.unstack(level='Ticker', fill_value='-')
# Out:
# Ticker                                                        AAPL       AMZN  \
# Treading Date Volume Category Previously a column axis
# 2014-01-02    low             month                            1.0          -
#                               year                          2014.0          -
#                               day                              2.0          -
#                               open                           79.38          -
#                               close                          79.02          -
# ...                                                            ...        ...
# 2019-08-23    medium          open                          209.43    1793.03
#                               close                         202.64    1749.62
#                               high                          212.05     1804.9
#                               low                            201.0    1745.23
# ...

# %% [markdown]
# # 188. Bonus: Creating Multilevel columns manually

# %%
stacked.head()
# Out:
# Treading Date  Volume Category  Ticker  Previously a column axis
# 2014-01-02     low              AAPL    month                          1.00
#                                         year                        2014.00
#                                         day                            2.00
#                                         open                          79.38
#                                         close                         79.02
# dtype: float64

# %%
stacked.unstack().unstack(fill_value='-')
# Out:
# Previously a column axis      month                         year          \
# Ticker                         AAPL AMZN   FB GOOGL MSFT    AAPL    AMZN
# Treading Date Volume Category
# 2014-01-02    low               1.0    -    -     -    -  2014.0       -
#               medium              -  1.0  1.0   1.0  1.0       -  2014.0
# 2014-01-03    low               1.0    -    -     -    -  2014.0       -
#               medium              -  1.0  1.0   1.0  1.0       -  2014.0
# 2014-01-06    high                -    -  1.0     -    -       -       -
# ...                             ...  ...  ...   ...  ...     ...     ...
# 2019-08-21    low                 -  8.0  8.0   8.0  8.0       -  2019.0
#               medium            8.0    -    -     -    -  2019.0       -
# 2019-08-22    low                 -    -  8.0   8.0    -       -       -
#               medium            8.0  8.0    -     -  8.0  2019.0  2019.0
# ...

# %%
# let's build one manually!

# criteria:
# - 2-level multiindex column axis, containing:
# - tading volume (high and low) and ticker (MSFT and AMZN)
# - 10 random closing price observations

# %%
tech.reset_index(inplace=True)

# %%
tech.head(n=2)
# Out:
#   Treading Date Volume Category Ticker  month  year  day    open   close  \
# 0    2014-01-02             low   AAPL      1  2014    2   79.38   79.02
# 1    2014-01-02          medium   AMZN      1  2014    2  398.80  397.97
#
#      high     low   volume
# 0   79.58   78.86  8398851
# 1  399.36  394.02  2140246

# %%
# step 1: create muliindex

# %%
pd.MultiIndex.from_product([['low','high'],['MSFT','AMZN']],names=['Volume Category', 'Ticker'])
# Out:
# MultiIndex([( 'low', 'MSFT'),
#             ( 'low', 'AMZN'),
#             ('high', 'MSFT'),
#             ('high', 'AMZN')],
#            names=['Volume Category', 'Ticker'])

# %%
cols = pd.MultiIndex.from_product([['low','high'],['MSFT','AMZN']],names=['Volume Category', 'Ticker'])

# %%
# sterp 2: prep the undelaying data

# %%
low = tech['Volume Category'] == 'low'
high =tech['Volume Category'] == 'high'
amzn = tech.Ticker == 'AMZN'
msft = tech.Ticker == 'MSFT'

# %%
[
    tech[low & msft].close.sample(10).values,
    tech[low & amzn].close.sample(10).values,
    tech[high & msft].close.sample(10).values,
    tech[high & amzn].close.sample(10).values
]
# Out:
# [array([ 53.93,  73.16,  60.53,  65.39,  64.41,  63.28, 138.79,  57.6 ,
#          85.71,  65.47]),
#  array([ 310.35,  767.58,  784.06, 1823.54, 1801.38,  382.36, 1006.34,
#          335.78,  398.03,  337.49]),
#  array([42.71, 88.18, 36.81, 59.66, 83.81, 47.52, 50.99, 40.16, 98.23,
#         51.78]),
#  array([ 337.15, 1520.91, 1470.9 , 1572.62,  488.1 , 1782.17,  296.58,
#         1161.27,  742.38, 1460.83])]

# %%
data = [
    tech[low & msft].close.sample(10).values,
    tech[low & amzn].close.sample(10).values,
    tech[high & msft].close.sample(10).values,
    tech[high & amzn].close.sample(10).values
]

# %%
data = [[*i] for i in zip(*data)]

# %%
data
# Out:
# [[74.69, 767.58, 101.71, 1808.0],
#  [120.33, 1939.0, 108.3, 1572.62],
#  [68.77, 401.01, 55.91, 1642.81],
#  [76.29, 771.24, 50.79, 531.07],
#  [73.98, 378.59, 40.4, 1817.27],
#  [109.67, 759.22, 114.26, 358.69],
#  [55.67, 436.04, 103.73, 529.42],
#  [103.07, 948.95, 98.23, 1656.58],
#  [48.14, 531.52, 47.52, 488.1],
#  [60.53, 1176.76, 44.08, 810.2]]

# %%
df = pd.DataFrame(data, columns=cols)

# %%
df
# Out:
# Volume Category     low             high
# Ticker             MSFT     AMZN    MSFT     AMZN
# 0                 74.69   767.58  101.71  1808.00
# 1                120.33  1939.00  108.30  1572.62
# 2                 68.77   401.01   55.91  1642.81
# 3                 76.29   771.24   50.79   531.07
# 4                 73.98   378.59   40.40  1817.27
# 5                109.67   759.22  114.26   358.69
# 6                 55.67   436.04  103.73   529.42
# 7                103.07   948.95   98.23  1656.58
# 8                 48.14   531.52   47.52   488.10
# 9                 60.53  1176.76   44.08   810.20

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.columns.nlevels
# Out:
# 2

# %% [markdown]
# # 189. An Easier way: transpose()

# %%
# multiindex columns = set_index() transpose()

# %%
# set_index(): create multiindex
# transpose():  swap columns with index

# %%
tech
# Out:
#      Treading Date Volume Category Ticker  month  year  day     open    close  \
# 0       2014-01-02             low   AAPL      1  2014    2    79.38    79.02
# 1       2014-01-02          medium   AMZN      1  2014    2   398.80   397.97
# 2       2014-01-02          medium     FB      1  2014    2    54.86    54.71
# 3       2014-01-02          medium  GOOGL      1  2014    2   557.73   556.56
# 4       2014-01-02          medium   MSFT      1  2014    2    37.35    37.16
# ...            ...             ...    ...    ...   ...  ...      ...      ...
# 7100    2019-08-23          medium   AAPL      8  2019   23   209.43   202.64
# 7101    2019-08-23          medium   AMZN      8  2019   23  1793.03  1749.62
# 7102    2019-08-23          medium     FB      8  2019   23   180.84   177.75
# 7103    2019-08-23          medium  GOOGL      8  2019   23  1185.17  1153.58
# 7104    2019-08-23          medium   MSFT      8  2019   23   137.19   133.39
#
#          high      low    volume
# ...

# %%
tech.set_index(['Treading Date','Volume Category']).transpose()
# Out:
# Treading Date   2014-01-02                                       2014-01-03  \
# Volume Category        low   medium    medium   medium    medium        low
# Ticker                AAPL     AMZN        FB    GOOGL      MSFT       AAPL
# month                    1        1         1        1         1          1
# year                  2014     2014      2014     2014      2014       2014
# day                      2        2         2        2         2          3
# open                 79.38    398.8     54.86   557.73     37.35       79.0
# close                79.02   397.97     54.71   556.56     37.16      77.28
# high                 79.58   399.36     55.22   558.88      37.4       79.1
# low                  78.86   394.02     54.19   554.13      37.1       77.2
# volume             8398851  2140246  43257622  1822719  30643745   14043410
#
# Treading Date                                          ... 2019-08-22  \
# ...

# %% [markdown]
# # 190. BONUS - What about panels?

# %%
# deprecated in pandas!

# %% [markdown]
# # 191. Skill Challenge

# %%
# 1. Change the index of the che dataframe to a 3-level Multiindex containing year, month and day on levels 0, 1 and 2 respectively. Set the resulting dataframe to the variable tech_df3

# %%
tech.head(n=2)
# Out:
#   Treading Date Volume Category Ticker  month  year  day    open   close  \
# 0    2014-01-02             low   AAPL      1  2014    2   79.38   79.02
# 1    2014-01-02          medium   AMZN      1  2014    2  398.80  397.97
#
#      high     low   volume
# 0   79.58   78.86  8398851
# 1  399.36  394.02  2140246

# %%
tech.set_index(['year','month','day'])
# Out:
#                Treading Date Volume Category Ticker     open    close  \
# year month day
# 2014 1     2      2014-01-02             low   AAPL    79.38    79.02
#            2      2014-01-02          medium   AMZN   398.80   397.97
#            2      2014-01-02          medium     FB    54.86    54.71
#            2      2014-01-02          medium  GOOGL   557.73   556.56
#            2      2014-01-02          medium   MSFT    37.35    37.16
# ...                      ...             ...    ...      ...      ...
# 2019 8     23     2019-08-23          medium   AAPL   209.43   202.64
#            23     2019-08-23          medium   AMZN  1793.03  1749.62
#            23     2019-08-23          medium     FB   180.84   177.75
#            23     2019-08-23          medium  GOOGL  1185.17  1153.58
#            23     2019-08-23          medium   MSFT   137.19   133.39
#
#                    high      low    volume
# year month day
# 2014 1     2      79.58    78.86   8398851
# ...

# %%
tech_df3 = tech.set_index(['year','month','day'])

# %%
tech_df3.head(n=2)
# Out:
#                Treading Date Volume Category Ticker    open   close    high  \
# year month day
# 2014 1     2      2014-01-02             low   AAPL   79.38   79.02   79.58
#            2      2014-01-02          medium   AMZN  398.80  397.97  399.36
#
#                    low   volume
# year month day
# 2014 1     2     78.86  8398851
#            2    394.02  2140246

# %%
# 2 From the tech_df3 dataset, select all the trading days from the year 2019. In addition, add the existing column axis as the 4th level of the multiindex. Assign the resulting series to the variable tech_series.

# %%
tech_df3.loc[('2019',slice(None),slice(None)):,]
# Out:
#                Treading Date Volume Category Ticker     open    close  \
# year month day
# 2019 1     2      2019-01-02          medium   AAPL   154.89   157.92
#            2      2019-01-02          medium   AMZN  1465.20  1539.13
#            2      2019-01-02          medium     FB   128.99   135.68
#            2      2019-01-02          medium  GOOGL  1027.20  1054.68
#            2      2019-01-02          medium   MSFT    99.55   101.12
# ...                      ...             ...    ...      ...      ...
#      8     23     2019-08-23          medium   AAPL   209.43   202.64
#            23     2019-08-23          medium   AMZN  1793.03  1749.62
#            23     2019-08-23          medium     FB   180.84   177.75
#            23     2019-08-23          medium  GOOGL  1185.17  1153.58
#            23     2019-08-23          medium   MSFT   137.19   133.39
#
#                    high      low    volume
# year month day
# 2019 1     2     158.85   154.23  37039737
# ...

# %%
tech_df3.index.names
# Out:
# FrozenList(['year', 'month', 'day'])

# %%
tech_df3.set_index(['Treading Date','Volume Category','Ticker','open','close','high','low','volume']).transpose()
# Out:
# Empty DataFrame
# ...

# %%
tech_df3.loc[('2019',slice(None),slice(None)):,].set_index(['Treading Date','Volume Category','Ticker','open','close','high','low','volume']).transpose()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# # 3. From the tech series dataframe find the average close price and it's standard deaviation

# %%
tech.head(n=2)
# Out:
#   Treading Date Volume Category Ticker  month  year  day    open   close  \
# 0    2014-01-02             low   AAPL      1  2014    2   79.38   79.02
# 1    2014-01-02          medium   AMZN      1  2014    2  398.80  397.97
#
#      high     low   volume
# 0   79.58   78.86  8398851
# 1  399.36  394.02  2140246

# %%
tech.loc[:,'close']
# Out:
# 0         79.02
# 1        397.97
# 2         54.71
# 3        556.56
# 4         37.16
#          ...
# 7100     202.64
# 7101    1749.62
# 7102     177.75
# 7103    1153.58
# 7104     133.39
# Name: close, Length: 7105, dtype: float64

# %%
tech.loc[:,'close'].std()
# Out:
# 466.4376116928889

# %%
tech.loc[:,'close'].mean()
# Out:
# 422.33469106263186

# %%
tech.describe()
# Out:
#              month         year          day         open        close  \
# count  7105.000000  7105.000000  7105.000000  7105.000000  7105.000000
# mean      6.303308  2016.342013    15.709360   422.441371   422.334691
# std       3.374632     1.638798     8.735306   466.689575   466.437612
# min       1.000000  2014.000000     1.000000    34.710000    34.980000
# 25%       3.000000  2015.000000     8.000000    97.320000    97.340000
# 50%       6.000000  2016.000000    16.000000   170.090000   170.000000
# 75%       9.000000  2018.000000    23.000000   704.120000   704.250000
# max      12.000000  2019.000000    31.000000  2038.110000  2039.510000
#
#               high          low        volume
# count  7105.000000  7105.000000  7.105000e+03
# mean    426.219065   418.146104  2.008567e+07
# std     470.903795   461.622114  1.990953e+07
# min      35.880000    34.630000  7.167800e+04
# 25%      98.170000    96.320000  3.050074e+06
# 50%     171.680000   168.600000  1.727104e+07
# ...

# %% [markdown]
# # 192. - Solution

# %%
# 1
tech.head()
# Out:
#   Treading Date Volume Category Ticker  month  year  day    open   close  \
# 0    2014-01-02             low   AAPL      1  2014    2   79.38   79.02
# 1    2014-01-02          medium   AMZN      1  2014    2  398.80  397.97
# 2    2014-01-02          medium     FB      1  2014    2   54.86   54.71
# 3    2014-01-02          medium  GOOGL      1  2014    2  557.73  556.56
# 4    2014-01-02          medium   MSFT      1  2014    2   37.35   37.16
#
#      high     low    volume
# 0   79.58   78.86   8398851
# 1  399.36  394.02   2140246
# 2   55.22   54.19  43257622
# 3  558.88  554.13   1822719
# 4   37.40   37.10  30643745

# %%
tech_index = ['year','month','month']
tech_df3 = tech.set_index(tech_index)

# %%
tech_df3.head(n=10)
# Out:
#                  Treading Date Volume Category Ticker  day    open   close  \
# year month month
# 2014 1     1        2014-01-02             low   AAPL    2   79.38   79.02
#            1        2014-01-02          medium   AMZN    2  398.80  397.97
#            1        2014-01-02          medium     FB    2   54.86   54.71
#            1        2014-01-02          medium  GOOGL    2  557.73  556.56
#            1        2014-01-02          medium   MSFT    2   37.35   37.16
#            1        2014-01-03             low   AAPL    3   79.00   77.28
#            1        2014-01-03          medium   AMZN    3  398.29  396.44
#            1        2014-01-03          medium     FB    3   55.00   54.56
#            1        2014-01-03          medium  GOOGL    3  557.50  552.50
#            1        2014-01-03          medium   MSFT    3   37.20   36.91
#
#                     high     low    volume
# year month month
# 2014 1     1       79.58   78.86   8398851
# ...

# %%
# 2
tech_df3.loc[(2019,slice(None),slice(None)),:]
# Out:
#                  Treading Date Volume Category Ticker  day     open    close  \
# year month month
# 2019 1     1        2019-01-02          medium   AAPL    2   154.89   157.92
#            1        2019-01-02          medium   AMZN    2  1465.20  1539.13
#            1        2019-01-02          medium     FB    2   128.99   135.68
#            1        2019-01-02          medium  GOOGL    2  1027.20  1054.68
#            1        2019-01-02          medium   MSFT    2    99.55   101.12
# ...                        ...             ...    ...  ...      ...      ...
#      8     8        2019-08-23          medium   AAPL   23   209.43   202.64
#            8        2019-08-23          medium   AMZN   23  1793.03  1749.62
#            8        2019-08-23          medium     FB   23   180.84   177.75
#            8        2019-08-23          medium  GOOGL   23  1185.17  1153.58
#            8        2019-08-23          medium   MSFT   23   137.19   133.39
#
# ...

# %%
tech_series = tech_df3.loc[(2019,slice(None),slice(None)),:].stack()

# %%
tech_series.head(n=12)
# Out:
# year  month  month
# 2019  1      1      Treading Date      2019-01-02
#                     Volume Category        medium
#                     Ticker                   AAPL
#                     day                         2
#                     open                   154.89
#                     close                  157.92
#                     high                   158.85
#                     low                    154.23
#                     volume               37039737
#                     Treading Date      2019-01-02
#                     Volume Category        medium
#                     Ticker                   AMZN
# dtype: object

# %%
# 3
tech_series.describe()
# Out:
# count       7335
# unique      4033
# top       medium
# freq         701
# dtype: object

# %%
# tech_series.mean()

# TypeError: can only concatenate str (not "int") to str

# %%
# tech_series.unstack()

# ValueError: Index contains duplicate entries, cannot reshape

# %%
# mean and std for 'close'

# %%
tech_series.loc[(slice(None),slice(None),slice(None),'close')]
# Out:
# year  month  month
# 2019  1      1         157.92
#              1        1539.13
#              1         135.68
#              1        1054.68
#              1         101.12
#                        ...
#       8      8         202.64
#              8        1749.62
#              8         177.75
#              8        1153.58
#              8         133.39
# Length: 815, dtype: object

# %%
tech_series.loc[(slice(None),slice(None),slice(None),'close')].std()
# Out:
# 677.2268499713305

# %%
tech_series.loc[(slice(None),slice(None),slice(None),'close')].describe()
# Out:
# count     815.0
# unique    801.0
# top       138.9
# freq        2.0
# dtype: float64

# %%
tech_series.loc[(slice(None),slice(None),slice(None),'close')].apply({'Average price':'mean','Standard Deviation of Price':'std'})
# Out:
# Average price                  686.39762
# Standard Deviation of Price    677.22685
# dtype: float64
