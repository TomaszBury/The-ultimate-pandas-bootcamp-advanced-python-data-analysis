# %%
import pandas as pd

# %%
pd.read_csv('https://andybek.com/pandas-drinks')
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol
# 0                             NaN
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
url = 'https://andybek.com/pandas-drinks'

# %% [markdown]
# ### Reade the drinks.csv dataset again, this time bring in the beer_servings sequence into a new sereis with country again acting as the index. Assign this series to the varaible beers.
# link to data: https://andybek.com/pandas-drinks

# %%
beers = pd.read_csv(url,usecols=['country', 'beer_servings'] , index_col='country').squeeze('columns')
beers.head(n=6)
# Out:
# country
# Afghanistan            NaN
# Albania               89.0
# Algeria               25.0
# Andorra              245.0
# Angola               217.0
# Antigua & Barbuda     12.0
# Name: beer_servings, dtype: float64

# %% [markdown]
# ### 2. Calculate the mean, median and standard deviation of beer servings in beers. Is the distribution right or left skewed?

# %%
beers.describe()
# Out:
# count    178.000000
# mean     102.870787
# std      100.645713
# min        1.000000
# 25%       21.000000
# 50%       60.000000
# 75%      172.500000
# max      376.000000
# Name: beer_servings, dtype: float64

# %%
beers.mean()
# Out:
# 102.87078651685393

# %%
beers.median()
# Out:
# 60.0

# %%
beers.std()
# Out:
# 100.6457126793478

# %%
beers.plot()
# Out:
# <AxesSubplot:xlabel='country'>

# %%
beers.plot.bar()
# Out:
# <AxesSubplot:xlabel='country'>

# %%
beers.plot.barh(stacked=True)
# Out:
# <AxesSubplot:ylabel='country'>

# %%
beers.plot.pie(figsize=(23, 23))
# Out:
# <AxesSubplot:ylabel='beer_servings'>

# %% [markdown]
# ### 3. Slice the first 10 from beers. Are these relatively large or small relative to the rest of the sample?
# BONUS: To answer that, we could compare each value to the mean or median, An even better approach would be to clculate standard scores, or z-scores as they are kown.

# %%
beers[:10]
# Out:
# country
# Afghanistan            NaN
# Albania               89.0
# Algeria               25.0
# Andorra              245.0
# Angola               217.0
# Antigua & Barbuda     12.0
# Argentina            193.0
# Armenia               21.0
# Australia            261.0
# Austria              279.0
# Name: beer_servings, dtype: float64

# %%
beers.describe()
# Out:
# count    178.000000
# mean     102.870787
# std      100.645713
# min        1.000000
# 25%       21.000000
# 50%       60.000000
# 75%      172.500000
# max      376.000000
# Name: beer_servings, dtype: float64

# %%
beers.head()
# Out:
# country
# Afghanistan      NaN
# Albania         89.0
# Algeria         25.0
# Andorra        245.0
# Angola         217.0
# Name: beer_servings, dtype: object
