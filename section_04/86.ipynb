# %%
data_url = 'https://gist.githubusercontent.com/sh7ata/56976975b3c67caabb2efd80bb3a8467/raw/f1b7d2abf6770548edafee58ea15be71e2d28aac/Nutrition.csv'

# %%
import pandas as pd
import numpy as np

# %%
nutrition = pd.read_csv(data_url, index_col=[1])
nutrition = nutrition.drop('Unnamed: 0', axis=1)
nutrition.head(n=2)
# Out:
#              serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch          100 g       381      0.1g           NaN           0
# Nuts, pecans        100 g       691       72g          6.2g           0
#
#                sodium  choline     folate folic_acid    niacin  ...      fat  \
# name                                                            ...
# Cornstarch    9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...   0.05 g
# Nuts, pecans  0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...  71.97 g
#
#              saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch                 0.009 g                     0.016 g
# Nuts, pecans               6.180 g                    40.801 g
#
#              polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                       0.025 g                 0.00 mg   0.0 g
# Nuts, pecans                    21.614 g                 0.00 mg   0.0 g
#
# ...

# %%
nutrition.replace(to_replace='', value='', regex=True)
# Out:
#                                                    serving_size  calories  \
# name
# Cornstarch                                                100 g       381
# Nuts, pecans                                              100 g       691
# Eggplant, raw                                             100 g        25
# Teff, uncooked                                            100 g       367
# Sherbet, orange                                           100 g       144
# ...                                                         ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       125
# Lamb, cooked, separable lean only, composite of...        100 g       206
# Lamb, raw, separable lean and fat, composite of...        100 g       277
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       121
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       121
#
# ...

# %%
nutrition
# Out:
#                                                    serving_size  calories  \
# name
# Cornstarch                                                100 g       381
# Nuts, pecans                                              100 g       691
# Eggplant, raw                                             100 g        25
# Teff, uncooked                                            100 g       367
# Sherbet, orange                                           100 g       144
# ...                                                         ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       125
# Lamb, cooked, separable lean only, composite of...        100 g       206
# Lamb, raw, separable lean and fat, composite of...        100 g       277
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       121
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       121
#
# ...

# %%
nutrition.sample(n=20, axis=1).head(n=5)
# Out:
#                  alanine tryptophan    sodium polyunsaturated_fatty_acids  \
# name
# Cornstarch       0.019 g    0.001 g   9.00 mg                     0.025 g
# Nuts, pecans     0.397 g    0.093 g   0.00 mg                    21.614 g
# Eggplant, raw    0.051 g    0.009 g   2.00 mg                     0.076 g
# Teff, uncooked   0.747 g    0.139 g  12.00 mg                     1.071 g
# Sherbet, orange        0          0  46.00 mg                     0.080 g
#
#                 carotene_alpha  choline   sugars lutein_zeaxanthin threonine  \
# name
# Cornstarch            0.00 mcg   0.4 mg   0.00 g          0.00 mcg   0.009 g
# Nuts, pecans          0.00 mcg  40.5 mg   3.97 g         17.00 mcg   0.306 g
# Eggplant, raw         0.00 mcg   6.9 mg   3.53 g         36.00 mcg   0.037 g
# Teff, uncooked        0.00 mcg  13.1 mg   1.84 g         66.00 mcg   0.510 g
# Sherbet, orange       0.00 mcg   7.7 mg  24.32 g          7.00 mcg         0
#
# ...

# %%
nutrition.replace(to_replace='[^a-zA-Z]', value='', regex=True)
# Out:
#                                                    serving_size  calories  \
# name
# Cornstarch                                                    g       381
# Nuts, pecans                                                  g       691
# Eggplant, raw                                                 g        25
# Teff, uncooked                                                g       367
# Sherbet, orange                                               g       144
# ...                                                         ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...            g       125
# Lamb, cooked, separable lean only, composite of...            g       206
# Lamb, raw, separable lean and fat, composite of...            g       277
# Beef, raw, all grades, trimmed to 0" fat, separ...            g       121
# Beef, raw, all grades, trimmed to 0" fat, separ...            g       121
#
# ...

# %%
nutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8789 entries, Cornstarch to Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   serving_size                 8789 non-null   object
#  1   calories                     8789 non-null   int64
#  2   total_fat                    8789 non-null   object
#  3   saturated_fat                7199 non-null   object
#  4   cholesterol                  8789 non-null   object
#  5   sodium                       8789 non-null   object
#  6   choline                      8789 non-null   object
#  7   folate                       8789 non-null   object
#  8   folic_acid                   8789 non-null   object
#  9   niacin                       8789 non-null   object
#  10  pantothenic_acid             8789 non-null   object
# ...

# %%
nutrition.astype(str).replace(to_replace='[^a-zA-Z]', value='', regex=True)
# Out:
#                                                    serving_size calories  \
# name
# Cornstarch                                                    g
# Nuts, pecans                                                  g
# Eggplant, raw                                                 g
# Teff, uncooked                                                g
# Sherbet, orange                                               g
# ...                                                         ...      ...
# Beef, raw, all grades, trimmed to 0" fat, separ...            g
# Lamb, cooked, separable lean only, composite of...            g
# Lamb, raw, separable lean and fat, composite of...            g
# Beef, raw, all grades, trimmed to 0" fat, separ...            g
# Beef, raw, all grades, trimmed to 0" fat, separ...            g
#
#                                                    total_fat saturated_fat  \
# name
# Cornstarch                                                 g           nan
# ...

# %%
units = nutrition.astype(str).replace(to_replace='[^a-zA-Z]', value='', regex=True)

# %%
units.sample(n=20, axis=1).head(n=5)
# Out:
#                 saturated_fat galactose cystine lucopene valine alanine  \
# name
# Cornstarch                nan                 g               g       g
# Nuts, pecans                g                 g               g       g
# Eggplant, raw             nan                 g               g       g
# Teff, uncooked              g         g       g               g       g
# Sherbet, orange             g
#
#                 threonine lactose vitamin_d calories glucose vitamin_k  \
# name
# Cornstarch              g                IU                        mcg
# Nuts, pecans            g       g        IU                g       mcg
# Eggplant, raw           g                IU                g       mcg
# Teff, uncooked          g       g                          g       mcg
# Sherbet, orange                          IU                        mcg
#
#                 folic_acid monounsaturated_fatty_acids aspartic_acid fructose  \
# name
# ...

# %%
units.saturated_fat.value_counts()
# Out:
# g      7199
# nan    1590
# Name: saturated_fat, dtype: int64

# %%
units.value_counts()
# Out:
# serving_size  calories  total_fat  saturated_fat  cholesterol  sodium  choline  folate  folic_acid  niacin  pantothenic_acid  riboflavin  thiamin  vitamin_a  vitamin_a_rae  carotene_alpha  carotene_beta  cryptoxanthin_beta  lutein_zeaxanthin  lucopene  vitamin_b12  vitamin_b6  vitamin_c  vitamin_d  vitamin_e  tocopherol_alpha  vitamin_k  calcium  copper  irom  magnesium  manganese  phosphorous  potassium  selenium  zink  protein  alanine  arginine  aspartic_acid  cystine  glutamic_acid  glycine  histidine  hydroxyproline  isoleucine  leucine  lysine  methionine  phenylalanine  proline  serine  threonine  tryptophan  tyrosine  valine  carbohydrate  fiber  sugars  fructose  galactose  glucose  lactose  maltose  sucrose  fat  saturated_fatty_acids  monounsaturated_fatty_acids  polyunsaturated_fatty_acids  fatty_acids_total_trans  alcohol  ash  caffeine  theobromine  water
# ...

# %%
units.saturated_fat.mode()
# Out:
# 0    g
# Name: saturated_fat, dtype: object

# %%
units.mode()
# Out:
#   serving_size calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g                  g             g          mg     mg      mg
#
#   folate folic_acid niacin  ... fat saturated_fatty_acids  \
# 0    mcg        mcg     mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine water
# 0                      mg       g   g       mg          mg     g
#
# [1 rows x 75 columns]

# %%
units = units.mode()
