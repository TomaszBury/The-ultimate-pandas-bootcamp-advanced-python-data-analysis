# %%
import pandas as pd

# %%
data_url = 'https://gist.githubusercontent.com/sh7ata/56976975b3c67caabb2efd80bb3a8467/raw/f1b7d2abf6770548edafee58ea15be71e2d28aac/Nutrition.csv'

# %%
nutrition = pd.read_csv(data_url,index_col=[1])
nutrition.head(n=2)
# Out:
#               Unnamed: 0 serving_size  calories total_fat saturated_fat  \
# name
# Cornstarch             0        100 g       381      0.1g           NaN
# Nuts, pecans           1        100 g       691       72g          6.2g
#
#              cholesterol   sodium  choline     folate folic_acid  ...  \
# name                                                              ...
# Cornstarch             0  9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...
# Nuts, pecans           0  0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...
#
#                   fat saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch     0.05 g               0.009 g                     0.016 g
# Nuts, pecans  71.97 g               6.180 g                    40.801 g
#
#              polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                       0.025 g                 0.00 mg   0.0 g
# Nuts, pecans                    21.614 g                 0.00 mg   0.0 g
#
#                  ash caffeine theobromine   water
# name
# Cornstarch    0.09 g  0.00 mg     0.00 mg  8.32 g
# Nuts, pecans  1.49 g  0.00 mg     0.00 mg  3.52 g
#
# [2 rows x 76 columns]

# %%
nutr_mini = nutrition.sample(n=10, axis=0)
nutr_mini.shape
# Out:
# (10, 76)

# %%
nutr_mini.loc[:,['total_fat','cholesterol']]
# Out:
#                                                    total_fat cholesterol
# name
# Plantains, raw                                          0.4g           0
# Pork, cooked, rendered fat, bacon                       100g        97mg
# Wheat flours, unenriched, bread                         1.7g           0
# Chicken, fried, cooked, meat only, broilers or ...      9.1g        94mg
# Beef, raw, choice, trimmed to 0" fat, separable...       18g        66mg
# Beef, grilled, cooked, choice, trimmed to 0" fa...       14g        89mg
# Salad dressing, low calorie, mayonnaise and may...       19g        26mg
# Chocolate, 70-85% cacao solids, dark                     43g         3mg
# Crackers, rusk toast                                    7.2g        78mg
# Bread, pumpernickel                                     3.1g           0

# %% [markdown]
# # 3

# %%
b12_loc = nutr_mini.columns.get_loc('vitamin_b12')

# %%
nutr_mini.iloc[0:3,b12_loc:]
# Out:
#                                   vitamin_b12 vitamin_b6 vitamin_c vitamin_d  \
# name
# Plantains, raw                       0.00 mcg   0.299 mg   18.4 mg   0.00 IU
# Pork, cooked, rendered fat, bacon    0.09 mcg   0.005 mg    0.0 mg         0
# Wheat flours, unenriched, bread      0.00 mcg   0.037 mg    0.0 mg   0.00 IU
#
#                                   vitamin_e tocopherol_alpha vitamin_k  \
# name
# Plantains, raw                      0.14 mg          0.14 mg   0.7 mcg
# Pork, cooked, rendered fat, bacon   0.00 mg          0.00 mg   0.0 mcg
# Wheat flours, unenriched, bread     0.40 mg          0.40 mg   0.3 mcg
#
#                                     calcium    copper     irom  ...      fat  \
# name                                                            ...
# Plantains, raw                      3.00 mg  0.081 mg  0.60 mg  ...   0.37 g
# Pork, cooked, rendered fat, bacon   1.00 mg  0.022 mg  0.13 mg  ...  99.50 g
# Wheat flours, unenriched, bread    15.00 mg  0.182 mg  0.90 mg  ...   1.66 g
#
#                                   saturated_fatty_acids  \
# name
# Plantains, raw                                  0.143 g
# Pork, cooked, rendered fat, bacon              31.991 g
# Wheat flours, unenriched, bread                 0.244 g
#
#                                   monounsaturated_fatty_acids  \
# name
# Plantains, raw                                        0.032 g
# Pork, cooked, rendered fat, bacon                    41.435 g
# Wheat flours, unenriched, bread                       0.140 g
#
#                                   polyunsaturated_fatty_acids  \
# name
# Plantains, raw                                        0.069 g
# Pork, cooked, rendered fat, bacon                    10.535 g
# Wheat flours, unenriched, bread                       0.727 g
#
#                                   fatty_acids_total_trans alcohol     ash  \
# name
# Plantains, raw                                    0.00 mg   0.0 g  1.17 g
# Pork, cooked, rendered fat, bacon                97.00 mg   0.0 g  0.16 g
# Wheat flours, unenriched, bread                   0.00 mg   0.0 g  0.47 g
#
#                                   caffeine theobromine    water
# name
# Plantains, raw                     0.00 mg     0.00 mg  65.28 g
# Pork, cooked, rendered fat, bacon  0.00 mg     0.00 mg   0.25 g
# Wheat flours, unenriched, bread    0.00 mg     0.00 mg  13.36 g
#
# [3 rows x 55 columns]

# %% [markdown]
# # 4

# %%
nutr_mini.iat[2,1]
# Out:
# '100 g'
