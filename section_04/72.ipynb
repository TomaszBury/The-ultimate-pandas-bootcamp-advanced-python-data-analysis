# %%
import pandas as pd

# %%
data_url = 'https://gist.githubusercontent.com/sh7ata/56976975b3c67caabb2efd80bb3a8467/raw/f1b7d2abf6770548edafee58ea15be71e2d28aac/Nutrition.csv'

# %%
nutrition = pd.read_csv(data_url, index_col=[0])
nutrition.head(n=2)
# Out:
#            name serving_size  calories total_fat saturated_fat cholesterol  \
# 0    Cornstarch        100 g       381      0.1g           NaN           0
# 1  Nuts, pecans        100 g       691       72g          6.2g           0
#
#     sodium  choline     folate folic_acid  ...      fat saturated_fatty_acids  \
# 0  9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g               0.009 g
# 1  0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g               6.180 g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                     0.016 g                     0.025 g
# 1                    40.801 g                    21.614 g
#
#   fatty_acids_total_trans alcohol     ash caffeine theobromine   water
# 0                 0.00 mg   0.0 g  0.09 g  0.00 mg     0.00 mg  8.32 g
# 1                 0.00 mg   0.0 g  1.49 g  0.00 mg     0.00 mg  3.52 g
#
# [2 rows x 76 columns]

# %%
nutrition.sample()
# Out:
#                                           name serving_size  calories  \
# 2056  Nuts, peeled, dried, european, chestnuts        100 g       369
#
#      total_fat saturated_fat cholesterol    sodium choline      folate  \
# 2056      3.9g          0.7g           0  37.00 mg       0  110.00 mcg
#
#      folic_acid  ...     fat saturated_fatty_acids  \
# 2056   0.00 mcg  ...  3.91 g               0.736 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 2056                     1.349 g                     1.546 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine   water
# 2056                 0.00 mg       0  3.64 g        0           0  9.00 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample()
# Out:
#                                                   name serving_size  calories  \
# 3564  Veal, braised, cooked, separable lean only, loin        100 g       226
#
#      total_fat saturated_fat cholesterol    sodium   choline     folate  \
# 3564      9.2g          2.6g       125mg  84.00 mg  125.4 mg  15.00 mcg
#
#      folic_acid  ...     fat saturated_fatty_acids  \
# 3564   0.00 mcg  ...  9.15 g               2.550 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 3564                     3.270 g                     0.820 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 3564               125.00 mg   0.0 g  1.15 g  0.00 mg     0.00 mg  56.96 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample()
# Out:
#                    name serving_size  calories total_fat saturated_fat  \
# 295  Bread, white wheat        100 g       238      2.2g          0.6g
#
#     cholesterol     sodium choline      folate folic_acid  ...     fat  \
# 295           0  478.00 mg  8.1 mg  127.00 mcg  49.00 mcg  ...  2.15 g
#
#     saturated_fatty_acids monounsaturated_fatty_acids  \
# 295               0.630 g                     0.393 g
#
#     polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 295                     0.973 g                 0.00 mg   0.0 g  3.69 g
#
#     caffeine theobromine    water
# 295  0.00 mg     0.00 mg  39.60 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample(random_state=12)
# Out:
#                                                  name serving_size  calories  \
# 3713  Thuringer, pork, beef, summer sausage, cervelat        100 g       362
#
#      total_fat saturated_fat cholesterol      sodium  choline    folate  \
# 3713       30g           12g        74mg  1300.00 mg  78.9 mg  2.00 mcg
#
#      folic_acid  ...      fat saturated_fatty_acids  \
# 3713   0.00 mcg  ...  30.43 g              11.510 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 3713                    12.970 g                     1.200 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 3713                74.00 mg   0.0 g  3.63 g  0.00 mg     0.00 mg  45.18 g
#
# [1 rows x 76 columns]

# %%
# n default n=1
nutrition.sample(n=5)
# Out:
#                                     name serving_size  calories total_fat  \
# 1370   McDONALD'S, Low Fat Caramel Sauce        100 g       313      3.3g
# 895          Radish seeds, raw, sprouted        100 g        43      2.5g
# 1989      Mollusks, raw, Pacific, oyster        100 g        81      2.3g
# 1456  Cream, cultured, reduced fat, sour        100 g       135       12g
# 874         Peppers, raw, red, hot chili        100 g        40      0.4g
#
#      saturated_fat cholesterol     sodium  choline     folate folic_acid  ...  \
# 1370          1.8g        12mg  170.00 mg        0   0.00 mcg          0  ...
# 895           0.8g           0    6.00 mg        0  95.00 mcg   0.00 mcg  ...
# 1989          0.5g        50mg  106.00 mg        0  10.00 mcg   0.00 mcg  ...
# 1456          7.5g        39mg   89.00 mg  19.2 mg  11.00 mcg   0.00 mcg  ...
# 874            NaN           0    9.00 mg  10.9 mg  23.00 mcg   0.00 mcg  ...
#
#           fat saturated_fatty_acids monounsaturated_fatty_acids  \
# 1370   3.25 g               1.772 g                     0.771 g
# 895    2.53 g               0.767 g                     0.419 g
# 1989   2.30 g               0.510 g                     0.358 g
# 1456  12.00 g               7.470 g                     3.466 g
# 874    0.44 g               0.042 g                     0.024 g
#
#      polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 1370                     0.139 g                12.00 mg       0  0.82 g
# 895                      1.141 g                 0.00 mg       0  0.53 g
# 1989                     0.894 g                50.00 mg   0.0 g  1.23 g
# 1456                     0.446 g                39.00 mg   0.0 g  0.66 g
# 874                      0.239 g                 0.00 mg   0.0 g  0.87 g
#
#      caffeine theobromine    water
# 1370        0           0  22.50 g
# 895         0           0  90.07 g
# 1989        0           0  82.06 g
# 1456  0.00 mg     0.00 mg  80.14 g
# 874   0.00 mg     0.00 mg  88.02 g
#
# [5 rows x 76 columns]

# %%
nutrition.sample(frac=0.01)
# Out:
#                                                    name serving_size  \
# 603                                        Litchis, raw        100 g
# 6429  Ice creams, All Natural Light Vanilla Chocolat...        100 g
# 2335             Fish, smoked, mixed species, whitefish        100 g
# 761                       Sauce, ready-to-serve, tartar        100 g
# 8037  Beef, raw, choice, trimmed to 1/8" fat, separa...        100 g
# ...                                                 ...          ...
# 3192          Alcoholic beverage, low carb, light, beer        100 g
# 3433  KASHI Spinach Artichoke Pasta, unprepared, frozen        100 g
# 7981  Beef, raw, choice, trimmed to 1/8" fat, separa...        100 g
# 6496  Infant formula, ready-to-feed, NUTRAMIGEN AA, ...        100 g
# 6690  Chicken, cooked simmered, meat and skin, neck,...        100 g
#
#       calories total_fat saturated_fat cholesterol      sodium  choline  \
# 603         66      0.4g          0.1g           0     1.00 mg   7.1 mg
# 6429       161      4.4g          2.7g        14mg    69.00 mg        0
# 2335       108      0.9g          0.2g        33mg  1019.00 mg  95.0 mg
# 761        211       17g          3.3g         7mg   667.00 mg   8.0 mg
# 8037       140        5g          1.7g        62mg    56.00 mg  92.8 mg
# ...        ...       ...           ...         ...         ...      ...
# 3192        27        0g           NaN           0     3.00 mg   0.0 mg
# 3433       103      3.4g          1.6g         7mg   229.00 mg        0
# 7981       228       16g          6.7g        62mg    35.00 mg  50.5 mg
# 6496        66      3.5g          1.6g           0    31.00 mg  15.8 mg
# 6690       247       18g            5g        70mg    52.00 mg  49.3 mg
#
#          folate folic_acid  ...      fat saturated_fatty_acids  \
# 603   14.00 mcg   0.00 mcg  ...   0.44 g               0.099 g
# 6429          0          0  ...   4.35 g               2.700 g
# 2335   7.00 mcg   0.00 mcg  ...   0.93 g               0.228 g
# 761    5.00 mcg   0.00 mcg  ...  16.70 g               3.333 g
# 8037  13.00 mcg   0.00 mcg  ...   4.96 g               1.699 g
# ...         ...        ...  ...      ...                   ...
# 3192   0.00 mcg   0.00 mcg  ...   0.00 g               0.000 g
# 3433  14.00 mcg          0  ...   3.40 g               1.600 g
# 7981   5.00 mcg   0.00 mcg  ...  15.83 g               6.684 g
# 6496  11.00 mcg  11.00 mcg  ...   3.48 g               1.592 g
# 6690   3.00 mcg   0.00 mcg  ...  18.10 g               5.000 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 603                      0.120 g                     0.132 g
# 6429                           0                           0
# 2335                     0.278 g                     0.293 g
# 761                      3.605 g                     9.044 g
# 8037                     2.090 g                     0.213 g
# ...                          ...                         ...
# 3192                     0.000 g                     0.000 g
# 3433                     1.100 g                     0.500 g
# 7981                     7.312 g                     0.720 g
# 6496                     0.031 g                     0.741 g
# 6690                     7.220 g                     3.940 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 603                  0.00 mg   0.0 g  0.44 g  0.00 mg     0.00 mg  81.76 g
# 6429                14.00 mg       0  1.58 g        0           0  63.32 g
# 2335                33.00 mg   0.0 g  5.06 g  0.00 mg     0.00 mg  70.83 g
# 761                  7.00 mg   0.0 g  1.96 g  0.00 mg     0.00 mg  67.00 g
# 8037                62.00 mg   0.0 g  1.06 g  0.00 mg     0.00 mg  71.99 g
# ...                      ...     ...     ...      ...         ...      ...
# 3192                 0.00 mg   3.3 g  0.06 g  0.00 mg     0.00 mg  95.40 g
# 3433                 7.00 mg       0  1.10 g        0           0  75.40 g
# 7981                62.00 mg   0.0 g  0.91 g  0.00 mg     0.00 mg  63.43 g
# 6496                 0.00 mg   0.0 g  0.20 g  0.00 mg     0.00 mg  87.78 g
# 6690                70.00 mg   0.0 g  0.61 g  0.00 mg     0.00 mg  61.73 g
#
# [88 rows x 76 columns]
