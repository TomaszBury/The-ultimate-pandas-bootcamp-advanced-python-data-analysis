# %%
import pandas as pd

# %%
data_url = 'https://gist.githubusercontent.com/sh7ata/56976975b3c67caabb2efd80bb3a8467/raw/f1b7d2abf6770548edafee58ea15be71e2d28aac/Nutrition.csv'

# %%
nutrition = pd.read_csv(data_url, index_col=[0])
nutrition.head(n=2)
# Out:
#            name serving_size  calories total_fat saturated_fat cholesterol  \
# 0    Cornstarch        100 g       381      0.1g           NaN           0
# 1  Nuts, pecans        100 g       691       72g          6.2g           0
#
#     sodium  choline     folate folic_acid  ...      fat saturated_fatty_acids  \
# 0  9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g               0.009 g
# 1  0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g               6.180 g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                     0.016 g                     0.025 g
# 1                    40.801 g                    21.614 g
#
#   fatty_acids_total_trans alcohol     ash caffeine theobromine   water
# 0                 0.00 mg   0.0 g  0.09 g  0.00 mg     0.00 mg  8.32 g
# 1                 0.00 mg   0.0 g  1.49 g  0.00 mg     0.00 mg  3.52 g
#
# [2 rows x 76 columns]

# %%
nutrition.sample(n=3, replace=True)
# Out:
#                                                    name serving_size  \
# 4822  Soup, prepared with equal volume milk, canned,...        100 g
# 7146  Infant formula, powder not reconstituted, PM 6...        100 g
# 2200            Vitasoy USA, Organic Nasoya Silken Tofu        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium  choline  \
# 4822        55      3.2g          2.1g        13mg  425.00 mg        0
# 7146       524       29g           12g        17mg  123.00 mg  61.6 mg
# 2200        47      2.5g          0.3g           0          0        0
#
#          folate folic_acid  ...      fat saturated_fatty_acids  \
# 4822   4.00 mcg   0.00 mcg  ...   3.24 g               2.060 g
# 7146  77.00 mcg  77.00 mcg  ...  28.71 g              12.214 g
# 2200          0          0  ...   2.50 g               0.300 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 4822                     0.850 g                     0.130 g
# ...

# %%
weights = pd.Series(data=[10,10,10,1,2], index=[7,17,29,5,6])
weights
# Out:
# 7     10
# 17    10
# 29    10
# 5      1
# 6      2
# dtype: int64

# %%
nutrition.sample(n=3, weights=weights)
# Out:
#                       name serving_size  calories total_fat saturated_fat  \
# 29  Nuts, dried, pine nuts        100 g       673       68g          4.9g
# 7        Lamb, raw, ground        100 g       282       23g           10g
# 6         Taro leaves, raw        100 g        42      0.7g          0.2g
#
#    cholesterol    sodium  choline      folate folic_acid  ...      fat  \
# 29           0   2.00 mg  55.8 mg   34.00 mcg   0.00 mcg  ...  68.37 g
# 7         73mg  59.00 mg  69.3 mg   18.00 mcg   0.00 mcg  ...  23.41 g
# 6            0   3.00 mg  12.8 mg  126.00 mcg   0.00 mcg  ...   0.74 g
#
#    saturated_fatty_acids monounsaturated_fatty_acids  \
# 29               4.899 g                    18.764 g
# 7               10.190 g                     9.600 g
# 6                0.151 g                     0.060 g
#
#    polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 29                    34.071 g                 0.00 mg   0.0 g  2.59 g
# ...

# %%
nutrition.sample(n=5,weights=weights)
# Out:
#                       name serving_size  calories total_fat saturated_fat  \
# 17  Peppers, raw, jalapeno        100 g        29      0.4g          0.1g
# 7        Lamb, raw, ground        100 g       282       23g           10g
# 6         Taro leaves, raw        100 g        42      0.7g          0.2g
# 29  Nuts, dried, pine nuts        100 g       673       68g          4.9g
# 5         Cauliflower, raw        100 g        25      0.3g          0.1g
#
#    cholesterol    sodium  choline      folate folic_acid  ...      fat  \
# 17           0   3.00 mg   7.5 mg   27.00 mcg   0.00 mcg  ...   0.37 g
# 7         73mg  59.00 mg  69.3 mg   18.00 mcg   0.00 mcg  ...  23.41 g
# 6            0   3.00 mg  12.8 mg  126.00 mcg   0.00 mcg  ...   0.74 g
# 29           0   2.00 mg  55.8 mg   34.00 mcg   0.00 mcg  ...  68.37 g
# 5            0  30.00 mg  44.3 mg   57.00 mcg   0.00 mcg  ...   0.28 g
#
#    saturated_fatty_acids monounsaturated_fatty_acids  \
# ...
