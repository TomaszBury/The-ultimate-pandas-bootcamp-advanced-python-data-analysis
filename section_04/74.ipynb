# %%
import pandas as pd

# %%
data_url = 'https://gist.githubusercontent.com/sh7ata/56976975b3c67caabb2efd80bb3a8467/raw/f1b7d2abf6770548edafee58ea15be71e2d28aac/Nutrition.csv'

# %%
nutrition = pd.read_csv(data_url, index_col=[0])
nutrition.head(n=2)
# Out:
#            name serving_size  calories total_fat saturated_fat cholesterol  \
# 0    Cornstarch        100 g       381      0.1g           NaN           0
# 1  Nuts, pecans        100 g       691       72g          6.2g           0
#
#     sodium  choline     folate folic_acid  ...      fat saturated_fatty_acids  \
# 0  9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g               0.009 g
# 1  0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g               6.180 g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                     0.016 g                     0.025 g
# 1                    40.801 g                    21.614 g
#
#   fatty_acids_total_trans alcohol     ash caffeine theobromine   water
# 0                 0.00 mg   0.0 g  0.09 g  0.00 mg     0.00 mg  8.32 g
# 1                 0.00 mg   0.0 g  1.49 g  0.00 mg     0.00 mg  3.52 g
#
# [2 rows x 76 columns]

# %%
nutrition.sample()
# Out:
#                                                    name serving_size  \
# 7866  Beef, braised, cooked, choice, trimmed to 0" f...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium   choline  \
# 7866       216      7.1g          2.5g        90mg  45.00 mg  135.7 mg
#
#         folate folic_acid  ...     fat saturated_fatty_acids  \
# 7866  9.00 mcg   0.00 mcg  ...  7.09 g               2.520 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 7866                     2.820 g                     0.310 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 7866                90.00 mg   0.0 g  1.72 g  0.00 mg     0.00 mg  57.31 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample(random_state=19)
# Out:
#                                                    name serving_size  \
# 4176  Babyfood, apple and sweet potato, fruit and ve...        100 g
#
#       calories total_fat saturated_fat cholesterol   sodium choline    folate  \
# 4176        64      0.2g           NaN           0  3.00 mg  4.4 mg  2.00 mcg
#
#      folic_acid  ...     fat saturated_fatty_acids  \
# 4176   0.00 mcg  ...  0.22 g               0.041 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 4176                     0.008 g                     0.079 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 4176                 0.00 mg   0.0 g  0.30 g  0.00 mg     0.00 mg  84.00 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample(random_state=13)
# Out:
#                                                    name serving_size  \
# 4453  KFC, Skin and Breading, EXTRA CRISPY, Fried Ch...        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium choline folate  \
# 4453       464       37g          7.5g        59mg  828.00 mg       0      0
#
#      folic_acid  ...      fat saturated_fatty_acids  \
# 4453          0  ...  36.61 g               7.541 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 4453                    11.816 g                    14.238 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 4453                59.00 mg       0  2.92 g        0           0  26.98 g
#
# [1 rows x 76 columns]
