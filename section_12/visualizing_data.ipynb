# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.1'

# %% [markdown]
# # The art of data visualization
# > Data visualizaion i the paractice (and art) of creating a visual representation of information that conveys insight, tells a story, or summarizes data
#
# ### In this seciton we'll cover the what, why and how behind each plot.

# %% [markdown]
# # 280. The preliminaries of matplitlib

# %% [markdown]
# This is a pandas bootcamp with detours:
# -  pure python
# - numpy
# - regex
# - and now: matplotlib!

# %%
x = np.random.normal(size=400)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Another approach:
#
# ```python
# from matplotlib import pyplot as plt
# ```

# %%
plt.plot(x)

# %%
plt.plot(x.cumsum())

# %%
plt.plot(x.cumsum());

# %%
plt.plot(x.cumsum())
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
plt.plot(x.cumsum())
plt.show()

# %%
y = np.random.normal(size=400)

# %%
plt.plot(y.cumsum())
plt.show()

# %%
plt.plot(x.cumsum())
plt.plot(y.cumsum())
plt.show()

# %%
plt.plot(x.cumsum())
plt.plot(y.cumsum(), color='purple')

# %%
plt.plot(x.cumsum(), label='x')
plt.plot(y.cumsum(), color='purple', label='y')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Firure holds one or more axes

# %%
figure, axes = plt.subplots()
axes.plot(x.cumsum(), label='x')
axes.plot(y.cumsum(), color='purple', label='y')
axes.legend(loc='upper left')

figure.set_size_inches(10,2)

plt.show()

# %% [markdown]
# # 281. The preliminaries of matplitlib
# Line Graphs
# * a graph that displays a varriable over time

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

url_oil = "https://andybek.com/pandas-oil"

brent = pd.read_csv(url_oil)

# %%
brent.head(n=7)
# Out:
#         Date  Price
# 0  04-Jan-00  23.95
# 1  05-Jan-00  23.72
# 2  06-Jan-00  23.55
# 3  07-Jan-00  23.35
# 4  10-Jan-00  22.77
# 5  11-Jan-00  23.93
# 6  12-Jan-00  24.62

# %%
brent.plot()
plt.show()

# %%
brent.plot(color='purple')
plt.show()

# %%
url_tech = "https://andybek.com/pandas-tech"

tech = pd.read_csv(url_tech)

# %%
tech.head(n=7)
# Out:
#          date  month  year  day   name    open   close    high     low  \
# 0  2014-01-02      1  2014    2     FB   54.86   54.71   55.22   54.19
# 1  2014-01-02      1  2014    2   AAPL   79.38   79.02   79.58   78.86
# 2  2014-01-02      1  2014    2  GOOGL  557.73  556.56  558.88  554.13
# 3  2014-01-02      1  2014    2   MSFT   37.35   37.16   37.40   37.10
# 4  2014-01-02      1  2014    2   AMZN  398.80  397.97  399.36  394.02
# 5  2014-01-03      1  2014    3     FB   55.00   54.56   55.65   54.53
# 6  2014-01-03      1  2014    3  GOOGL  557.50  552.50  558.47  552.47
#
#      volume volume_type
# 0  43257622      medium
# 1   8398851         low
# 2   1822719      medium
# 3  30643745      medium
# 4   2140246      medium
# 5  38287706      medium
# 6   1669229      medium

# %%
tech.plot()
plt.show()

# %%
tech = pd.read_csv(url_tech, index_col=0, parse_dates=True)

# %%
tech.head(n=7)
# Out:
#             month  year  day   name    open   close    high     low    volume  \
# date
# 2014-01-02      1  2014    2     FB   54.86   54.71   55.22   54.19  43257622
# 2014-01-02      1  2014    2   AAPL   79.38   79.02   79.58   78.86   8398851
# 2014-01-02      1  2014    2  GOOGL  557.73  556.56  558.88  554.13   1822719
# 2014-01-02      1  2014    2   MSFT   37.35   37.16   37.40   37.10  30643745
# 2014-01-02      1  2014    2   AMZN  398.80  397.97  399.36  394.02   2140246
# 2014-01-03      1  2014    3     FB   55.00   54.56   55.65   54.53  38287706
# 2014-01-03      1  2014    3  GOOGL  557.50  552.50  558.47  552.47   1669229
#
#            volume_type
# date
# 2014-01-02      medium
# 2014-01-02         low
# 2014-01-02      medium
# 2014-01-02      medium
# 2014-01-02      medium
# 2014-01-03      medium
# 2014-01-03      medium

# %%
tech.plot()
plt.show()

# %%
brent = pd.read_csv(url_oil, index_col=0, parse_dates=True)

# %%
brent.head(n=6)
# Out:
#             Price
# Date
# 2000-01-04  23.95
# 2000-01-05  23.72
# 2000-01-06  23.55
# 2000-01-07  23.35
# 2000-01-10  22.77
# 2000-01-11  23.93

# %%
brent.plot()
plt.show()

# %%
tech.index
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-02', '2014-01-02', '2014-01-02',
#                '2014-01-02', '2014-01-03', '2014-01-03', '2014-01-03',
#                '2014-01-03', '2014-01-03',
#                ...
#                '2019-08-22', '2019-08-22', '2019-08-22', '2019-08-22',
#                '2019-08-22', '2019-08-23', '2019-08-23', '2019-08-23',
#                '2019-08-23', '2019-08-23'],
#               dtype='datetime64[ns]', name='date', length=7105, freq=None)

# %%
tech.head(n=11)
# Out:
#             month  year  day   name    open   close    high     low    volume  \
# date
# 2014-01-02      1  2014    2     FB   54.86   54.71   55.22   54.19  43257622
# 2014-01-02      1  2014    2   AAPL   79.38   79.02   79.58   78.86   8398851
# 2014-01-02      1  2014    2  GOOGL  557.73  556.56  558.88  554.13   1822719
# 2014-01-02      1  2014    2   MSFT   37.35   37.16   37.40   37.10  30643745
# 2014-01-02      1  2014    2   AMZN  398.80  397.97  399.36  394.02   2140246
# 2014-01-03      1  2014    3     FB   55.00   54.56   55.65   54.53  38287706
# 2014-01-03      1  2014    3  GOOGL  557.50  552.50  558.47  552.47   1669229
# 2014-01-03      1  2014    3   MSFT   37.20   36.91   37.22   36.60  31134795
# 2014-01-03      1  2014    3   AAPL   79.00   77.28   79.10   77.20  14043410
# 2014-01-03      1  2014    3   AMZN  398.29  396.44  402.71  396.22   2213512
# 2014-01-06      1  2014    6   MSFT   36.86   36.13   36.89   36.11  43615035
#
#            volume_type
# ...

# %%
fb = tech.loc[tech.name == 'FB', 'close'].rename('Facebook')

# %%
fb
# Out:
# date
# 2014-01-02     54.71
# 2014-01-03     54.56
# 2014-01-06     57.20
# 2014-01-07     57.92
# 2014-01-08     58.23
#                ...
# 2019-08-19    186.17
# 2019-08-20    183.81
# 2019-08-21    183.55
# 2019-08-22    182.04
# 2019-08-23    177.75
# Name: Facebook, Length: 1421, dtype: float64

# %%
fb.plot()
plt.show()

# %%
msft = tech.loc[tech.name == 'MSFT', 'close'].rename('Microsoft')
aapl = tech.loc[tech.name == 'AAPL', 'close'].rename('Apple')

# %%
fb.plot()
msft.plot()
aapl.plot()
plt.show()

# %%
dfs = pd.concat([fb,msft, aapl], axis=1)

# %%
dfs.plot()
plt.show()

# %%
dfs.plot(subplots=True, linewidth=.7, figsize=(13,6))
plt.show()

# %% [markdown]
# # 282. Bar. Charts
# A chart that displays a numerical value across levels of a categorical value.|

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

url = "https://andybek.com/pandas-marathon"

boston= pd.read_csv(url)
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran
# 0        1       1       NaN
# 1        2       2       NaN
# 2        3       3       NaN
# 3        4       4       NaN
# 4        5       5      2015

# %% [markdown]
# Marathon runners by age:

# %%
boston.Age
# Out:
# 0      24
# 1      30
# 2      25
# 3      32
# 4      31
#        ..
# 995    38
# 996    43
# 997    40
# 998    35
# 999    35
# Name: Age, Length: 1000, dtype: int64

# %%
boston.Age.plot()

plt.show()

# %%
boston.Age.value_counts()
# Out:
# 28    60
# 30    60
# 29    56
# 26    56
# 32    53
# 36    50
# 33    49
# 27    49
# 35    48
# 31    44
# 25    41
# 34    37
# 39    35
# 40    33
# 37    33
# 38    29
# 24    29
# 41    29
# 23    23
# 42    22
# 43    21
# 44    18
# 45    17
# 22    15
# 47    15
# 21    12
# 46    12
# 50    12
# 48     9
# 49     6
# 20     5
# 52     5
# 19     4
# 53     4
# 51     3
# 56     2
# 55     2
# 57     1
# 59     1
# Name: Age, dtype: int64

# %%
boston.Age.value_counts().plot()

plt.show()

# %%
boston.Age.value_counts().plot(kind='bar', figsize=(12,6))

plt.show()

# %%
ax = boston.Age.value_counts(sort=False).plot(kind='bar', figsize=(12,6))

ax.set_xlabel('Age Group')
ax.set_ylabel('# of runners')

plt.show()

# %%
ax = boston.Age.value_counts(sort=False).sort_index().plot(kind='bar', figsize=(12,6))

ax.set_xlabel('Age Group')
ax.set_ylabel('# of runners')

plt.show()

# %%
ax = boston.Age.value_counts(sort=False).sort_index().plot(kind='barh', figsize=(12,6))

ax.set_xlabel('Age Group')
ax.set_ylabel('# of runners')

plt.show()

# %% [markdown]
# Marathon runners by gender?

# %%
boston['M/F'].value_counts(normalize=True).plot(kind='barh')

plt.show()

# %% [markdown]
# # 283 Pie Plots
# A plot that is used to show how a total amount i attributed between its component parts.

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

url_games = 'https://andybek.com/pandas-games'

games = pd.read_csv(url_games)

# %%
games.head()
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# 3              Activision      9.03      4.28      0.13         1.32
# 4              Activision      9.67      3.73      0.11         1.13
#
#    Global_Sales
# 0         21.82
# 1         21.40
# 2         16.38
# 3         14.76
# 4         14.64

# %%
games.Global_Sales.plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='Global_Sales'>

# %% [markdown]
# What is the market share for each platform in NA?

# %%
games.NA_Sales
# Out:
# 0       14.97
# 1        7.01
# 2        9.63
# 3        9.03
# 4        9.67
#         ...
# 3138     0.00
# 3139     0.01
# 3140     0.01
# 3141     0.00
# 3142     0.00
# Name: NA_Sales, Length: 3143, dtype: float64

# %% [markdown]
# Does PS have a larger market share in JP?

# %%
games.groupby('Platform').JP_Sales.sum().plot(kind='pie', figsize=(10,10))

plt.show()

# %%
games.groupby('Platform').NA_Sales.sum().plot(kind='pie', figsize=(10,10))

plt.show()

# %%
market_sales = ['NA_Sales','JP_Sales','Platform']

games.loc[:,market_sales].groupby('Platform').sum().plot(kind='pie',y='NA_Sales')

plt.show()

# %%
market_sales = ['NA_Sales','JP_Sales','Platform']

games.loc[:,market_sales].groupby('Platform').sum().plot(kind='pie',subplots=True, figsize=(13,10))

plt.show()

# %%
games.NA_Sales.sum()
# Out:
# 1173.3

# %%
games.JP_Sales.sum()
# Out:
# 107.06

# %% [markdown]
# # 284. Histograms
# Display the distribution of a numeric variable as a series of bars

# %%
drinks_url = 'https://andybek.com/pandas-drinks'

drinks = pd.read_csv(drinks_url)

drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            NaN              NaN            NaN
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              NaN           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol
# 0                           NaN
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
drinks.beer_servings.plot(kind='hist')

plt.show()

# %%
ax = drinks.beer_servings.plot(kind='hist', bins=10)

ax.set_xlabel('Beer Servings')

plt.show()

# %%
ax = drinks.beer_servings.plot(kind='hist', bins=5)

ax.set_xlabel('Beer Servings')

plt.show()

# %%
ax = drinks.beer_servings.plot(kind='hist', bins=15)

ax.set_xlabel('Beer Servings')

plt.show()

# %%
ax = drinks.beer_servings.plot(kind='hist', bins=35)

ax.set_xlabel('Beer Servings')

plt.show()

# %%
ax = drinks.beer_servings.plot(kind='hist', bins=10, orientation='horizontal')

ax.set_xlabel('Beer Servings')

plt.show()

# %% [markdown]
# What happens if w try to histogram an entire df?

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            NaN              NaN            NaN
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              NaN           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol
# 0                           NaN
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='object')

# %%
servings = drinks.columns[1:4].to_list()
servings
# Out:
# ['beer_servings', 'spirit_servings', 'wine_servings']

# %%
drinks.loc[:,servings].plot(kind='hist', figsize=(10,10), alpha=0.6)

plt.show()

# %%
drinks.loc[:,servings].plot(kind='hist', figsize=(10,5), alpha=0.6, subplots=True)

plt.show()

# %% [markdown]
# # Histograms
# Display the distribution of a numeric variable as a series of bars

# %%
url_drinks = 'https://andybek.com/pandas-drinks'
drnks = pd.read_csv(url_drinks)

# %%
drinks.head(n=6)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan            NaN              NaN            NaN
# 1            Albania           89.0            132.0           54.0
# 2            Algeria           25.0              NaN           14.0
# 3            Andorra          245.0            138.0          312.0
# 4             Angola          217.0             57.0           45.0
# 5  Antigua & Barbuda           12.0            128.0           45.0
#
#    total_litres_of_pure_alcohol
# 0                           NaN
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9
# 5                           4.9

# %%
drinks.plot()
plt.show()

# %%
drinks.beer_servings.plot(kind='hist')

plt.show()

# %%
ax = drinks.beer_servings.plot(kind='hist')
ax.set_xlabel('Beer Servings')

plt.show()

# %%
drinks.beer_servings.plot(kind='hist', bins=5);

# %%
drinks.beer_servings.plot(kind='hist', bins=15);

# %%
drinks.beer_servings.plot(kind='hist', bins=35);

# %%
drinks.beer_servings.plot(kind='hist', bins=10);

# %% [markdown]
# Changing the orientation

# %%
ax = drinks.beer_servings.plot(kind='hist', bins=5, orientation='horizontal');
ax.set_xlabel('Beer Servings');

# %% [markdown]
# What happens if we try to histogroam an entire df?

# %%
drinks.head(n=2)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            NaN              NaN            NaN
# 1      Albania           89.0            132.0           54.0
#
#    total_litres_of_pure_alcohol
# 0                           NaN
# 1                           4.9

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].plot(kind='hist');

# %%
drinks.iloc[:,1:4].plot(kind='hist');

# %%
drinks.iloc[:,1:4].plot(kind='hist', alpha=0.6);

# %%
drinks.iloc[:,1:4].plot(kind='hist', subplots=True, figsize=(10,10));

# %% [markdown]
# # 285. Scatter plots
# Show the relationship between two numeric values

# %%
url_sat = 'https://andybek.com/pandas-sat'
sat = pd.read_csv(url_sat)
sat.head(n=6)
# Out:
#                              School Name    Borough  Student Enrollment  \
# 0  A. Philip Randolph Campus High School  Manhattan                1354
# 1  A. Philip Randolph Campus High School  Manhattan                1354
# 2  A. Philip Randolph Campus High School  Manhattan                1354
# 3            Abraham Lincoln High School   Brooklyn                2341
# 4            Abraham Lincoln High School   Brooklyn                2341
# 5            Abraham Lincoln High School   Brooklyn                2341
#
#   Percent Tested SAT Section  Score
# 0         74.00%        Math    459
# 1         74.00%     Reading    453
# 2         74.00%     Writing    447
# 3         54.90%        Math    441
# 4         54.90%     Reading    422
# 5         54.90%     Writing    422

# %% [markdown]
# ## Is reading and writing more strongly associated than writing and math?

# %%
mask_math = sat.loc[:,'SAT Section'] == 'Math'
mask_reading = sat.loc[:,'SAT Section'] == 'Reading'
mask_writing = sat.loc[:,'SAT Section'] == 'Writing'

math = sat.loc[mask_math].Score.reset_index(drop=True)
reading = sat.loc[mask_reading].Score.reset_index(drop=True)
writing = sat.loc[mask_writing].Score.reset_index(drop=True)

# %%
scores = pd.concat([math, writing, reading], axis=1)
scores.columns = ['Math', 'Writing', 'Reading']

# %%
scores.head(n=7)
# Out:
#    Math  Writing  Reading
# 0   459      447      453
# 1   441      422      422
# 2   444      444      458
# 3   386      393      397
# 4   381      390      397
# 5   365      348      366
# 6   406      396      405

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Math     375 non-null    int64
#  1   Writing  375 non-null    int64
#  2   Reading  375 non-null    int64
# dtypes: int64(3)
# memory usage: 8.9 KB

# %%
scores.plot(kind='scatter', x='Math', y='Writing');

# %%
math.corr(writing)
# Out:
# 0.9341552744743187

# %%
scores.plot(kind='scatter', x='Reading', y='Writing');

# %%
reading.corr(writing)
# Out:
# 0.9854389581058107

# %% [markdown]
# # 286 Other Visualization Options

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.1
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages
# Requires: matplotlib, numpy, pandas
# Required-by:

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
scores.head()
# Out:
#    Math  Writing  Reading
# 0   459      447      453
# 1   441      422      422
# 2   444      444      458
# 3   386      393      397
# 4   381      390      397

# %%
sns.jointplot(x='Math', y='Writing', data=scores, kind='scatter');

# %% [markdown]
# Hexagonal binnning
#
# [https://seaborn.pydata.org/generated/seaborn.jointplot.html](https://seaborn.pydata.org/generated/seaborn.jointplot.html)

# %%
sns.jointplot(x='Math', y='Writing', data=scores, kind='hex');

# %% [markdown]
# # 287. BONUS: Data ink and Chartjunk

# %% [markdown]
# # 288. Skill challenge
# 1. Starting with the games dataset, create pie plot that breaks down total game sals (global_sales) by gaming consle (platform). Note: We last used this dateset in lecture 5. It is attached and also accessible at https://andybek.com/pandas-games

# %%
url_games_skill = "https://andybek.com/pandas-games"

# %%
pd.read_csv(url_games_skill)
# Out:
#                                 Name Platform    Year         Genre  \
# 0                 Kinect Adventures!     X360  2010.0          Misc
# 1                 Grand Theft Auto V      PS3  2013.0        Action
# 2                 Grand Theft Auto V     X360  2013.0        Action
# 3     Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 4            Call of Duty: Black Ops     X360  2010.0       Shooter
# ...                              ...      ...     ...           ...
# 3138                  Bound By Flame     X360  2014.0  Role-Playing
# 3139                    Mighty No. 9     XOne  2016.0      Platform
# 3140              Resident Evil 4 HD     XOne  2016.0       Shooter
# 3141   Farming 2017 - The Simulation      PS4  2016.0    Simulation
# 3142               Rugby Challenge 3     XOne  2016.0        Sports
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0     Microsoft Game Studios     14.97      4.94      0.24         1.67
# ...

# %%
games.head()
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# 3              Activision      9.03      4.28      0.13         1.32
# 4              Activision      9.67      3.73      0.11         1.13
#
#    Global_Sales
# 0         21.82
# 1         21.40
# 2         16.38
# 3         14.76
# 4         14.64

# %% [markdown]
# 2. From the games datase, create a smaller dataframe that contains toatl Global_sales asross Platforms from all releases in sports genere. Set Name as the index of this new dataframe and assign it to the variable sports_games.

# %%
sports_games =  games.loc[games.Genre == 'Sports' , ['Name','Global_Sales']].groupby('Name').sum(numeric_only=True)

# %% [markdown]
# 3. Using the sports_games dataframe created in the previous queston, create a bar chart of the Top 20 best selling games. Based on the visualized data and without doing any specific numeric calculations, how does the difference between the 1st and 10th best selling games compare to that between the 11th and 20th?

# %%
sports_games.nlargest(n=20, columns='Global_Sales').plot(kind='bar', figsize=(10,5))

# plt.style.use("dark_background")

plt.style.use('Solarize_Light2')

plt.rcParams.update({
    "axes.facecolor": "darkgray",
    "figure.facecolor": "lightgray"}
)

plt.show()
