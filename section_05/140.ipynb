# %%
import pandas as pd
import numpy as np
data_url = 'https://andybek.com/pandas-soccer'
players = pd.read_csv(data_url)
players.head(n=2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing
# 0        4        1         1            0
# 1        4        1         1            0

# %%
# Aaron -> nickname

# %%
players.loc[players.name.str.startswith('Aaron')]
# Out:
#                 name          club  age position  position_cat  market_value  \
# 15      Aaron Ramsey       Arsenal   26       CM             2          35.0
# 157     Aaron Lennon       Everton   30       RW             1           5.0
# 176       Aaron Mooy  Huddersfield   26       CM             2           5.0
# 455  Aaron Cresswell      West+Ham   27       LB             3          12.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 15         1040        7.0   5.10%          56       1       Wales
# 157         504        5.5   0.20%          22       1     England
# 176         588        5.5   2.50%           0       4   Australia
# 455         380        5.0   1.30%          60       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 15             0        3        1         1            0
# 157            0        4        7         0            0
# 176            0        3        8         0            0
# 455            0        3       20         0            0

# %%
players.loc[players.name.str.startswith('Aaron'), 'name'] = 'Ronny'

# %%
players.loc[players.name.str.startswith('Aaron')]
# Out:
# Empty DataFrame
# Columns: [name, club, age, position, position_cat, market_value, page_views, fpl_value, fpl_sel, fpl_points, region, nationality, new_foreign, age_cat, club_id, big_club, new_signing]
# Index: []

# %%
players.loc[players.name.str.startswith('Ronny')]
# Out:
#       name          club  age position  position_cat  market_value  \
# 15   Ronny       Arsenal   26       CM             2          35.0
# 157  Ronny       Everton   30       RW             1           5.0
# 176  Ronny  Huddersfield   26       CM             2           5.0
# 455  Ronny      West+Ham   27       LB             3          12.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 15         1040        7.0   5.10%          56       1       Wales
# 157         504        5.5   0.20%          22       1     England
# 176         588        5.5   2.50%           0       4   Australia
# 455         380        5.0   1.30%          60       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 15             0        3        1         1            0
# 157            0        4        7         0            0
# 176            0        3        8         0            0
# 455            0        3       20         0            0

# %%
# do not do this!

# %%
players['age'].iloc[1] = '12'
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_16248\3319155415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players['age'].iloc[1] = '12'

# %%
players.drop_duplicates().loc[3, 'position'] = 'CM'

# %%
players
# Out:
#                     name      club age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal  28       LW             1          65.0
# 1             Mesut Ozil   Arsenal  12       AM             1          50.0
# 2              Petr Cech   Arsenal  35       GK             4           7.0
# 3           Theo Walcott   Arsenal  28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal  31       CB             3          22.0
# ..                   ...       ...  ..      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham  21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham  23       LB             3           7.0
# 462            Sam Byram  West+Ham  23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham  21       CF             1           1.0
# 464         Diafra Sakho  West+Ham  27       CF             1          10.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0          4329       12.0  17.10%         264       3           Chile
# 1          4395        9.5   5.60%         167       2         Germany
# 2          1529        5.5   5.90%         134       2  Czech Republic
# 3          2393        7.5   1.50%         122       1         England
# 4           912        6.0   0.70%         121       2          France
# ..          ...        ...     ...         ...     ...             ...
# 460         288        4.5   0.40%          38       2     Switzerland
# 461         199        4.5   0.20%          34       4        Congo DR
# 462         198        4.5   0.30%          29       1         England
# 463         412        4.5   5.90%          16       1         England
# 464         214        5.5   0.10%          12       4         Senegal
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 0              0        4        1         1            0
# 1              0        4        1         1            0
# 2              0        6        1         1            0
# 3              0        4        1         1            0
# 4              0        4        1         1            0
# ..           ...      ...      ...       ...          ...
# 460            0        1       20         0            1
# 461            0        2       20         0            1
# 462            0        2       20         0            0
# 463            0        1       20         0            1
# 464            0        3       20         0            0
#
# [465 rows x 17 columns]

# %%
'MVtoFPL' in players
# Out:
# False

# %%
'name' in players
# Out:
# True

# %%
'popularity' in players
# Out:
# False

# %%
def get_popularity(x):
    if x < 200:
        return 'relatively unknown'
    elif x < 600:
        return 'kind of popular'
    elif x < 2000:
        return 'popular'
    else:
        return 'super-popular'

# %%
players['popularity'] = players.page_views.apply(get_popularity)

# %%
'popularity' in players
# Out:
# True

# %%
players.popularity
# Out:
# 0           super-popular
# 1           super-popular
# 2                 popular
# 3           super-popular
# 4                 popular
#               ...
# 460       kind of popular
# 461    relatively unknown
# 462    relatively unknown
# 463       kind of popular
# 464       kind of popular
# Name: popularity, Length: 465, dtype: object

# %%
players['MVtoFPL'] = 1.0

# %%
'MVtoFPL' in players
# Out:
# True

# %%
players.iloc[:,-1]
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 460    1.0
# 461    1.0
# 462    1.0
# 463    1.0
# 464    1.0
# Name: MVtoFPL, Length: 465, dtype: float64

# %%
'market_value' in players
# Out:
# True

# %%
'fpl_value' in players
# Out:
# True

# %%
players['MVtoFPL'] = players.loc[:,'market_value'] / players.loc[:,'fpl_value']

# %%
players.iloc[0:5,-4:players.columns.size]
# Out:
#    big_club  new_signing     popularity   MVtoFPL
# 0         1            0  super-popular  5.416667
# 1         1            0  super-popular  5.263158
# 2         1            0        popular  1.272727
# 3         1            0  super-popular  2.666667
# 4         1            0        popular  3.666667

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       LW             1          65.0
# 1         Mesut Ozil  Arsenal  12       AM             1          50.0
# 2          Petr Cech  Arsenal  35       GK             4           7.0
# 3       Theo Walcott  Arsenal  28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity  \
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular
#
#     MVtoFPL
# 0  5.416667
# 1  5.263158
# 2  1.272727
# 3  2.666667
# 4  3.666667

# %%
df_mini = players.iloc[:4, 1:5]

# %%
df_mini
# Out:
#       club age position  position_cat
# 0  Arsenal  28       LW             1
# 1  Arsenal  12       AM             1
# 2  Arsenal  35       GK             4
# 3  Arsenal  28       RW             1

# %%
players_names = pd.Series(['Bronson', 'Bradley', 'Ronald', 'Ronny'])

# %%
players_names
# Out:
# 0    Bronson
# 1    Bradley
# 2     Ronald
# 3      Ronny
# dtype: object

# %%
df_mini.insert(0, 'nicknames', players_names)

# %%
df_mini
# Out:
#   nicknames     club age position  position_cat
# 0   Bronson  Arsenal  28       LW             1
# 1   Bradley  Arsenal  12       AM             1
# 2    Ronald  Arsenal  35       GK             4
# 3     Ronny  Arsenal  28       RW             1

# %%
# the assign() approach

# %%
df_mini.assign(career_goals=[12,67,179,49])
# Out:
#   nicknames     club age position  position_cat  career_goals
# 0   Bronson  Arsenal  28       LW             1            12
# 1   Bradley  Arsenal  12       AM             1            67
# 2    Ronald  Arsenal  35       GK             4           179
# 3     Ronny  Arsenal  28       RW             1            49

# %%
df_mini.assign(nationality=['American', 'British', 'Turkish', 'Indian'])
# Out:
#   nicknames     club age position  position_cat nationality
# 0   Bronson  Arsenal  28       LW             1    American
# 1   Bradley  Arsenal  12       AM             1     British
# 2    Ronald  Arsenal  35       GK             4     Turkish
# 3     Ronny  Arsenal  28       RW             1      Indian
