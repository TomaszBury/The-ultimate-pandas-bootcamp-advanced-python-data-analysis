# %%
import pandas as pd
data_url = 'https://andybek.com/pandas-soccer'
players = pd.read_csv(data_url)
players.head(n=2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing
# 0        4        1         1            0
# 1        4        1         1            0

# %%
players.shape
# Out:
# (465, 17)

# %%
players.dropna()
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.shape
# Out:
# (465, 17)

# %%
players.age
# Out:
# 0      28
# 1      28
# 2      35
# 3      28
# 4      31
#        ..
# 460    21
# 461    23
# 462    23
# 463    21
# 464    27
# Name: age, Length: 465, dtype: int64

# %%
type(players.age)
# Out:
# pandas.core.series.Series

# %%
ages = players.age

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: age, Length: 465, dtype: bool

# %%
ages.loc[ages.isna()]
# Out:
# Series([], Name: age, dtype: int64)

# %%
players.loc[ages.isna()]
# Out:
# Empty DataFrame
# Columns: [name, club, age, position, position_cat, market_value, page_views, fpl_value, fpl_sel, fpl_points, region, nationality, new_foreign, age_cat, club_id, big_club, new_signing]
# Index: []

# %%
players.isna().value_counts()
# Out:
# name   club   age    position  position_cat  market_value  page_views  fpl_value  fpl_sel  fpl_points  region  nationality  new_foreign  age_cat  club_id  big_club  new_signing
# False  False  False  False     False         False         False       False      False    False       False   False        False        False    False    False     False          462
#                                              True          False       False      False    False       False   False        False        False    False    False     False            2
#                      True      False         True          False       False      False    False       False   False        False        False    False    False     False            1
# dtype: int64

# %%
mask = players.market_value.isna()

# %%
players.loc[mask]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
mask_position = players.position.isna()
players.loc[mask_position]
# Out:
#             name     club  age position  position_cat  market_value  \
# 30  Granit Xhaka  Arsenal   24      NaN             2           NaN
#
#     page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 30        1815        5.5   2.00%          85       2  Switzerland
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# 30            0        2        1         1            0

# %%
players.isna()
# Out:
#       name   club    age  position  position_cat  market_value  page_views  \
# 0    False  False  False     False         False         False       False
# 1    False  False  False     False         False         False       False
# 2    False  False  False     False         False         False       False
# 3    False  False  False     False         False         False       False
# 4    False  False  False     False         False         False       False
# ..     ...    ...    ...       ...           ...           ...         ...
# 460  False  False  False     False         False         False       False
# 461  False  False  False     False         False         False       False
# 462  False  False  False     False         False         False       False
# 463  False  False  False     False         False         False       False
# 464  False  False  False     False         False         False       False
#
# ...

# %%
# how many NAs are there in this dataframe?
import numpy as np
np.count_nonzero(players.isna())
# Out:
# 4

# %%
# which recoerd have NAs in this dataframe?
players.loc[players.isna()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\The-ultimate-pandas-bootcamp-advanced-python-data-analysis\section_05\127.ipynb Cell 18 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/The-ultimate-pandas-bootcamp-advanced-python-data-analysis/section_05/127.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> # which recoerd have NAs in this dataframe?
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/The-ultimate-pandas-bootcamp-advanced-python-data-analysis/section_05/127.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> players.loc[players.isna()]
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
# ...

# %%
players[players.isna()]
# Out:
#     name club  age position  position_cat  market_value  page_views  \
# 0    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 1    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 2    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 3    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 4    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# ..   ...  ...  ...      ...           ...           ...         ...
# 460  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 461  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 462  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 463  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 464  NaN  NaN  NaN      NaN           NaN           NaN         NaN
#
#      fpl_value fpl_sel  fpl_points  region nationality  new_foreign  age_cat  \
# ...

# %%
players[players.isna()].value_counts()
# Out:
# Series([], dtype: int64)

# %%
players.isna().values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
players.loc[players.isna().values]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 30   Switzerland            0        2        1         1            0
# ...
