# %%
import pandas as pd
data_url = 'https://andybek.com/pandas-soccer'
players = pd.read_csv(data_url)
players.head(n=2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing
# 0        4        1         1            0
# 1        4        1         1            0

# %%
players.market_value.sort_values(ascending=False)
# Out:
# 96     75.00
# 267    75.00
# 0      65.00
# 244    65.00
# 245    65.00
#        ...
# 287     0.10
# 113     0.05
# 30       NaN
# 192      NaN
# 195      NaN
# Name: market_value, Length: 465, dtype: float64

# %%
players.sort_values(by='market_value', ascending=False)
# Out:
#                     name               club  age position  position_cat  \
# 96           Eden Hazard            Chelsea   26       LW             1
# 267           Paul Pogba  Manchester+United   24       CM             2
# 0         Alexis Sanchez            Arsenal   28       LW             1
# 244      Kevin De Bruyne    Manchester+City   26       AM             1
# 245        Sergio Aguero    Manchester+City   29       CF             1
# ..                   ...                ...  ...      ...           ...
# 287  Joel Castro Pereira  Manchester+United   21       GK             4
# 113     Eduardo Carvalho            Chelsea   34       LW             1
# 30          Granit Xhaka            Arsenal   24      NaN             2
# 192         Steve Mounie       Huddersfield   22       CF             1
# 195    Kasper Schmeichel     Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %%
players.sort_index(ascending=False)
# Out:
#                     name      club  age position  position_cat  market_value  \
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# ..                   ...       ...  ...      ...           ...           ...
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
#
# ...

# %%
players.index
# Out:
# RangeIndex(start=0, stop=465, step=1)

# %%
players.set_index('name' , inplace=True)

# %%
players.head(n=10)
# Out:
#                       club  age position  position_cat  market_value  \
# name
# Alexis Sanchez     Arsenal   28       LW             1          65.0
# Mesut Ozil         Arsenal   28       AM             1          50.0
# Petr Cech          Arsenal   35       GK             4           7.0
# Theo Walcott       Arsenal   28       RW             1          20.0
# Laurent Koscielny  Arsenal   31       CB             3          22.0
# Hector Bellerin    Arsenal   22       RB             3          30.0
# Olivier Giroud     Arsenal   30       CF             1          22.0
# Nacho Monreal      Arsenal   31       LB             3          13.0
# Shkodran Mustafi   Arsenal   25       CB             3          30.0
# Alex Iwobi         Arsenal   21       LW             1          10.0
#
#                    page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Alexis Sanchez           4329       12.0  17.10%         264       3
# ...

# %%
players.sort_index(ascending=False)
# Out:
#                               club  age position  position_cat  market_value  \
# name
# Åukasz FabiaÅ„ski         Swansea   32       GK             4           9.0
# Ã€ngel Rangel              Swansea   34       RB             3           1.0
# Ã‰tienne Capoue            Watford   29       DM             2           9.0
# YounÃ¨s Kaboul             Watford   31       CB             3           2.5
# Yohan Cabaye        Crystal+Palace   31       CM             2          15.0
# ...                            ...  ...      ...           ...           ...
# Abdoulaye Doucoure         Watford   24       CM             2           6.0
# Aaron Ramsey               Arsenal   26       CM             2          35.0
# Aaron Mooy            Huddersfield   26       CM             2           5.0
# Aaron Lennon               Everton   30       RW             1           5.0
# Aaron Cresswell           West+Ham   27       LB             3          12.0
#
# ...

# %%
players.sort_index().head(n=10)
# Out:
#                             club  age position  position_cat  market_value  \
# name
# Aaron Cresswell         West+Ham   27       LB             3          12.0
# Aaron Lennon             Everton   30       RW             1           5.0
# Aaron Mooy          Huddersfield   26       CM             2           5.0
# Aaron Ramsey             Arsenal   26       CM             2          35.0
# Abdoulaye Doucoure       Watford   24       CM             2           6.0
# Adam Federici        Bournemouth   32       GK             4           1.0
# Adam Lallana           Liverpool   29       AM             1          25.0
# Adam Smith           Bournemouth   26       RB             3           5.0
# Ademola Lookman          Everton   19       LW             1           5.0
# Adrian                  West+Ham   30       GK             4           8.0
#
#                     page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# ...

# %%
players.sort_index(inplace=True)

# %%
players.head(n=10)
# Out:
#                             club  age position  position_cat  market_value  \
# name
# Aaron Cresswell         West+Ham   27       LB             3          12.0
# Aaron Lennon             Everton   30       RW             1           5.0
# Aaron Mooy          Huddersfield   26       CM             2           5.0
# Aaron Ramsey             Arsenal   26       CM             2          35.0
# Abdoulaye Doucoure       Watford   24       CM             2           6.0
# Adam Federici        Bournemouth   32       GK             4           1.0
# Adam Lallana           Liverpool   29       AM             1          25.0
# Adam Smith           Bournemouth   26       RB             3           5.0
# Ademola Lookman          Everton   19       LW             1           5.0
# Adrian                  West+Ham   30       GK             4           8.0
#
#                     page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# ...

# %%
players.sort_index(ascending=False, inplace=True)

# %%
players.head(n=10)
# Out:
#                                club  age position  position_cat  market_value  \
# name
# Åukasz FabiaÅ„ski          Swansea   32       GK             4           9.0
# Ã€ngel Rangel               Swansea   34       RB             3           1.0
# Ã‰tienne Capoue             Watford   29       DM             2           9.0
# YounÃ¨s Kaboul              Watford   31       CB             3           2.5
# Yohan Cabaye         Crystal+Palace   31       CM             2          15.0
# Yohan Benalouane     Leicester+City   30       CB             3           1.0
# Yaya Toure          Manchester+City   34       CM             2           8.0
# Yannick Bolasie             Everton   28       LW             1          20.0
# Xherdan Shaqiri          Stoke+City   25       RW             1          15.0
# Winston Reid               West+Ham   29       CB             3          10.0
#
#                     page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# ...

# %%
players.sort_index(axis=1)
# Out:
#                     age  age_cat  big_club            club  club_id  \
# name
# Åukasz FabiaÅ„ski   32        5         0         Swansea       16
# Ã€ngel Rangel        34        6         0         Swansea       16
# Ã‰tienne Capoue      29        4         0         Watford       18
# YounÃ¨s Kaboul       31        4         0         Watford       18
# Yohan Cabaye         31        4         0  Crystal+Palace        6
# ...                 ...      ...       ...             ...      ...
# Abdoulaye Doucoure   24        2         0         Watford       18
# Aaron Ramsey         26        3         1         Arsenal        1
# Aaron Mooy           26        3         0    Huddersfield        8
# Aaron Lennon         30        4         0         Everton        7
# Aaron Cresswell      27        3         0        West+Ham       20
#
#                     fpl_points fpl_sel  fpl_value  market_value nationality  \
# name
# ...

# %%
players.sort_index(axis=1, inplace=True)

# %%
players.reset_index(inplace=True)

# %%
players.head(n=10)
# Out:
#                  name  age  age_cat  big_club             club  club_id  \
# 0  Åukasz FabiaÅ„ski   32        5         0          Swansea       16
# 1       Ã€ngel Rangel   34        6         0          Swansea       16
# 2     Ã‰tienne Capoue   29        4         0          Watford       18
# 3      YounÃ¨s Kaboul   31        4         0          Watford       18
# 4        Yohan Cabaye   31        4         0   Crystal+Palace        6
# 5    Yohan Benalouane   30        4         0   Leicester+City        9
# 6          Yaya Toure   34        6         1  Manchester+City       11
# 7     Yannick Bolasie   28        4         0          Everton        7
# 8     Xherdan Shaqiri   25        3         0       Stoke+City       15
# 9        Winston Reid   29        4         0         West+Ham       20
#
#    fpl_points fpl_sel  fpl_value  market_value    nationality  new_foreign  \
# 0         116   6.20%        4.5           9.0         Poland            0
# ...

# %%
players.reset_index(inplace=True)

# %%
players.head(n=10)
# Out:
#    index                name  age  age_cat  big_club             club  \
# 0      0  Åukasz FabiaÅ„ski   32        5         0          Swansea
# 1      1       Ã€ngel Rangel   34        6         0          Swansea
# 2      2     Ã‰tienne Capoue   29        4         0          Watford
# 3      3      YounÃ¨s Kaboul   31        4         0          Watford
# 4      4        Yohan Cabaye   31        4         0   Crystal+Palace
# 5      5    Yohan Benalouane   30        4         0   Leicester+City
# 6      6          Yaya Toure   34        6         1  Manchester+City
# 7      7     Yannick Bolasie   28        4         0          Everton
# 8      8     Xherdan Shaqiri   25        3         0       Stoke+City
# 9      9        Winston Reid   29        4         0         West+Ham
#
#    club_id  fpl_points fpl_sel  fpl_value  market_value    nationality  \
# 0       16         116   6.20%        4.5           9.0         Poland
# ...

# %%
players.reset_index(inplace=True)

# %%
players.head(n=10)
# Out:
#    level_0  index                name  age  age_cat  big_club  \
# 0        0      0  Åukasz FabiaÅ„ski   32        5         0
# 1        1      1       Ã€ngel Rangel   34        6         0
# 2        2      2     Ã‰tienne Capoue   29        4         0
# 3        3      3      YounÃ¨s Kaboul   31        4         0
# 4        4      4        Yohan Cabaye   31        4         0
# 5        5      5    Yohan Benalouane   30        4         0
# 6        6      6          Yaya Toure   34        6         1
# 7        7      7     Yannick Bolasie   28        4         0
# 8        8      8     Xherdan Shaqiri   25        3         0
# 9        9      9        Winston Reid   29        4         0
#
#               club  club_id  fpl_points fpl_sel  fpl_value  market_value  \
# 0          Swansea       16         116   6.20%        4.5           9.0
# 1          Swansea       16          26  18.80%        4.0           1.0
# ...

# %%
players.drop('level_0', axis=1, inplace=True)

# %%
players.drop('index',axis=1, inplace=True)

# %%
players.head(n=10)
# Out:
#                  name  age  age_cat  big_club             club  club_id  \
# 0  Åukasz FabiaÅ„ski   32        5         0          Swansea       16
# 1       Ã€ngel Rangel   34        6         0          Swansea       16
# 2     Ã‰tienne Capoue   29        4         0          Watford       18
# 3      YounÃ¨s Kaboul   31        4         0          Watford       18
# 4        Yohan Cabaye   31        4         0   Crystal+Palace        6
# 5    Yohan Benalouane   30        4         0   Leicester+City        9
# 6          Yaya Toure   34        6         1  Manchester+City       11
# 7     Yannick Bolasie   28        4         0          Everton        7
# 8     Xherdan Shaqiri   25        3         0       Stoke+City       15
# 9        Winston Reid   29        4         0         West+Ham       20
#
#    fpl_points fpl_sel  fpl_value  market_value    nationality  new_foreign  \
# 0         116   6.20%        4.5           9.0         Poland            0
# ...
