# %%
import pandas as pd
import numpy as np
data_url = 'https://andybek.com/pandas-soccer'
players = pd.read_csv(data_url)
players.head(n=2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing
# 0        4        1         1            0
# 1        4        1         1            0

# %%
def get_popularity(x):
    if x < 200:
        return 'relatively unknown'
    elif x < 600:
        return 'kind of popular'
    elif x < 2000:
        return 'popular'
    else:
        return 'super-popular'

# %%
players['popularity'] = players.page_views.apply(get_popularity)

# %%
players.head(n=2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super-popular
# 1        4        1         1            0  super-popular

# %%
df_mini = players.iloc[:4, 1:5]

# %%
players_names = pd.Series(['Bronson', 'Bradley', 'Ronald', 'Ronny'])

# %%
df_mini.insert(0, 'nicknames', players_names)

# %%
df_mini.assign(career_goals=[12,67,179,49])
# Out:
#   nicknames     club  age position  position_cat  career_goals
# 0   Bronson  Arsenal   28       LW             1            12
# 1   Bradley  Arsenal   28       AM             1            67
# 2    Ronald  Arsenal   35       GK             4           179
# 3     Ronny  Arsenal   28       RW             1            49

# %%
df_mini.assign(nationality=['American', 'British', 'Turkish', 'Indian'])
# Out:
#   nicknames     club  age position  position_cat nationality
# 0   Bronson  Arsenal   28       LW             1    American
# 1   Bradley  Arsenal   28       AM             1     British
# 2    Ronald  Arsenal   35       GK             4     Turkish
# 3     Ronny  Arsenal   28       RW             1      Indian

# %%
cristiano = pd.Series({
    'nicknames': 'Cristiano',
    'age': 32,
    'position': 'RW',
    'club':'Juventus',
    'position_cat': 1
}, name=4)

# %%
cristiano
# Out:
# nicknames       Cristiano
# age                    32
# position               RW
# club             Juventus
# position_cat            1
# Name: 4, dtype: object

# %%
df_mini.append(cristiano)
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_16200\1194034564.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mini.append(cristiano)
#    nicknames      club  age position  position_cat
# 0    Bronson   Arsenal   28       LW             1
# 1    Bradley   Arsenal   28       AM             1
# 2     Ronald   Arsenal   35       GK             4
# 3      Ronny   Arsenal   28       RW             1
# 4  Cristiano  Juventus   32       RW             1

# %%
df_mini.append(cristiano)
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_16200\1194034564.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mini.append(cristiano)
#    nicknames      club  age position  position_cat
# 0    Bronson   Arsenal   28       LW             1
# 1    Bradley   Arsenal   28       AM             1
# 2     Ronald   Arsenal   35       GK             4
# 3      Ronny   Arsenal   28       RW             1
# 4  Cristiano  Juventus   32       RW             1

# %%
pd.concat([df_mini, cristiano.to_frame().T])
# Out:
#    nicknames      club age position position_cat
# 0    Bronson   Arsenal  28       LW            1
# 1    Bradley   Arsenal  28       AM            1
# 2     Ronald   Arsenal  35       GK            4
# 3      Ronny   Arsenal  28       RW            1
# 4  Cristiano  Juventus  32       RW            1

# %%
other_players = pd.DataFrame({
    'nicknames': ['Gianluigi', 'Lionel'],
    'age':[37,32],
    'club':['Juventus', 'Barcelona'],
    'position':['GK', 'CF'],
    'position_cat': [4, 2]
}, index=[5, 6])

# %%
other_players
# Out:
#    nicknames  age       club position  position_cat
# 5  Gianluigi   37   Juventus       GK             4
# 6     Lionel   32  Barcelona       CF             2

# %%
pd.concat([df_mini, other_players])
# Out:
#    nicknames       club  age position  position_cat
# 0    Bronson    Arsenal   28       LW             1
# 1    Bradley    Arsenal   28       AM             1
# 2     Ronald    Arsenal   35       GK             4
# 3      Ronny    Arsenal   28       RW             1
# 5  Gianluigi   Juventus   37       GK             4
# 6     Lionel  Barcelona   32       CF             2

# %%
# setting with enlargement

# %%
# df['inexistent label'] = 'some value'

# %%
df_mini
# Out:
#   nicknames     club  age position  position_cat
# 0   Bronson  Arsenal   28       LW             1
# 1   Bradley  Arsenal   28       AM             1
# 2    Ronald  Arsenal   35       GK             4
# 3     Ronny  Arsenal   28       RW             1

# %%
df_mini = pd.concat([df_mini, cristiano.to_frame().T])

# %%
df_mini = pd.concat([df_mini, other_players])

# %%
df_mini
# Out:
#    nicknames       club age position position_cat
# 0    Bronson    Arsenal  28       LW            1
# 1    Bradley    Arsenal  28       AM            1
# 2     Ronald    Arsenal  35       GK            4
# 3      Ronny    Arsenal  28       RW            1
# 4  Cristiano   Juventus  32       RW            1
# 5  Gianluigi   Juventus  37       GK            4
# 6     Lionel  Barcelona  32       CF            2

# %%
df_mini.loc[9]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 9
#
# ...

# %%
df_mini.loc[9] = 'some row value'

# %%
df_mini
# Out:
#         nicknames            club             age        position  \
# 0         Bronson         Arsenal              28              LW
# 1         Bradley         Arsenal              28              AM
# 2          Ronald         Arsenal              35              GK
# 3           Ronny         Arsenal              28              RW
# 4       Cristiano        Juventus              32              RW
# 5       Gianluigi        Juventus              37              GK
# 6          Lionel       Barcelona              32              CF
# 9  some row value  some row value  some row value  some row value
#
#      position_cat
# 0               1
# 1               1
# 2               4
# 3               1
# 4               1
# 5               4
# 6               2
# 9  some row value

# %%
# adding rows to dataframes is inefficient (a very expensive oparation)
