# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
# DATA URL SOURCES ################################
#engineering schools
eng_url = 'https://andybek.com/pandas-eng'
# State University
state_url = 'https://andybek.com/pandas-state'
# https://en.wikipedia.org/wiki/Party_school
# party school is used to refer to a college or university (usually in the United States) that has a reputation for heavy alcohol and drug use or a general culture of licentiousness at the expense of educational credibility and integrity.
party_url = 'https://andybek.com/pandas-party'
# https://en.wikipedia.org/wiki/Liberal_arts_college
liberal_url = 'https://andybek.com/pandas-liberal'
# https://en.wikipedia.org/wiki/Ivy_League
ivies_url = 'https://andybek.com/pandas-ivies'
###################################################

# %%
eng = pd.read_csv(eng_url)
eng.head()
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $72,200.00              $126,000.00
# 1            $75,500.00              $123,000.00
# 2            $71,800.00              $122,000.00
# 3            $62,400.00              $114,000.00
# 4            $62,200.00              $114,000.00

# %% [markdown]
# Introducint (Five ?) New Datasets

# %%
state = pd.read_csv(state_url)
state.head()
# Out:
#                                       School Name School Type  \
# 0              University of California, Berkeley       State
# 1                    University of Virginia (UVA)       State
# 2                        Cal Poly San Luis Obispo       State
# 3  University of California at Los Angeles (UCLA)       State
# 4      University of California, San Diego (UCSD)       State
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 1            $52,700.00              $103,000.00
# 2            $57,200.00              $101,000.00
# 3            $52,600.00              $101,000.00
# 4            $51,100.00              $101,000.00

# %%
party = pd.read_csv(party_url)
party.head()
# Out:
#                                          School Name School Type  \
# 0  University of Illinois at Urbana-Champaign (UIUC)       Party
# 1               University of Maryland, College Park       Party
# 2     University of California, Santa Barbara (UCSB)       Party
# 3                  University of Texas (UT) - Austin       Party
# 4      State University of New York (SUNY) at Albany       Party
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $52,900.00               $96,100.00
# 1            $52,000.00               $95,000.00
# 2            $50,500.00               $95,000.00
# 3            $49,700.00               $93,900.00
# 4            $44,500.00               $92,200.00

# %%
liberal = pd.read_csv(liberal_url)
liberal.head()
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
# 2      Amherst College  Liberal Arts            $54,500.00
# 3    Lafayette College  Liberal Arts            $53,900.00
# 4      Bowdoin College  Liberal Arts            $48,100.00
#
#   Mid-Career Median Salary
# 0             $110,000.00
# 1             $108,000.00
# 2             $107,000.00
# 3             $107,000.00
# 4             $107,000.00

# %%
ivies = pd.read_csv(ivies_url)
ivies.head()
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00

# %% [markdown]
# Concatenating DataFrames

# %%
dfs = [state, eng, liberal, ivies, party]

# %%
for df in dfs:
    print(df.shape)
# Out:
# (175, 4)
# (19, 4)
# (47, 4)
# (8, 4)
# (20, 4)

# %%
pd.concat([ivies, eng])
# Out:
#                                           School Name  School Type  \
# 0                                   Dartmouth College   Ivy League
# 1                                Princeton University   Ivy League
# 2                                     Yale University   Ivy League
# 3                                  Harvard University   Ivy League
# 4                          University of Pennsylvania   Ivy League
# 5                                  Cornell University   Ivy League
# 6                                    Brown University   Ivy League
# 7                                 Columbia University   Ivy League
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# ...

# %%
pd.concat([ivies, eng]).shape
# Out:
# (27, 4)

# %%
ivies.shape[0] + eng.shape[0]
# Out:
# 27

# %%
pd.concat(dfs)
# Out:
#                                        School Name School Type  \
# 0               University of California, Berkeley       State
# 1                     University of Virginia (UVA)       State
# 2                         Cal Poly San Luis Obispo       State
# 3   University of California at Los Angeles (UCLA)       State
# 4       University of California, San Diego (UCSD)       State
# ..                                             ...         ...
# 15               University of New Hampshire (UNH)       Party
# 16                  West Virginia University (WVU)       Party
# 17                         University of Tennessee       Party
# 18                                 Ohio University       Party
# 19                  Florida State University (FSU)       Party
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $59,900.00              $112,000.00
# 1             $52,700.00              $103,000.00
# 2             $57,200.00              $101,000.00
# ...

# %%
add = 0
for df in dfs:
    add += df.shape[0]
add
# Out:
# 269

# %%
set(party['School Name']).difference(state['School Name'])
# Out:
# {'Randolph-Macon College'}

# %%
'Randolph-Macon College' in liberal['School Name'].values
# Out:
# True

# %%
pd.concat(dfs).duplicated(subset=['School Name'], keep='first')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# Length: 269, dtype: bool

# %%
pd.concat(dfs)[pd.concat(dfs).duplicated(subset=['School Name'], keep='first')]
# Out:
#                                           School Name School Type  \
# 0   University of Illinois at Urbana-Champaign (UIUC)       Party
# 1                University of Maryland, College Park       Party
# 2      University of California, Santa Barbara (UCSB)       Party
# 3                   University of Texas (UT) - Austin       Party
# 4       State University of New York (SUNY) at Albany       Party
# 5                          University of Florida (UF)       Party
# 6                    Louisiana State University (LSU)       Party
# 7                         University of Georgia (UGA)       Party
# 8                 Pennsylvania State University (PSU)       Party
# 9                      Arizona State University (ASU)       Party
# 10               Indiana University (IU), Bloomington       Party
# 11                            University of Iowa (UI)       Party
# 12                             Randolph-Macon College       Party
# ...

# %%
schools = pd.concat(dfs).drop_duplicates(subset='School Name')

# %% [markdown]
# The duplicated Index Issue

# %%
schools.loc[0]
# Out:
#                                    School Name   School Type  \
# 0           University of California, Berkeley         State
# 0  Massachusetts Institute of Technology (MIT)   Engineering
# 0                          Bucknell University  Liberal Arts
# 0                            Dartmouth College    Ivy League
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 0            $72,200.00              $126,000.00
# 0            $54,100.00              $110,000.00
# 0            $58,000.00              $134,000.00

# %%
schools.reindex()
# Out:
#                                        School Name School Type  \
# 0               University of California, Berkeley       State
# 1                     University of Virginia (UVA)       State
# 2                         Cal Poly San Luis Obispo       State
# 3   University of California at Los Angeles (UCLA)       State
# 4       University of California, San Diego (UCSD)       State
# ..                                             ...         ...
# 3                               Harvard University  Ivy League
# 4                       University of Pennsylvania  Ivy League
# 5                               Cornell University  Ivy League
# 6                                 Brown University  Ivy League
# 7                              Columbia University  Ivy League
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $59,900.00              $112,000.00
# 1             $52,700.00              $103,000.00
# 2             $57,200.00              $101,000.00
# ...

# %%
schools.loc[0]
# Out:
#                                    School Name   School Type  \
# 0           University of California, Berkeley         State
# 0  Massachusetts Institute of Technology (MIT)   Engineering
# 0                          Bucknell University  Liberal Arts
# 0                            Dartmouth College    Ivy League
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 0            $72,200.00              $126,000.00
# 0            $54,100.00              $110,000.00
# 0            $58,000.00              $134,000.00

# %%
# pd.concat() -> does not disacrd the original index of the dataframes being concatenated!

# %%
schools.index.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
# schools.loc[0:2]

# KeyError: 'Cannot get left slice bound for non-unique label: 0'

# %%
# the first fix

# %%
schools.reset_index(drop=True,inplace=True)

# %%
schools
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 244                              Harvard University  Ivy League
# 245                      University of Pennsylvania  Ivy League
# 246                              Cornell University  Ivy League
# 247                                Brown University  Ivy League
# 248                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
schools.loc[0:2]
# Out:
#                           School Name School Type Starting Median Salary  \
# 0  University of California, Berkeley       State            $59,900.00
# 1        University of Virginia (UVA)       State            $52,700.00
# 2            Cal Poly San Luis Obispo       State            $57,200.00
#
#   Mid-Career Median Salary
# 0             $112,000.00
# 1             $103,000.00
# 2             $101,000.00

# %%
schools.index.duplicated().sum()
# Out:
# 0

# %%
# the alternative approach: concat()

# %%
pd.concat(dfs).drop_duplicates(subset=['School Name'])
# Out:
#                                        School Name School Type  \
# 0               University of California, Berkeley       State
# 1                     University of Virginia (UVA)       State
# 2                         Cal Poly San Luis Obispo       State
# 3   University of California at Los Angeles (UCLA)       State
# 4       University of California, San Diego (UCSD)       State
# ..                                             ...         ...
# 3                               Harvard University  Ivy League
# 4                       University of Pennsylvania  Ivy League
# 5                               Cornell University  Ivy League
# 6                                 Brown University  Ivy League
# 7                              Columbia University  Ivy League
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $59,900.00              $112,000.00
# 1             $52,700.00              $103,000.00
# 2             $57,200.00              $101,000.00
# ...

# %%
pd.concat(dfs, ignore_index=True).drop_duplicates(subset=['School Name'])
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 244                              Harvard University  Ivy League
# 245                      University of Pennsylvania  Ivy League
# 246                              Cornell University  Ivy League
# 247                                Brown University  Ivy League
# 248                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
ivies2 = ivies.set_index('School Name')
eng2 = eng.set_index('School Name')

# %%
eng2.head()
# Out:
#                                               School Type  \
# School Name
# Massachusetts Institute of Technology (MIT)   Engineering
# California Institute of Technology (CIT)      Engineering
# Harvey Mudd College                           Engineering
# Polytechnic University of New York, Brooklyn  Engineering
# Cooper Union                                  Engineering
#
#                                              Starting Median Salary  \
# School Name
# Massachusetts Institute of Technology (MIT)             $72,200.00
# California Institute of Technology (CIT)                $75,500.00
# Harvey Mudd College                                     $71,800.00
# Polytechnic University of New York, Brooklyn            $62,400.00
# Cooper Union                                            $62,200.00
#
#                                              Mid-Career Median Salary
# School Name
# Massachusetts Institute of Technology (MIT)              $126,000.00
# ...

# %%
pd.concat([ivies2, eng2], ignore_index=True)
# Out:
#     School Type Starting Median Salary Mid-Career Median Salary
# 0    Ivy League            $58,000.00              $134,000.00
# 1    Ivy League            $66,500.00              $131,000.00
# 2    Ivy League            $59,100.00              $126,000.00
# 3    Ivy League            $63,400.00              $124,000.00
# 4    Ivy League            $60,900.00              $120,000.00
# 5    Ivy League            $60,300.00              $110,000.00
# 6    Ivy League            $56,200.00              $109,000.00
# 7    Ivy League            $59,400.00              $107,000.00
# 8   Engineering            $72,200.00              $126,000.00
# 9   Engineering            $75,500.00              $123,000.00
# 10  Engineering            $71,800.00              $122,000.00
# 11  Engineering            $62,400.00              $114,000.00
# 12  Engineering            $62,200.00              $114,000.00
# 13  Engineering            $61,000.00              $114,000.00
# ...

# %%
pd.concat([ivies2, eng2])
# Out:
#                                                     School Type  \
# School Name
# Dartmouth College                                    Ivy League
# Princeton University                                 Ivy League
# Yale University                                      Ivy League
# Harvard University                                   Ivy League
# University of Pennsylvania                           Ivy League
# Cornell University                                   Ivy League
# Brown University                                     Ivy League
# Columbia University                                  Ivy League
# Massachusetts Institute of Technology (MIT)         Engineering
# California Institute of Technology (CIT)            Engineering
# Harvey Mudd College                                 Engineering
# Polytechnic University of New York, Brooklyn        Engineering
# Cooper Union                                        Engineering
# ...

# %%
pd.concat([ivies2, eng2], verify_integrity=True)
# Out:
#                                                     School Type  \
# School Name
# Dartmouth College                                    Ivy League
# Princeton University                                 Ivy League
# Yale University                                      Ivy League
# Harvard University                                   Ivy League
# University of Pennsylvania                           Ivy League
# Cornell University                                   Ivy League
# Brown University                                     Ivy League
# Columbia University                                  Ivy League
# Massachusetts Institute of Technology (MIT)         Engineering
# California Institute of Technology (CIT)            Engineering
# Harvey Mudd College                                 Engineering
# Polytechnic University of New York, Brooklyn        Engineering
# Cooper Union                                        Engineering
# ...

# %%
random_eng_chool = eng2.sample()

# %%
random_eng_chool
# Out:
#                                              School Type  \
# School Name
# Massachusetts Institute of Technology (MIT)  Engineering
#
#                                             Starting Median Salary  \
# School Name
# Massachusetts Institute of Technology (MIT)            $72,200.00
#
#                                             Mid-Career Median Salary
# School Name
# Massachusetts Institute of Technology (MIT)             $126,000.00

# %%
ivies2 = pd.concat([ivies2, random_eng_chool])

# %%
# pd.concat([ivies2, eng2], verify_integrity=True)

# ValueError: Indexes have overlapping values: Index(['Illinois Institute of Technology (IIT)'], dtype='object', name='School Name')

# %% [markdown]
# BONUS - Creating multiple Indicates with concat()

# %%
# Previously: pd.concat(ignore_index=True)

# %%
# How about a MultiIndex?

# %%
new_df = pd.concat([ivies, eng], keys=['ivyleague_schools', 'engineering_shools'])

# %%
type(new_df.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
new_df.head()
# Out:
#                                     School Name School Type  \
# ivyleague_schools 0           Dartmouth College  Ivy League
#                   1        Princeton University  Ivy League
#                   2             Yale University  Ivy League
#                   3          Harvard University  Ivy League
#                   4  University of Pennsylvania  Ivy League
#
#                     Starting Median Salary Mid-Career Median Salary
# ivyleague_schools 0            $58,000.00              $134,000.00
#                   1            $66,500.00              $131,000.00
#                   2            $59,100.00              $126,000.00
#                   3            $63,400.00              $124,000.00
#                   4            $60,900.00              $120,000.00

# %%
new_df.loc[('ivyleague_schools',3)]
# Out:
# School Name                 Harvard University
# School Type                         Ivy League
# Starting Median Salary             $63,400.00
# Mid-Career Median Salary          $124,000.00
# Name: (ivyleague_schools, 3), dtype: object

# %%
new_df.iloc[3]
# Out:
# School Name                 Harvard University
# School Type                         Ivy League
# Starting Median Salary             $63,400.00
# Mid-Career Median Salary          $124,000.00
# Name: (ivyleague_schools, 3), dtype: object

# %% [markdown]
# Column Axis Concatenation

# %%
#### previously:
# dfs = [state, eng, liberal, ivies, party]
# schools = pd.concat(dfs)

# %%
schools
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 244                              Harvard University  Ivy League
# 245                      University of Pennsylvania  Ivy League
# 246                              Cornell University  Ivy League
# 247                                Brown University  Ivy League
# 248                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
ivies3 = ivies.sort_values(by=['Starting Median Salary'], ascending=False)[:5].reset_index(drop=True)

# %%
eng3 = eng.sort_values(by=['Starting Median Salary'], ascending=False)[:5].reset_index(drop=True)

# %%
pd.concat([ivies3, eng3], axis=1)
# Out:
#                   School Name School Type Starting Median Salary  \
# 0        Princeton University  Ivy League            $66,500.00
# 1          Harvard University  Ivy League            $63,400.00
# 2  University of Pennsylvania  Ivy League            $60,900.00
# 3          Cornell University  Ivy League            $60,300.00
# 4         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary                                   School Name  \
# 0             $131,000.00       California Institute of Technology (CIT)
# 1             $124,000.00    Massachusetts Institute of Technology (MIT)
# 2             $120,000.00                            Harvey Mudd College
# 3             $110,000.00   Polytechnic University of New York, Brooklyn
# 4             $107,000.00                                   Cooper Union
#
#    School Type Starting Median Salary Mid-Career Median Salary
# 0  Engineering            $75,500.00              $123,000.00
# ...

# %% [markdown]
# The append() Method: A Special case of concat()

# %%
liberal.append(party)
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_15072\2111828760.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liberal.append(party)
#                           School Name   School Type Starting Median Salary  \
# 0                 Bucknell University  Liberal Arts            $54,100.00
# 1                  Colgate University  Liberal Arts            $52,800.00
# 2                     Amherst College  Liberal Arts            $54,500.00
# 3                   Lafayette College  Liberal Arts            $53,900.00
# 4                     Bowdoin College  Liberal Arts            $48,100.00
# ..                                ...           ...                    ...
# 15  University of New Hampshire (UNH)         Party            $41,800.00
# 16     West Virginia University (WVU)         Party            $43,100.00
# 17            University of Tennessee         Party            $43,800.00
# ...

# %%
pd.concat([liberal, party])
# Out:
#                           School Name   School Type Starting Median Salary  \
# 0                 Bucknell University  Liberal Arts            $54,100.00
# 1                  Colgate University  Liberal Arts            $52,800.00
# 2                     Amherst College  Liberal Arts            $54,500.00
# 3                   Lafayette College  Liberal Arts            $53,900.00
# 4                     Bowdoin College  Liberal Arts            $48,100.00
# ..                                ...           ...                    ...
# 15  University of New Hampshire (UNH)         Party            $41,800.00
# 16     West Virginia University (WVU)         Party            $43,100.00
# 17            University of Tennessee         Party            $43,800.00
# 18                    Ohio University         Party            $42,200.00
# 19     Florida State University (FSU)         Party            $42,100.00
#
#    Mid-Career Median Salary
# 0              $110,000.00
# ...

# %% [markdown]
# Concat on different columns

# %%
# add STEM column
# Science, technology, engineering, and mathematics

# %%
eng4 = eng.copy()

# %%
eng4['STEM'] = True

# %%
eng4.head()
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#   Starting Median Salary Mid-Career Median Salary  STEM
# 0            $72,200.00              $126,000.00   True
# 1            $75,500.00              $123,000.00   True
# 2            $71,800.00              $122,000.00   True
# 3            $62,400.00              $114,000.00   True
# 4            $62,200.00              $114,000.00   True

# %%
pd.concat([ivies, eng4])
# Out:
#                                           School Name  School Type  \
# 0                                   Dartmouth College   Ivy League
# 1                                Princeton University   Ivy League
# 2                                     Yale University   Ivy League
# 3                                  Harvard University   Ivy League
# 4                          University of Pennsylvania   Ivy League
# 5                                  Cornell University   Ivy League
# 6                                    Brown University   Ivy League
# 7                                 Columbia University   Ivy League
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# ...

# %%
# pd.concat([ivies, eng4], verify_integrity=True)

# ValueError: Indexes have overlapping values: Int64Index([0, 1, 2, 3, 4, 5, 6, 7], dtype='int64')

# %%
pd.concat([ivies, eng4], ignore_index=True, verify_integrity=True)
# Out:
#                                           School Name  School Type  \
# 0                                   Dartmouth College   Ivy League
# 1                                Princeton University   Ivy League
# 2                                     Yale University   Ivy League
# 3                                  Harvard University   Ivy League
# 4                          University of Pennsylvania   Ivy League
# 5                                  Cornell University   Ivy League
# 6                                    Brown University   Ivy League
# 7                                 Columbia University   Ivy League
# 8         Massachusetts Institute of Technology (MIT)  Engineering
# 9            California Institute of Technology (CIT)  Engineering
# 10                                Harvey Mudd College  Engineering
# 11       Polytechnic University of New York, Brooklyn  Engineering
# 12                                       Cooper Union  Engineering
# ...

# %%
pd.concat([ivies, eng4], join='inner', ignore_index=True, verify_integrity=True)
# Out:
#                                           School Name  School Type  \
# 0                                   Dartmouth College   Ivy League
# 1                                Princeton University   Ivy League
# 2                                     Yale University   Ivy League
# 3                                  Harvard University   Ivy League
# 4                          University of Pennsylvania   Ivy League
# 5                                  Cornell University   Ivy League
# 6                                    Brown University   Ivy League
# 7                                 Columbia University   Ivy League
# 8         Massachusetts Institute of Technology (MIT)  Engineering
# 9            California Institute of Technology (CIT)  Engineering
# 10                                Harvey Mudd College  Engineering
# 11       Polytechnic University of New York, Brooklyn  Engineering
# 12                                       Cooper Union  Engineering
# ...

# %% [markdown]
# # 156 - skill challenge

# %% [markdown]
# ## 1

# %%
len(pd.concat([liberal, state], ignore_index=True, verify_integrity=True)['School Name'].unique())
# Out:
# 222

# %%
liberal_state_uni = pd.concat([liberal, state], ignore_index=True, verify_integrity=True)

# %%
liberal_state_uni.head(n=2)
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
#
#   Mid-Career Median Salary
# 0             $110,000.00
# 1             $108,000.00

# %%
liberal_state_uni.iloc[:,0]
# Out:
# 0                      Bucknell University
# 1                       Colgate University
# 2                          Amherst College
# 3                        Lafayette College
# 4                          Bowdoin College
#                       ...
# 217           Austin Peay State University
# 218             Pittsburg State University
# 219               Southern Utah University
# 220    Montana State University - Billings
# 221           Black Hills State University
# Name: School Name, Length: 222, dtype: object

# %%
liberal_state_uni.iloc[:,0].unique().size
# Out:
# 222

# %% [markdown]
# ## 2 What is the average median starting salary in the dataframe created above?

# %%
liberal_state_uni.head(n=2)
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
#
#   Mid-Career Median Salary
# 0             $110,000.00
# 1             $108,000.00

# %%
liberal_state_uni.iloc[:,2]
# Out:
# 0      $54,100.00
# 1      $52,800.00
# 2      $54,500.00
# 3      $53,900.00
# 4      $48,100.00
#           ...
# 217    $37,700.00
# 218    $40,400.00
# 219    $41,900.00
# 220    $37,900.00
# 221    $35,300.00
# Name: Starting Median Salary, Length: 222, dtype: object

# %%
# liberal_state_uni.iloc[:,2].median()

# TypeError: could not convert string to float: '$54,100.00 '

# %%
liberal_state_uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   School Name               222 non-null    object
#  1   School Type               222 non-null    object
#  2   Starting Median Salary    222 non-null    object
#  3   Mid-Career Median Salary  222 non-null    object
# dtypes: object(4)
# memory usage: 7.1+ KB

# %%
for col in liberal_state_uni:
    liberal_state_uni[col] = liberal_state_uni[col].map(lambda x: x.replace('$',''))

# %%
for col in liberal_state_uni:
    liberal_state_uni[col] = liberal_state_uni[col].map(lambda x: x.replace('.00',''))

# %%
for col in liberal_state_uni:
    liberal_state_uni[col] = liberal_state_uni[col].map(lambda x: x.replace(',',''))

# %%
liberal_state_uni.head(n=2)
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts                 54100
# 1   Colgate University  Liberal Arts                 52800
#
#   Mid-Career Median Salary
# 0                  110000
# 1                  108000

# %%
liberal_state_uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   School Name               222 non-null    object
#  1   School Type               222 non-null    object
#  2   Starting Median Salary    222 non-null    object
#  3   Mid-Career Median Salary  222 non-null    object
# dtypes: object(4)
# memory usage: 7.1+ KB

# %%
liberal_state_uni['Starting Median Salary'] = pd.to_numeric(liberal_state_uni['Starting Median Salary'])

# %%
liberal_state_uni['Mid-Career Median Salary'] = pd.to_numeric(liberal_state_uni['Mid-Career Median Salary'])

# %%
liberal_state_uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   School Name               222 non-null    object
#  1   School Type               222 non-null    object
#  2   Starting Median Salary    222 non-null    int64
#  3   Mid-Career Median Salary  222 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 7.1+ KB

# %%
liberal_state_uni.head()
# Out:
#            School Name   School Type  Starting Median Salary  \
# 0  Bucknell University  Liberal Arts                   54100
# 1   Colgate University  Liberal Arts                   52800
# 2      Amherst College  Liberal Arts                   54500
# 3    Lafayette College  Liberal Arts                   53900
# 4      Bowdoin College  Liberal Arts                   48100
#
#    Mid-Career Median Salary
# 0                    110000
# 1                    108000
# 2                    107000
# 3                    107000
# 4                    107000

# %%
liberal_state_uni.iloc[:,3].mean()
# Out:
# 80856.3063063063

# %%
liberal_state_uni.iloc[:,2].mean()
# Out:
# 44469.36936936937

# %% [markdown]
# ## Create a short dataframe that shows the top 3 liberal arts and state schools that produce the highest (mid-career) earning graduates.
# ## Show the school name and mid careet median salary columns from each dataset, side by side i.e. horizontally.
# ## BONUS: nest the column labels within 'Liberal Arts' and ' State' Labels

# %%
liberal.iloc[0:3, [0,3]]
# Out:
#            School Name Mid-Career Median Salary
# 0  Bucknell University             $110,000.00
# 1   Colgate University             $108,000.00
# 2      Amherst College             $107,000.00

# %%
state.iloc[0:3, [0,3]]
# Out:
#                           School Name Mid-Career Median Salary
# 0  University of California, Berkeley             $112,000.00
# 1        University of Virginia (UVA)             $103,000.00
# 2            Cal Poly San Luis Obispo             $101,000.00

# %%
pd.concat ([liberal.iloc[0:3,[0,3]], state.iloc[0:3,[0,3]]], axis=1)
# Out:
#            School Name Mid-Career Median Salary  \
# 0  Bucknell University             $110,000.00
# 1   Colgate University             $108,000.00
# 2      Amherst College             $107,000.00
#
#                           School Name Mid-Career Median Salary
# 0  University of California, Berkeley             $112,000.00
# 1        University of Virginia (UVA)             $103,000.00
# 2            Cal Poly San Luis Obispo             $101,000.00

# %% [markdown]
# # 157 - Solution

# %% [markdown]
# ## 1

# %%
dfc = pd.concat([liberal, state])

# %%
dfc.head()
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
# 2      Amherst College  Liberal Arts            $54,500.00
# 3    Lafayette College  Liberal Arts            $53,900.00
# 4      Bowdoin College  Liberal Arts            $48,100.00
#
#   Mid-Career Median Salary
# 0             $110,000.00
# 1             $108,000.00
# 2             $107,000.00
# 3             $107,000.00
# 4             $107,000.00

# %%
dfc.nunique()
# Out:
# School Name                 222
# School Type                   2
# Starting Median Salary      122
# Mid-Career Median Salary    155
# dtype: int64

# %%
dfc['School Name'].nunique()
# Out:
# 222

# %%
liberal.shape[0] + state.shape[0]
# Out:
# 222

# %%
dfc.iloc[:,3]
# Out:
# 0      $110,000.00
# 1      $108,000.00
# 2      $107,000.00
# 3      $107,000.00
# 4      $107,000.00
#            ...
# 170     $59,200.00
# 171     $58,200.00
# 172     $56,500.00
# 173     $50,600.00
# 174     $43,900.00
# Name: Mid-Career Median Salary, Length: 222, dtype: object

# %%
# dfc.iloc[:,3].mean()

# TypeError: Could not convert $110,000.00 $108,000.00 $107,000.00 $107,000.00 $107,000.00 $106,000.00 $105,000.00 $104,000.00 $104,000.00 $104,000.00 $103,000.00 $102,000.00 $101,000.00 $97,900.00 $96,500.00 $95,800.00 $94,600.00 $94,600.00 $94,200.00 $94,100.00 $92,800.00 $88,300.00 $86,200.00 $85,800.00 $85,800.00 $85,200.00 $83,900.00 $83,700.00 $83,600.00 $83,500.00 $83,500.00 $81,600.00 $81,500.00 $81,400.00 $81,100.00 $80,600.00 $80,100.00 $80,000.00 $78,900.00 $78,200.00 $76,600.00 $74,600.00 $74,400.00 $72,600.00 $69,800.00 $67,500.00 $63,900.00 $112,000.00 $103,000.00 $101,000.00 $101,000.00 $101,000.00 $99,600.00 $97,600.00 $96,700.00 $96,100.00 $96,100.00 $95,900.00 $95,800.00 $95,600.00 $95,000.00 $95,000.00 $93,900.00 $93,000.00 $93,000.00 $92,200.00 $91,800.00 $90,500.00 $88,800.00 $88,200.00 $88,100.00 $87,900.00 $87,800.00 $87,800.00 $87,000.00 $86,900.00 $86,600.00 $86,400.00 $86,100.00 $86,000.00 $86,000.00 $85,700.00 $85,300.00 $85,300.00 $85,300.00 $85,200.00 $84,700.00 $84,700.00 $84,700.00 $84,600.00 $84,500.00 $84,400.00 $84,300.00 $84,200.00 $84,200.00 $84,100.00 $84,100.00 $84,000.00 $83,900.00 $83,700.00 $83,300.00 $83,300.00 $83,200.00 $82,900.00 $82,900.00 $82,800.00 $82,700.00 $82,700.00 $82,400.00 $82,000.00 $81,700.00 $81,700.00 $81,600.00 $81,600.00 $81,500.00 $81,400.00 $81,300.00 $81,300.00 $81,000.00 $80,900.00 $80,800.00 $80,800.00 $80,700.00 $80,600.00 $80,400.00 $79,900.00 $79,700.00 $79,500.00 $79,400.00 $79,300.00 $79,000.00 $79,000.00 $78,700.00 $78,700.00 $78,500.00 $78,400.00 $78,300.00 $78,300.00 $78,200.00 $78,100.00 $77,800.00 $77,800.00 $77,800.00 $77,700.00 $77,500.00 $76,700.00 $76,300.00 $76,200.00 $76,100.00 $76,000.00 $75,900.00 $75,500.00 $75,500.00 $75,400.00 $74,700.00 $74,600.00 $74,600.00 $74,500.00 $74,000.00 $74,000.00 $74,000.00 $73,800.00 $73,500.00 $73,400.00 $73,400.00 $73,400.00 $73,100.00 $73,000.00 $72,600.00 $72,600.00 $72,600.00 $72,500.00 $72,100.00 $72,100.00 $72,100.00 $72,100.00 $72,100.00 $71,900.00 $71,700.00 $71,700.00 $71,600.00 $71,400.00 $71,400.00 $71,400.00 $71,300.00 $71,100.00 $71,100.00 $70,900.00 $70,900.00 $70,700.00 $70,300.00 $70,300.00 $70,100.00 $69,700.00 $69,500.00 $69,500.00 $69,300.00 $69,100.00 $68,400.00 $68,300.00 $67,500.00 $67,100.00 $67,100.00 $66,600.00 $66,400.00 $66,200.00 $65,800.00 $64,800.00 $64,500.00 $64,400.00 $64,000.00 $63,600.00 $63,300.00 $62,600.00 $62,400.00 $60,600.00 $60,600.00 $59,200.00 $58,200.00 $56,500.00 $50,600.00 $43,900.00  to numeric

# %%
dfc.iloc[:,3].replace(r'\$|,','', regex=True).astype(float).mean()
# Out:
# 80856.3063063063

# %% [markdown]
# ## 3

# %%
lib_2 = liberal.sort_values(by=['Mid-Career Median Salary'], ascending=False).iloc[:3,[0,3]].reset_index(drop=True)

# %%
state_2 = state.sort_values(by=['Mid-Career Median Salary'], ascending=False).iloc[:3, [0,3]].reset_index(drop=True)

# %%
pd.concat([lib_2, state_2], axis=1, keys=['Liberal Arts', 'State'])
# Out:
#                                     Liberal Arts                           \
#                                      School Name Mid-Career Median Salary
# 0  Wesleyan University (Middletown, Connecticut)              $97,900.00
# 1                                  Bates College              $96,500.00
# 2                                  Union College              $95,800.00
#
#                                     State
#                               School Name Mid-Career Median Salary
# 0         University of California, Davis              $99,600.00
# 1  University of Colorado - Boulder (UCB)              $97,600.00
# 2  University of California, Irvine (UCI)              $96,700.00

# %% [markdown]
# # 158. The merge() Method

# %%
# merge() is similar to SQL!
# regional information on the schools

regions_url = 'https://andybek.com/pandas-regions'
regions = pd.read_csv(regions_url)

# %%
regions.head()
# Out:
#                                     School Name        Region
# 0   Massachusetts Institute of Technology (MIT)  Northeastern
# 1      California Institute of Technology (CIT)    California
# 2                           Harvey Mudd College    California
# 3  Polytechnic University of New York, Brooklyn  Northeastern
# 4                                  Cooper Union  Northeastern

# %%
regions.shape
# Out:
# (269, 2)

# %%
schools.head()
# Out:
#                                       School Name School Type  \
# 0              University of California, Berkeley       State
# 1                    University of Virginia (UVA)       State
# 2                        Cal Poly San Luis Obispo       State
# 3  University of California at Los Angeles (UCLA)       State
# 4      University of California, San Diego (UCSD)       State
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 1            $52,700.00              $103,000.00
# 2            $57,200.00              $101,000.00
# 3            $52,600.00              $101,000.00
# 4            $51,100.00              $101,000.00

# %%
schools.shape
# Out:
# (249, 4)

# %%
pd.merge(schools, regions)
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 264                              Harvard University  Ivy League
# 265                      University of Pennsylvania  Ivy League
# 266                              Cornell University  Ivy League
# 267                                Brown University  Ivy League
# 268                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0              $59,900.00              $112,000.00     California
# ...

# %%
pd.merge(schools, regions, on='School Name')
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 264                              Harvard University  Ivy League
# 265                      University of Pennsylvania  Ivy League
# 266                              Cornell University  Ivy League
# 267                                Brown University  Ivy League
# 268                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0              $59,900.00              $112,000.00     California
# ...

# %%
schools['School Name'].nunique()
# Out:
# 249

# %%
schools.shape
# Out:
# (249, 4)

# %%
regions.shape
# Out:
# (269, 2)

# %%
regions['School Name'].nunique()
# Out:
# 249

# %%
regions[regions['School Name'].duplicated()]
# Out:
#                                            School Name        Region
# 67                              Randolph-Macon College      Southern
# 102  University of Illinois at Urbana-Champaign (UIUC)    Midwestern
# 107               University of Maryland, College Park      Southern
# 108     University of California, Santa Barbara (UCSB)    California
# 109                  University of Texas (UT) - Austin      Southern
# 112      State University of New York (SUNY) at Albany  Northeastern
# 118                         University of Florida (UF)      Southern
# 120                   Louisiana State University (LSU)      Southern
# 127                        University of Georgia (UGA)      Southern
# 128                Pennsylvania State University (PSU)  Northeastern
# 142                     Arizona State University (ASU)       Western
# 144               Indiana University (IU), Bloomington    Midwestern
# 145                            University of Iowa (UI)    Midwestern
# ...

# %%
regions.loc[regions.loc[:,'School Name'].duplicated()].shape
# Out:
# (20, 2)

# %%
regions.loc[regions.loc[:,'School Name'] == 'Louisiana State University (LSU)']
# Out:
#                           School Name    Region
# 25   Louisiana State University (LSU)  Southern
# 120  Louisiana State University (LSU)  Southern

# %%
regions.loc[regions.loc[:,'School Name'] == 'University of Illinois at Urbana-Champaign (UIUC)']
# Out:
#                                            School Name      Region
# 19   University of Illinois at Urbana-Champaign (UIUC)  Midwestern
# 102  University of Illinois at Urbana-Champaign (UIUC)  Midwestern

# %% [markdown]
# ## The left_on and right_on params

# %%
income_url = 'http://andybek.com/pandas-mid'
mid_career = pd.read_csv(income_url)
mid_career.head()
# Out:
#                                     school_name  \
# 0   Massachusetts Institute of Technology (MIT)
# 1      California Institute of Technology (CIT)
# 2                           Harvey Mudd College
# 3  Polytechnic University of New York, Brooklyn
# 4                                  Cooper Union
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                       $76,800.00                        $99,200.00
# 1                               NaN                      $104,000.00
# 2                               NaN                       $96,000.00
# 3                       $66,800.00                        $94,300.00
# 4                               NaN                       $80,200.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                      $168,000.00                       $220,000.00
# 1                      $161,000.00                                NaN
# ...

# %%
schools.head()
# Out:
#                                       School Name School Type  \
# 0              University of California, Berkeley       State
# 1                    University of Virginia (UVA)       State
# 2                        Cal Poly San Luis Obispo       State
# 3  University of California at Los Angeles (UCLA)       State
# 4      University of California, San Diego (UCSD)       State
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 1            $52,700.00              $103,000.00
# 2            $57,200.00              $101,000.00
# 3            $52,600.00              $101,000.00
# 4            $51,100.00              $101,000.00

# %%
# pd.merge(schools ,mid_career)

# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
pd.merge(schools, mid_career, left_on='School Name', right_on='school_name')
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 264                              Harvard University  Ivy League
# 265                      University of Pennsylvania  Ivy League
# 266                              Cornell University  Ivy League
# 267                                Brown University  Ivy League
# 268                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
pd.merge(schools, mid_career, left_on='School Name', right_on='school_name').drop('school_name', axis=1)
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 264                              Harvard University  Ivy League
# 265                      University of Pennsylvania  Ivy League
# 266                              Cornell University  Ivy League
# 267                                Brown University  Ivy League
# 268                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %% [markdown]
# # 160. Inner vs Outer joins
# ### the how param

# %%
pd.merge(ivies, regions)
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %%
regions.shape
# Out:
# (269, 2)

# %%
# defoult inner, intersection
pd.merge(ivies, regions, how='inner')
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %%
pd.merge(ivies, regions, how='outer')
# Out:
#                              School Name School Type Starting Median Salary  \
# 0                      Dartmouth College  Ivy League            $58,000.00
# 1                   Princeton University  Ivy League            $66,500.00
# 2                        Yale University  Ivy League            $59,100.00
# 3                     Harvard University  Ivy League            $63,400.00
# 4             University of Pennsylvania  Ivy League            $60,900.00
# ..                                   ...         ...                    ...
# 264         Austin Peay State University         NaN                    NaN
# 265           Pittsburg State University         NaN                    NaN
# 266             Southern Utah University         NaN                    NaN
# 267  Montana State University - Billings         NaN                    NaN
# 268         Black Hills State University         NaN                    NaN
#
#     Mid-Career Median Salary        Region
# ...

# %%
# === ASIDE outer == union, all keys are selected

# %%
a = {1,2,3}
b = {4,9,2}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 9}

# %% [markdown]
# # 161. let vs right joins

# %%
pd.merge(ivies, regions, how='left')
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %%
pd.merge(ivies, regions, how='right')
# Out:
#                                       School Name School Type  \
# 0     Massachusetts Institute of Technology (MIT)         NaN
# 1        California Institute of Technology (CIT)         NaN
# 2                             Harvey Mudd College         NaN
# 3    Polytechnic University of New York, Brooklyn         NaN
# 4                                    Cooper Union         NaN
# ..                                            ...         ...
# 264                  Austin Peay State University         NaN
# 265                    Pittsburg State University         NaN
# 266                      Southern Utah University         NaN
# 267           Montana State University - Billings         NaN
# 268                  Black Hills State University         NaN
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0                      NaN                      NaN  Northeastern
# 1                      NaN                      NaN    California
# ...

# %%
# these are equivalent, or the same:

# %%
pd.merge(regions, ivies, how='right')
# Out:
#                   School Name        Region School Type  \
# 0           Dartmouth College  Northeastern  Ivy League
# 1        Princeton University  Northeastern  Ivy League
# 2             Yale University  Northeastern  Ivy League
# 3          Harvard University  Northeastern  Ivy League
# 4  University of Pennsylvania  Northeastern  Ivy League
# 5          Cornell University  Northeastern  Ivy League
# 6            Brown University  Northeastern  Ivy League
# 7         Columbia University  Northeastern  Ivy League
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $58,000.00              $134,000.00
# 1            $66,500.00              $131,000.00
# 2            $59,100.00              $126,000.00
# 3            $63,400.00              $124,000.00
# 4            $60,900.00              $120,000.00
# 5            $60,300.00              $110,000.00
# 6            $56,200.00              $109,000.00
# 7            $59,400.00              $107,000.00

# %% [markdown]
# # 162 - **One to One** and **One to Many** Joins

# %%
# 1-1

# %%
ivies
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %%
regions.head()
# Out:
#                                     School Name        Region
# 0   Massachusetts Institute of Technology (MIT)  Northeastern
# 1      California Institute of Technology (CIT)    California
# 2                           Harvey Mudd College    California
# 3  Polytechnic University of New York, Brooklyn  Northeastern
# 4                                  Cooper Union  Northeastern

# %%
pd.merge(ivies, regions, how='inner', on='School Name')
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %%
pd.merge(ivies, regions, how='inner', on='School Name').loc[:,'School Name'].nunique()
# Out:
# 8

# %%
pd.merge(ivies, regions, how='inner', on='School Name').shape[0]
# Out:
# 8

# %%
regions.loc[regions.loc[:,'School Name'].isin(ivies.loc[:,'School Name'])]
# Out:
#                    School Name        Region
# 86           Dartmouth College  Northeastern
# 87        Princeton University  Northeastern
# 88             Yale University  Northeastern
# 89          Harvard University  Northeastern
# 90  University of Pennsylvania  Northeastern
# 91          Cornell University  Northeastern
# 92            Brown University  Northeastern
# 93         Columbia University  Northeastern

# %%
# 1-Many

# %%
state
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 170                    Austin Peay State University       State
# 171                      Pittsburg State University       State
# 172                        Southern Utah University       State
# 173             Montana State University - Billings       State
# 174                    Black Hills State University       State
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
state.shape
# Out:
# (175, 4)

# %%
regions.loc[regions.loc[:,'School Name'].isin(state.loc[:,'School Name'])]
# Out:
#                                            School Name        Region
# 19   University of Illinois at Urbana-Champaign (UIUC)    Midwestern
# 20                University of Maryland, College Park      Southern
# 21      University of California, Santa Barbara (UCSB)    California
# 22                   University of Texas (UT) - Austin      Southern
# 23       State University of New York (SUNY) at Albany  Northeastern
# ..                                                 ...           ...
# 264                       Austin Peay State University      Southern
# 265                         Pittsburg State University    Midwestern
# 266                           Southern Utah University       Western
# 267                Montana State University - Billings       Western
# 268                       Black Hills State University    Midwestern
#
# [194 rows x 2 columns]

# %%
state.loc[:,'School Name'].is_unique
# Out:
# True

# %%
regions.loc[:,'School Name'].is_unique
# Out:
# False

# %%
regions.loc[regions.loc[:,'School Name'].isin(state.loc[:,'School Name'])].loc[:,'School Name'].value_counts().head(n=20)
# Out:
# University of Illinois at Urbana-Champaign (UIUC)    2
# Indiana University (IU), Bloomington                 2
# University of Maryland, College Park                 2
# Ohio University                                      2
# University of Tennessee                              2
# West Virginia University (WVU)                       2
# University of New Hampshire (UNH)                    2
# University of Mississippi                            2
# University of Alabama, Tuscaloosa                    2
# University of Iowa (UI)                              2
# Florida State University (FSU)                       2
# Arizona State University (ASU)                       2
# University of Georgia (UGA)                          2
# Louisiana State University (LSU)                     2
# University of Florida (UF)                           2
# State University of New York (SUNY) at Albany        2
# University of Texas (UT) - Austin                    2
# ...

# %%
pd.merge(state, regions, how='inner', on='School Name')
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 189                    Austin Peay State University       State
# 190                      Pittsburg State University       State
# 191                        Southern Utah University       State
# 192             Montana State University - Billings       State
# 193                    Black Hills State University       State
#
#     Starting Median Salary Mid-Career Median Salary      Region
# 0              $59,900.00              $112,000.00   California
# 1              $52,700.00              $103,000.00     Southern
# ...

# %%
pd.merge(state, regions, how='inner', on='School Name').sort_values(by='School Name').head()
# Out:
#                          School Name School Type Starting Median Salary  \
# 169     Appalachian State University       State            $40,400.00
# 58    Arizona State University (ASU)       State            $47,400.00
# 57    Arizona State University (ASU)       State            $47,400.00
# 184  Arkansas State University (ASU)       State            $38,700.00
# 48                 Auburn University       State            $45,400.00
#
#     Mid-Career Median Salary    Region
# 169              $69,100.00   Southern
# 58               $84,100.00    Western
# 57               $84,100.00    Western
# 184              $63,300.00   Southern
# 48               $84,700.00   Southern

# %%
pd.merge(state, regions.drop_duplicates(), how='inner', on='School Name').sort_values(by='School Name')
# Out:
#                            School Name School Type Starting Median Salary  \
# 150       Appalachian State University       State            $40,400.00
# 48      Arizona State University (ASU)       State            $47,400.00
# 165    Arkansas State University (ASU)       State            $38,700.00
# 39                   Auburn University       State            $45,400.00
# 170       Austin Peay State University       State            $37,700.00
# ..                                 ...         ...                    ...
# 101             Wayne State University       State            $42,800.00
# 92      West Virginia University (WVU)       State            $43,100.00
# 156        Western Carolina University       State            $36,900.00
# 114  Western Michigan University (WMU)       State            $42,300.00
# 106      Western Washington University       State            $42,700.00
#
#     Mid-Career Median Salary      Region
# 150              $69,100.00     Southern
# ...

# %% [markdown]
# # 163 Many to Many joins

# %%
# survey data -> what is the prestige of any ivy or eng degree

# %%
survey = pd.DataFrame({
    'School Type':['Ivy League','Ivy League','Engineering','Engineering'],
    'Prestige':['High', 'Good','Good', 'Okay'],
    'Respondent':[1,2,3,4]
})

# %%
survey
# Out:
#    School Type   Prestige  Respondent
# 0   Ivy League       High           1
# 1   Ivy League       Good           2
# 2  Engineering       Good           3
# 3  Engineering       Okay           4
# 4   Ivy League  Very High           5

# %%
pd.merge(ivies, survey)
# Out:
#                    School Name School Type Starting Median Salary  \
# 0            Dartmouth College  Ivy League            $58,000.00
# 1            Dartmouth College  Ivy League            $58,000.00
# 2            Dartmouth College  Ivy League            $58,000.00
# 3         Princeton University  Ivy League            $66,500.00
# 4         Princeton University  Ivy League            $66,500.00
# 5         Princeton University  Ivy League            $66,500.00
# 6              Yale University  Ivy League            $59,100.00
# 7              Yale University  Ivy League            $59,100.00
# 8              Yale University  Ivy League            $59,100.00
# 9           Harvard University  Ivy League            $63,400.00
# 10          Harvard University  Ivy League            $63,400.00
# 11          Harvard University  Ivy League            $63,400.00
# 12  University of Pennsylvania  Ivy League            $60,900.00
# ...

# %%
survey = survey.append(pd.Series({'School Type': 'Ivy League', 'Prestige': 'Very High', 'Respondent':5}, name=4))
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_15072\4248073623.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   survey = survey.append(pd.Series({'School Type': 'Ivy League', 'Prestige': 'Very High', 'Respondent':5}, name=4))

# %%
survey
# Out:
#    School Type   Prestige  Respondent
# 0   Ivy League       High           1
# 1   Ivy League       Good           2
# 2  Engineering       Good           3
# 3  Engineering       Okay           4
# 4   Ivy League  Very High           5

# %%
survey = pd.concat([survey, pd.DataFrame({'School Type': ['Ivy League'], 'Prestige': ['Very High'], 'Respondent':[5]})])

# %%
pd.merge(ivies, survey)
# Out:
#                    School Name School Type Starting Median Salary  \
# 0            Dartmouth College  Ivy League            $58,000.00
# 1            Dartmouth College  Ivy League            $58,000.00
# 2            Dartmouth College  Ivy League            $58,000.00
# 3            Dartmouth College  Ivy League            $58,000.00
# 4         Princeton University  Ivy League            $66,500.00
# 5         Princeton University  Ivy League            $66,500.00
# 6         Princeton University  Ivy League            $66,500.00
# 7         Princeton University  Ivy League            $66,500.00
# 8              Yale University  Ivy League            $59,100.00
# 9              Yale University  Ivy League            $59,100.00
# 10             Yale University  Ivy League            $59,100.00
# 11             Yale University  Ivy League            $59,100.00
# 12          Harvard University  Ivy League            $63,400.00
# ...

# %% [markdown]
# # 164 Merging by index
#
# * automatic
# * the on poarameter
# * left_on, right_on params
#
# ## How about merging by index?

# %%
ivies4 = ivies.set_index('School Name')

# %%
reginos2 = regions.set_index('School Name')

# %%
ivies4
# Out:
#                            School Type Starting Median Salary  \
# School Name
# Dartmouth College           Ivy League            $58,000.00
# Princeton University        Ivy League            $66,500.00
# Yale University             Ivy League            $59,100.00
# Harvard University          Ivy League            $63,400.00
# University of Pennsylvania  Ivy League            $60,900.00
# Cornell University          Ivy League            $60,300.00
# Brown University            Ivy League            $56,200.00
# Columbia University         Ivy League            $59,400.00
#
#                            Mid-Career Median Salary
# School Name
# Dartmouth College                      $134,000.00
# Princeton University                   $131,000.00
# Yale University                        $126,000.00
# Harvard University                     $124,000.00
# University of Pennsylvania             $120,000.00
# Cornell University                     $110,000.00
# ...

# %%
reginos2
# Out:
#                                                     Region
# School Name
# Massachusetts Institute of Technology (MIT)   Northeastern
# California Institute of Technology (CIT)        California
# Harvey Mudd College                             California
# Polytechnic University of New York, Brooklyn  Northeastern
# Cooper Union                                  Northeastern
# ...                                                    ...
# Austin Peay State University                      Southern
# Pittsburg State University                      Midwestern
# Southern Utah University                           Western
# Montana State University - Billings                Western
# Black Hills State University                    Midwestern
#
# [269 rows x 1 columns]

# %%
# pd.merge(ivies4, reginos2)

# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
pd.merge(ivies4, reginos2, left_index=True, right_index=True)
# Out:
#                            School Type Starting Median Salary  \
# School Name
# Brown University            Ivy League            $56,200.00
# Columbia University         Ivy League            $59,400.00
# Cornell University          Ivy League            $60,300.00
# Dartmouth College           Ivy League            $58,000.00
# Harvard University          Ivy League            $63,400.00
# Princeton University        Ivy League            $66,500.00
# University of Pennsylvania  Ivy League            $60,900.00
# Yale University             Ivy League            $59,100.00
#
#                            Mid-Career Median Salary        Region
# School Name
# Brown University                       $109,000.00   Northeastern
# Columbia University                    $107,000.00   Northeastern
# Cornell University                     $110,000.00   Northeastern
# Dartmouth College                      $134,000.00   Northeastern
# ...

# %%
regions.head()
# Out:
#                                     School Name        Region
# 0   Massachusetts Institute of Technology (MIT)  Northeastern
# 1      California Institute of Technology (CIT)    California
# 2                           Harvey Mudd College    California
# 3  Polytechnic University of New York, Brooklyn  Northeastern
# 4                                  Cooper Union  Northeastern

# %%
ivies4.head()
# Out:
#                            School Type Starting Median Salary  \
# School Name
# Dartmouth College           Ivy League            $58,000.00
# Princeton University        Ivy League            $66,500.00
# Yale University             Ivy League            $59,100.00
# Harvard University          Ivy League            $63,400.00
# University of Pennsylvania  Ivy League            $60,900.00
#
#                            Mid-Career Median Salary
# School Name
# Dartmouth College                      $134,000.00
# Princeton University                   $131,000.00
# Yale University                        $126,000.00
# Harvard University                     $124,000.00
# University of Pennsylvania             $120,000.00

# %%
# How about merging by index vs column ?
pd.merge(ivies4, regions, left_index=True, right_on='School Name')
# Out:
#    School Type Starting Median Salary Mid-Career Median Salary  \
# 86  Ivy League            $58,000.00              $134,000.00
# 87  Ivy League            $66,500.00              $131,000.00
# 88  Ivy League            $59,100.00              $126,000.00
# 89  Ivy League            $63,400.00              $124,000.00
# 90  Ivy League            $60,900.00              $120,000.00
# 91  Ivy League            $60,300.00              $110,000.00
# 92  Ivy League            $56,200.00              $109,000.00
# 93  Ivy League            $59,400.00              $107,000.00
#
#                    School Name        Region
# 86           Dartmouth College  Northeastern
# 87        Princeton University  Northeastern
# 88             Yale University  Northeastern
# 89          Harvard University  Northeastern
# 90  University of Pennsylvania  Northeastern
# 91          Cornell University  Northeastern
# 92            Brown University  Northeastern
# ...

# %% [markdown]
# # 165 The join() method

# %%
ivies4
# Out:
#                            School Type Starting Median Salary  \
# School Name
# Dartmouth College           Ivy League            $58,000.00
# Princeton University        Ivy League            $66,500.00
# Yale University             Ivy League            $59,100.00
# Harvard University          Ivy League            $63,400.00
# University of Pennsylvania  Ivy League            $60,900.00
# Cornell University          Ivy League            $60,300.00
# Brown University            Ivy League            $56,200.00
# Columbia University         Ivy League            $59,400.00
#
#                            Mid-Career Median Salary
# School Name
# Dartmouth College                      $134,000.00
# Princeton University                   $131,000.00
# Yale University                        $126,000.00
# Harvard University                     $124,000.00
# University of Pennsylvania             $120,000.00
# Cornell University                     $110,000.00
# ...

# %%
reginos2
# Out:
#                                                     Region
# School Name
# Massachusetts Institute of Technology (MIT)   Northeastern
# California Institute of Technology (CIT)        California
# Harvey Mudd College                             California
# Polytechnic University of New York, Brooklyn  Northeastern
# Cooper Union                                  Northeastern
# ...                                                    ...
# Austin Peay State University                      Southern
# Pittsburg State University                      Midwestern
# Southern Utah University                           Western
# Montana State University - Billings                Western
# Black Hills State University                    Midwestern
#
# [269 rows x 1 columns]

# %%
ivies4.join(reginos2)
# Out:
#                            School Type Starting Median Salary  \
# School Name
# Brown University            Ivy League            $56,200.00
# Columbia University         Ivy League            $59,400.00
# Cornell University          Ivy League            $60,300.00
# Dartmouth College           Ivy League            $58,000.00
# Harvard University          Ivy League            $63,400.00
# Princeton University        Ivy League            $66,500.00
# University of Pennsylvania  Ivy League            $60,900.00
# Yale University             Ivy League            $59,100.00
#
#                            Mid-Career Median Salary        Region
# School Name
# Brown University                       $109,000.00   Northeastern
# Columbia University                    $107,000.00   Northeastern
# Cornell University                     $110,000.00   Northeastern
# Dartmouth College                      $134,000.00   Northeastern
# ...

# %%
pd.merge(ivies4, reginos2, right_index=True, left_index=True)
# Out:
#                            School Type Starting Median Salary  \
# School Name
# Brown University            Ivy League            $56,200.00
# Columbia University         Ivy League            $59,400.00
# Cornell University          Ivy League            $60,300.00
# Dartmouth College           Ivy League            $58,000.00
# Harvard University          Ivy League            $63,400.00
# Princeton University        Ivy League            $66,500.00
# University of Pennsylvania  Ivy League            $60,900.00
# Yale University             Ivy League            $59,100.00
#
#                            Mid-Career Median Salary        Region
# School Name
# Brown University                       $109,000.00   Northeastern
# Columbia University                    $107,000.00   Northeastern
# Cornell University                     $110,000.00   Northeastern
# Dartmouth College                      $134,000.00   Northeastern
# ...

# %%
ivies.join(reginos2, on='School Name')
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %% [markdown]
# # 166 Skill challenge

# %%
# 1. Merge liberal arts chools with region and assign the resutlting dataframe to dfm. What region has the highest number of liberal arts choools?

# %%
dfm = pd.merge(liberal, regions)
dfm.head()
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
# 2      Amherst College  Liberal Arts            $54,500.00
# 3    Lafayette College  Liberal Arts            $53,900.00
# 4      Bowdoin College  Liberal Arts            $48,100.00
#
#   Mid-Career Median Salary        Region
# 0             $110,000.00   Northeastern
# 1             $108,000.00   Northeastern
# 2             $107,000.00   Northeastern
# 3             $107,000.00   Northeastern
# 4             $107,000.00   Northeastern

# %%
dfm.loc[:,['School Type','Region']].value_counts()
# Out:
# School Type   Region
# Liberal Arts  Northeastern    25
#               Midwestern       8
#               Western          7
#               Southern         5
#               California       3
# dtype: int64

# %%
# Set school_name as the index of the mid_career dataframe. Do the operation inplace.

# %%
mid_career.head()
# Out:
#                                     school_name  \
# 0   Massachusetts Institute of Technology (MIT)
# 1      California Institute of Technology (CIT)
# 2                           Harvey Mudd College
# 3  Polytechnic University of New York, Brooklyn
# 4                                  Cooper Union
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                       $76,800.00                        $99,200.00
# 1                               NaN                      $104,000.00
# 2                               NaN                       $96,000.00
# 3                       $66,800.00                        $94,300.00
# 4                               NaN                       $80,200.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                      $168,000.00                       $220,000.00
# 1                      $161,000.00                                NaN
# ...

# %%
mid_career.set_index('school_name', inplace=True)

# %%
mid_career.head()
# Out:
#                                              Mid-Career 10th Percentile Salary  \
# school_name
# Massachusetts Institute of Technology (MIT)                        $76,800.00
# California Institute of Technology (CIT)                                   NaN
# Harvey Mudd College                                                        NaN
# Polytechnic University of New York, Brooklyn                       $66,800.00
# Cooper Union                                                               NaN
#
#                                              Mid-Career 25th Percentile Salary  \
# school_name
# Massachusetts Institute of Technology (MIT)                        $99,200.00
# California Institute of Technology (CIT)                          $104,000.00
# Harvey Mudd College                                                $96,000.00
# Polytechnic University of New York, Brooklyn                       $94,300.00
# ...

# %%
# 3. Merge the dfm and mid_career dataframes. Is the join operation one-to-one?

# %%
pd.merge(dfm, mid_career, right_index=True, left_on='School Name' ,sort=True)
# Out:
#                                       School Name   School Type  \
# 2                                 Amherst College  Liberal Arts
# 14                                  Bates College  Liberal Arts
# 4                                 Bowdoin College  Liberal Arts
# 0                             Bucknell University  Liberal Arts
# 10                               Carleton College  Liberal Arts
# 23                                  Colby College  Liberal Arts
# 1                              Colgate University  Liberal Arts
# 5                       College of the Holy Cross  Liberal Arts
# 34                          Colorado College (CC)  Liberal Arts
# 9                                Davidson College  Liberal Arts
# 21                              DePauw University  Liberal Arts
# 31                             Denison University  Liberal Arts
# 47                        Evergreen State College  Liberal Arts
# 45                             Fort Lewis College  Liberal Arts
# ...

# %% [markdown]
# # 167. Solution

# %%
# 1
dfm = pd.merge(liberal, regions)

# %%
dfm.head()
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
# 2      Amherst College  Liberal Arts            $54,500.00
# 3    Lafayette College  Liberal Arts            $53,900.00
# 4      Bowdoin College  Liberal Arts            $48,100.00
#
#   Mid-Career Median Salary        Region
# 0             $110,000.00   Northeastern
# 1             $108,000.00   Northeastern
# 2             $107,000.00   Northeastern
# 3             $107,000.00   Northeastern
# 4             $107,000.00   Northeastern

# %%
dfm.loc[:,'School Type'].nunique()
# Out:
# 1

# %%
dfm.Region.value_counts()
# Out:
# Northeastern    25
# Midwestern       8
# Western          7
# Southern         5
# California       3
# Name: Region, dtype: int64

# %%
# 2
mid_career.head()
# Out:
#                                              Mid-Career 10th Percentile Salary  \
# school_name
# Massachusetts Institute of Technology (MIT)                        $76,800.00
# California Institute of Technology (CIT)                                   NaN
# Harvey Mudd College                                                        NaN
# Polytechnic University of New York, Brooklyn                       $66,800.00
# Cooper Union                                                               NaN
#
#                                              Mid-Career 25th Percentile Salary  \
# school_name
# Massachusetts Institute of Technology (MIT)                        $99,200.00
# California Institute of Technology (CIT)                          $104,000.00
# Harvey Mudd College                                                $96,000.00
# Polytechnic University of New York, Brooklyn                       $94,300.00
# ...

# %%
# 3
dfm.head()
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
# 2      Amherst College  Liberal Arts            $54,500.00
# 3    Lafayette College  Liberal Arts            $53,900.00
# 4      Bowdoin College  Liberal Arts            $48,100.00
#
#   Mid-Career Median Salary        Region
# 0             $110,000.00   Northeastern
# 1             $108,000.00   Northeastern
# 2             $107,000.00   Northeastern
# 3             $107,000.00   Northeastern
# 4             $107,000.00   Northeastern

# %%
pd.merge(mid_career, dfm, left_index=True, right_on='School Name')
# Out:
#    Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 28                               NaN                       $54,100.00
# 29                               NaN                       $54,100.00
# 28                               NaN                       $54,100.00
# 29                               NaN                       $54,100.00
# 0                        $62,800.00                        $80,600.00
# 1                        $60,000.00                        $76,700.00
# 2                                NaN                       $84,900.00
# 3                        $70,600.00                        $79,300.00
# 4                                NaN                       $74,600.00
# 5                                NaN                       $65,600.00
# 6                                NaN                       $54,800.00
# 7                                NaN                       $82,800.00
# ...

# %%
# Is it 1 to 1
left_key = mid_career.index

# %%
# Liberal arts inner join regions
right_key = dfm.loc[:,'School Name']

# %%
left_key[left_key.isin(right_key)]
# Out:
# Index(['Randolph-Macon College', 'Bucknell University', 'Colgate University',
#        'Amherst College', 'Lafayette College', 'Bowdoin College',
#        'College of the Holy Cross', 'Occidental College',
#        'Washington and Lee University', 'Swarthmore College',
#        'Davidson College', 'Carleton College', 'Williams College',
#        'Pomona College', 'Wesleyan University (Middletown, Connecticut)',
#        'Bates College', 'Union College', 'University of Richmond',
#        'Vassar College', 'Middlebury College', 'Mount Holyoke College',
#        'Franklin and Marshall College', 'DePauw University',
#        'St. Olaf College', 'Colby College', 'Gettysburg College',
#        'Siena College', 'Smith College', 'Hamilton College',
#        'Randolph-Macon College', 'Wellesley College', 'Denison University',
#        'Oberlin College', 'University of Puget Sound', 'Colorado College (CC)',
#        'Reed College', 'Gustavus Adolphus College', 'Whitman College',
# ...

# %%
left_key[left_key.isin(right_key)].value_counts().sort_values(ascending=False).head()
# Out:
# Randolph-Macon College    2
# Williams College          1
# Colgate University        1
# Amherst College           1
# Lafayette College         1
# Name: school_name, dtype: int64
